# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Reshape, Dropout, Dense 
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Activation, ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
import numpy as np
from PIL import Image
from tqdm import tqdm
import os 
import time
import matplotlib.pyplot as plt

# %%
GENERATE_RES = 3 # Generation resolution factor 
# (1=32, 2=64, 3=96, 4=128, etc.)
GENERATE_SQUARE = 32 * GENERATE_RES # rows/cols (should be square)
IMAGE_CHANNELS = 3

# Preview image 
PREVIEW_ROWS = 4
PREVIEW_COLS = 7
PREVIEW_MARGIN = 16

# Size vector to generate images from
SEED_SIZE = 100

# Configuration
DATA_PATH = '/content/drive/MyDrive/Baroque/Baroque'
EPOCHS = 1000
BATCH_SIZE = 32
BUFFER_SIZE = 60000

print(f"Will generate {GENERATE_SQUARE}px square images.")
# Out:
# Will generate 96px square images.

# %%
training_binary_path = os.path.join(DATA_PATH,
        f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}.npy')

print(f"Looking for file: {training_binary_path}")

if not os.path.isfile(training_binary_path):
  start = time.time()
  print("Loading training images...")

  training_data = []
  faces_path = os.path.join(DATA_PATH)
  for filename in tqdm(os.listdir(faces_path)):
      path = os.path.join(faces_path,filename)
      image = Image.open(path).resize((GENERATE_SQUARE,
            GENERATE_SQUARE),Image.ANTIALIAS)
      training_data.append(np.asarray(image))
  training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,
            GENERATE_SQUARE,IMAGE_CHANNELS))
  training_data = training_data.astype(np.float32)
  training_data = training_data / 127.5 - 1.


  print("Saving training image binary...")
  np.save(training_binary_path,training_data)
  elapsed = time.time()-start
  print (f'Image preprocess time: {hms_string(elapsed)}')
else:
  print("Loading previous training pickle...")
  training_data = np.load(training_binary_path)
# Out:
# Looking for file: /content/drive/MyDrive/Baroque/Baroque/training_data_96_96.npy
# Loading previous training pickle...

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(training_data).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
 def build_generator(seed_size, channels):
    model = Sequential()

    model.add(Dense(4*4*256,activation="relu",input_dim=seed_size))
    model.add(Reshape((4,4,256)))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
   
    # Output resolution, additional upsampling
    model.add(UpSampling2D())
    model.add(Conv2D(128,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    if GENERATE_RES>1:
      model.add(UpSampling2D(size=(GENERATE_RES,GENERATE_RES)))
      model.add(Conv2D(128,kernel_size=3,padding="same"))
      model.add(BatchNormalization(momentum=0.8))
      model.add(Activation("relu"))

    # Final CNN layer
    model.add(Conv2D(channels,kernel_size=3,padding="same"))
    model.add(Activation("tanh"))

    return model


def build_discriminator(image_shape):
    model = Sequential()

    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=image_shape, 
                     padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(512, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))

    return model

# %%
def save_images(cnt,noise):
  image_array = np.full(( 
      PREVIEW_MARGIN + (PREVIEW_ROWS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 
      PREVIEW_MARGIN + (PREVIEW_COLS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 3), 
      255, dtype=np.uint8)
  
  generated_images = generator.predict(noise)

  generated_images = 0.5 * generated_images + 0.5

  image_count = 0
  for row in range(PREVIEW_ROWS):
      for col in range(PREVIEW_COLS):
        r = row * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        c = col * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        image_array[r:r+GENERATE_SQUARE,c:c+GENERATE_SQUARE] = generated_images[image_count] * 255
        image_count += 1

          
  output_path = os.path.join(DATA_PATH,'output')
  if not os.path.exists(output_path):
    os.makedirs(output_path)
  
  filename = os.path.join(output_path,f"train-{cnt}.png")
  im = Image.fromarray(image_array)
  im.save(filename)

# %%
generator = build_generator(SEED_SIZE, IMAGE_CHANNELS)

noise = tf.random.normal([1, SEED_SIZE])
generated_image = generator(noise, training=False)

plt.imshow(generated_image[0, :, :, 0])

# %%
image_shape = (GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS)

discriminator = build_discriminator(image_shape)
decision = discriminator(generated_image)
print (decision)
# Out:
# tf.Tensor([[0.4999055]], shape=(1, 1), dtype=float32)

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy()

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
generator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)

# %%
@tf.function
def train_step(images):
  seed = tf.random.normal([BATCH_SIZE, SEED_SIZE])

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator(seed, training=True)

    real_output = discriminator(images, training=True)
    fake_output = discriminator(generated_images, training=True)

    gen_loss = generator_loss(fake_output)
    disc_loss = discriminator_loss(real_output, fake_output)
    

    gradients_of_generator = gen_tape.gradient(
        gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(
        disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(
        gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(
        gradients_of_discriminator, 
        discriminator.trainable_variables))
  return gen_loss,disc_loss

# %%
def train(dataset, epochs):
  fixed_seed = np.random.normal(0, 1, (PREVIEW_ROWS * PREVIEW_COLS, 
                                       SEED_SIZE))
  start = time.time()

  for epoch in range(epochs):
    epoch_start = time.time()

    gen_loss_list = []
    disc_loss_list = []

    for image_batch in dataset:
      t = train_step(image_batch)
      gen_loss_list.append(t[0])
      disc_loss_list.append(t[1])

    g_loss = sum(gen_loss_list) / len(gen_loss_list)
    d_loss = sum(disc_loss_list) / len(disc_loss_list)

    epoch_elapsed = time.time()-epoch_start
    print (f'Epoch {epoch+1}, gen loss={g_loss},disc loss={d_loss},'
           ' {hms_string(epoch_elapsed)}')
    save_images(epoch,fixed_seed)

  elapsed = time.time()-start
  print (f'Training time: {(elapsed)}')

# %%
train(train_dataset, EPOCHS)
# Out:
# Epoch 1, gen loss=1.9515323638916016,disc loss=1.3830252885818481, {hms_string(epoch_elapsed)}
# Epoch 2, gen loss=1.4233410358428955,disc loss=1.5420395135879517, {hms_string(epoch_elapsed)}
# Epoch 3, gen loss=1.5104320049285889,disc loss=1.4037877321243286, {hms_string(epoch_elapsed)}
# Epoch 4, gen loss=1.4293471574783325,disc loss=1.429079532623291, {hms_string(epoch_elapsed)}
# Epoch 5, gen loss=1.3579788208007812,disc loss=1.3903909921646118, {hms_string(epoch_elapsed)}
# Epoch 6, gen loss=1.4665472507476807,disc loss=1.335316777229309, {hms_string(epoch_elapsed)}
# Epoch 7, gen loss=1.5018255710601807,disc loss=1.4087040424346924, {hms_string(epoch_elapsed)}
# Epoch 8, gen loss=1.4373092651367188,disc loss=1.3893386125564575, {hms_string(epoch_elapsed)}
# Epoch 9, gen loss=1.5067119598388672,disc loss=1.4329097270965576, {hms_string(epoch_elapsed)}
# Epoch 10, gen loss=1.7981548309326172,disc loss=1.203985571861267, {hms_string(epoch_elapsed)}
# Epoch 11, gen loss=1.5368200540542603,disc loss=1.271436333656311, {hms_string(epoch_elapsed)}
# Epoch 12, gen loss=1.5855658054351807,disc loss=1.2645498514175415, {hms_string(epoch_elapsed)}
# Epoch 13, gen loss=1.8208143711090088,disc loss=1.2214206457138062, {hms_string(epoch_elapsed)}
# Epoch 14, gen loss=1.6011805534362793,disc loss=1.2931385040283203, {hms_string(epoch_elapsed)}
# Epoch 15, gen loss=1.6450484991073608,disc loss=1.3353530168533325, {hms_string(epoch_elapsed)}
# Epoch 16, gen loss=1.7300177812576294,disc loss=1.1431597471237183, {hms_string(epoch_elapsed)}
# Epoch 17, gen loss=1.708664894104004,disc loss=1.3207846879959106, {hms_string(epoch_elapsed)}
# Epoch 18, gen loss=1.624172568321228,disc loss=1.2524744272232056, {hms_string(epoch_elapsed)}
# Epoch 19, gen loss=1.655515432357788,disc loss=1.2556993961334229, {hms_string(epoch_elapsed)}
# Epoch 20, gen loss=1.55378258228302,disc loss=1.3597545623779297, {hms_string(epoch_elapsed)}
# Epoch 21, gen loss=1.4331384897232056,disc loss=1.3702466487884521, {hms_string(epoch_elapsed)}
# Epoch 22, gen loss=1.3393092155456543,disc loss=1.3108413219451904, {hms_string(epoch_elapsed)}
# Epoch 23, gen loss=1.5189950466156006,disc loss=1.2589690685272217, {hms_string(epoch_elapsed)}
# Epoch 24, gen loss=1.5615501403808594,disc loss=1.2653108835220337, {hms_string(epoch_elapsed)}
# Epoch 25, gen loss=1.6185377836227417,disc loss=1.2027724981307983, {hms_string(epoch_elapsed)}
# Epoch 26, gen loss=1.602285385131836,disc loss=1.2462224960327148, {hms_string(epoch_elapsed)}
# Epoch 27, gen loss=1.5863709449768066,disc loss=1.1954047679901123, {hms_string(epoch_elapsed)}
# Epoch 28, gen loss=1.679914951324463,disc loss=1.2121542692184448, {hms_string(epoch_elapsed)}
# Epoch 29, gen loss=1.6305391788482666,disc loss=1.1602084636688232, {hms_string(epoch_elapsed)}
# Epoch 30, gen loss=1.6803275346755981,disc loss=1.1882410049438477, {hms_string(epoch_elapsed)}
# Epoch 31, gen loss=1.7091553211212158,disc loss=1.1646746397018433, {hms_string(epoch_elapsed)}
# Epoch 32, gen loss=1.6266586780548096,disc loss=1.1990723609924316, {hms_string(epoch_elapsed)}
# Epoch 33, gen loss=1.6130058765411377,disc loss=1.1852680444717407, {hms_string(epoch_elapsed)}
# Epoch 34, gen loss=1.663116455078125,disc loss=1.2166171073913574, {hms_string(epoch_elapsed)}
# Epoch 35, gen loss=1.6791086196899414,disc loss=1.1435446739196777, {hms_string(epoch_elapsed)}
# Epoch 36, gen loss=1.6819989681243896,disc loss=1.1321697235107422, {hms_string(epoch_elapsed)}
# Epoch 37, gen loss=1.7286421060562134,disc loss=1.1180236339569092, {hms_string(epoch_elapsed)}
# Epoch 38, gen loss=1.7388439178466797,disc loss=1.0859551429748535, {hms_string(epoch_elapsed)}
# Epoch 39, gen loss=1.7655029296875,disc loss=1.1228172779083252, {hms_string(epoch_elapsed)}
# Epoch 40, gen loss=1.8022855520248413,disc loss=1.0877249240875244, {hms_string(epoch_elapsed)}
# Epoch 41, gen loss=1.7629345655441284,disc loss=1.082872748374939, {hms_string(epoch_elapsed)}
# Epoch 42, gen loss=1.7568600177764893,disc loss=1.1564661264419556, {hms_string(epoch_elapsed)}
# Epoch 43, gen loss=1.8597122430801392,disc loss=1.0481269359588623, {hms_string(epoch_elapsed)}
# Epoch 44, gen loss=1.8457605838775635,disc loss=1.077734351158142, {hms_string(epoch_elapsed)}
# Epoch 45, gen loss=1.7936203479766846,disc loss=1.157892107963562, {hms_string(epoch_elapsed)}
# Epoch 46, gen loss=1.8934348821640015,disc loss=1.0593935251235962, {hms_string(epoch_elapsed)}
# Epoch 47, gen loss=1.7745814323425293,disc loss=1.1366363763809204, {hms_string(epoch_elapsed)}
# Epoch 48, gen loss=1.9291062355041504,disc loss=1.016238808631897, {hms_string(epoch_elapsed)}
# Epoch 49, gen loss=1.8535079956054688,disc loss=1.0627394914627075, {hms_string(epoch_elapsed)}
# Epoch 50, gen loss=1.8360315561294556,disc loss=1.069454312324524, {hms_string(epoch_elapsed)}
# Epoch 51, gen loss=1.8517223596572876,disc loss=1.055422067642212, {hms_string(epoch_elapsed)}
# Epoch 52, gen loss=1.9156452417373657,disc loss=1.0654891729354858, {hms_string(epoch_elapsed)}
# Epoch 53, gen loss=1.8797485828399658,disc loss=1.085394024848938, {hms_string(epoch_elapsed)}
# Epoch 54, gen loss=1.8745040893554688,disc loss=1.0417273044586182, {hms_string(epoch_elapsed)}
# Epoch 55, gen loss=1.8604154586791992,disc loss=1.0261465311050415, {hms_string(epoch_elapsed)}
# Epoch 56, gen loss=1.9682050943374634,disc loss=1.0628817081451416, {hms_string(epoch_elapsed)}
# Epoch 57, gen loss=1.8994693756103516,disc loss=1.0409111976623535, {hms_string(epoch_elapsed)}
# Epoch 58, gen loss=1.921342372894287,disc loss=1.0577818155288696, {hms_string(epoch_elapsed)}
# Epoch 59, gen loss=1.9631980657577515,disc loss=1.030759334564209, {hms_string(epoch_elapsed)}
# Epoch 60, gen loss=2.0042688846588135,disc loss=0.9913719892501831, {hms_string(epoch_elapsed)}
# Epoch 61, gen loss=1.912868857383728,disc loss=1.0660182237625122, {hms_string(epoch_elapsed)}
# Epoch 62, gen loss=1.9086238145828247,disc loss=1.0432512760162354, {hms_string(epoch_elapsed)}
# Epoch 63, gen loss=1.9222711324691772,disc loss=1.0293216705322266, {hms_string(epoch_elapsed)}
# Epoch 64, gen loss=1.9415727853775024,disc loss=1.0057086944580078, {hms_string(epoch_elapsed)}
# Epoch 65, gen loss=1.925454020500183,disc loss=1.0436090230941772, {hms_string(epoch_elapsed)}
# Epoch 66, gen loss=1.955420970916748,disc loss=1.0469317436218262, {hms_string(epoch_elapsed)}
# Epoch 67, gen loss=1.9914568662643433,disc loss=1.096508502960205, {hms_string(epoch_elapsed)}
# Epoch 68, gen loss=1.9838428497314453,disc loss=1.0168862342834473, {hms_string(epoch_elapsed)}
# Epoch 69, gen loss=1.9955999851226807,disc loss=0.9859908223152161, {hms_string(epoch_elapsed)}
# Epoch 70, gen loss=1.9950134754180908,disc loss=0.974206805229187, {hms_string(epoch_elapsed)}
# Epoch 71, gen loss=2.080758571624756,disc loss=0.928138256072998, {hms_string(epoch_elapsed)}
# Epoch 72, gen loss=2.07598876953125,disc loss=0.9536673426628113, {hms_string(epoch_elapsed)}
# Epoch 73, gen loss=2.1103639602661133,disc loss=0.9548712372779846, {hms_string(epoch_elapsed)}
# Epoch 74, gen loss=2.124983310699463,disc loss=0.9611313939094543, {hms_string(epoch_elapsed)}
# Epoch 75, gen loss=2.0102317333221436,disc loss=0.9736438393592834, {hms_string(epoch_elapsed)}
# Epoch 76, gen loss=2.0827810764312744,disc loss=0.9836929440498352, {hms_string(epoch_elapsed)}
# Epoch 77, gen loss=2.1503102779388428,disc loss=0.9074352383613586, {hms_string(epoch_elapsed)}
# Epoch 78, gen loss=2.255007743835449,disc loss=0.9185850024223328, {hms_string(epoch_elapsed)}
# Epoch 79, gen loss=2.0991344451904297,disc loss=0.968980610370636, {hms_string(epoch_elapsed)}
# Epoch 80, gen loss=2.1670444011688232,disc loss=0.9228882789611816, {hms_string(epoch_elapsed)}
# Epoch 81, gen loss=2.1218297481536865,disc loss=0.9412859082221985, {hms_string(epoch_elapsed)}
# Epoch 82, gen loss=2.3237574100494385,disc loss=0.8695985078811646, {hms_string(epoch_elapsed)}
# Epoch 83, gen loss=2.2390177249908447,disc loss=0.9083824157714844, {hms_string(epoch_elapsed)}
# Epoch 84, gen loss=2.156752347946167,disc loss=0.9358428120613098, {hms_string(epoch_elapsed)}
# Epoch 85, gen loss=2.209033727645874,disc loss=0.9007671475410461, {hms_string(epoch_elapsed)}
# Epoch 86, gen loss=2.260529041290283,disc loss=0.8676915764808655, {hms_string(epoch_elapsed)}
# Epoch 87, gen loss=2.23943829536438,disc loss=0.8668186664581299, {hms_string(epoch_elapsed)}
# Epoch 88, gen loss=2.326143264770508,disc loss=0.8381297588348389, {hms_string(epoch_elapsed)}
# Epoch 89, gen loss=2.332378625869751,disc loss=0.9018376469612122, {hms_string(epoch_elapsed)}
# Epoch 90, gen loss=2.3023247718811035,disc loss=0.9215621948242188, {hms_string(epoch_elapsed)}
# Epoch 91, gen loss=2.3195042610168457,disc loss=0.8923145532608032, {hms_string(epoch_elapsed)}
# Epoch 92, gen loss=2.3446567058563232,disc loss=0.8423884510993958, {hms_string(epoch_elapsed)}
# Epoch 93, gen loss=2.3412535190582275,disc loss=0.8936069011688232, {hms_string(epoch_elapsed)}
# Epoch 94, gen loss=2.5479044914245605,disc loss=0.821711540222168, {hms_string(epoch_elapsed)}
# Epoch 95, gen loss=2.4488070011138916,disc loss=0.8288158774375916, {hms_string(epoch_elapsed)}
# Epoch 96, gen loss=2.367680072784424,disc loss=0.8621190786361694, {hms_string(epoch_elapsed)}
# Epoch 97, gen loss=2.386802911758423,disc loss=0.8915911316871643, {hms_string(epoch_elapsed)}
# Epoch 98, gen loss=2.330869674682617,disc loss=0.8666650652885437, {hms_string(epoch_elapsed)}
# Epoch 99, gen loss=2.336796998977661,disc loss=0.859046459197998, {hms_string(epoch_elapsed)}
# Epoch 100, gen loss=2.4097421169281006,disc loss=0.8791298270225525, {hms_string(epoch_elapsed)}
# Epoch 101, gen loss=2.3271000385284424,disc loss=0.8512815237045288, {hms_string(epoch_elapsed)}
# Epoch 102, gen loss=2.400763988494873,disc loss=0.8449674844741821, {hms_string(epoch_elapsed)}
# Epoch 103, gen loss=2.4251084327697754,disc loss=0.842103898525238, {hms_string(epoch_elapsed)}
# Epoch 104, gen loss=2.402052879333496,disc loss=0.8718906044960022, {hms_string(epoch_elapsed)}
# Epoch 105, gen loss=2.4160783290863037,disc loss=0.8357616662979126, {hms_string(epoch_elapsed)}
# Epoch 106, gen loss=2.4331891536712646,disc loss=0.7933530211448669, {hms_string(epoch_elapsed)}
# Epoch 107, gen loss=2.4800703525543213,disc loss=0.7974727749824524, {hms_string(epoch_elapsed)}
# Epoch 108, gen loss=2.5268704891204834,disc loss=0.7899572253227234, {hms_string(epoch_elapsed)}
# Epoch 109, gen loss=2.4554860591888428,disc loss=0.8243370652198792, {hms_string(epoch_elapsed)}
# Epoch 110, gen loss=2.519479274749756,disc loss=0.8279979825019836, {hms_string(epoch_elapsed)}
# Epoch 111, gen loss=2.4319961071014404,disc loss=0.7945736646652222, {hms_string(epoch_elapsed)}
# Epoch 112, gen loss=2.5266425609588623,disc loss=0.7590261697769165, {hms_string(epoch_elapsed)}
# Epoch 113, gen loss=2.4947032928466797,disc loss=0.8130705952644348, {hms_string(epoch_elapsed)}
# Epoch 114, gen loss=2.4980506896972656,disc loss=0.7498356699943542, {hms_string(epoch_elapsed)}
# Epoch 115, gen loss=2.569540500640869,disc loss=0.8233161568641663, {hms_string(epoch_elapsed)}
# Epoch 116, gen loss=2.618671417236328,disc loss=0.7917414903640747, {hms_string(epoch_elapsed)}
# Epoch 117, gen loss=2.607494354248047,disc loss=0.7651347517967224, {hms_string(epoch_elapsed)}
# Epoch 118, gen loss=2.5826687812805176,disc loss=0.7607933282852173, {hms_string(epoch_elapsed)}
# Epoch 119, gen loss=2.636087417602539,disc loss=0.8242232799530029, {hms_string(epoch_elapsed)}
# Epoch 120, gen loss=2.6529006958007812,disc loss=0.7207924127578735, {hms_string(epoch_elapsed)}
# Epoch 121, gen loss=2.663431167602539,disc loss=0.7668247222900391, {hms_string(epoch_elapsed)}
# Epoch 122, gen loss=2.6798694133758545,disc loss=0.7727463245391846, {hms_string(epoch_elapsed)}
# Epoch 123, gen loss=2.700754165649414,disc loss=0.7546786069869995, {hms_string(epoch_elapsed)}
# Epoch 124, gen loss=2.635921001434326,disc loss=0.7788302302360535, {hms_string(epoch_elapsed)}
# Epoch 125, gen loss=2.791696786880493,disc loss=0.7214915156364441, {hms_string(epoch_elapsed)}
# Epoch 126, gen loss=2.6008412837982178,disc loss=0.7610833048820496, {hms_string(epoch_elapsed)}
# Epoch 127, gen loss=2.718763828277588,disc loss=0.7589080929756165, {hms_string(epoch_elapsed)}
# Epoch 128, gen loss=2.7454798221588135,disc loss=0.7036064267158508, {hms_string(epoch_elapsed)}
# Epoch 129, gen loss=2.623231887817383,disc loss=0.737315833568573, {hms_string(epoch_elapsed)}
# Epoch 130, gen loss=2.740070104598999,disc loss=0.7233728170394897, {hms_string(epoch_elapsed)}
# Epoch 131, gen loss=2.7656095027923584,disc loss=0.7303669452667236, {hms_string(epoch_elapsed)}
# Epoch 132, gen loss=2.781493902206421,disc loss=0.7847490310668945, {hms_string(epoch_elapsed)}
# Epoch 133, gen loss=2.739906072616577,disc loss=0.7186799645423889, {hms_string(epoch_elapsed)}
# Epoch 134, gen loss=2.8347136974334717,disc loss=0.7152455449104309, {hms_string(epoch_elapsed)}
# Epoch 135, gen loss=2.8888485431671143,disc loss=0.6379866600036621, {hms_string(epoch_elapsed)}
# Epoch 136, gen loss=2.872373342514038,disc loss=0.6959878206253052, {hms_string(epoch_elapsed)}
# Epoch 137, gen loss=2.9055089950561523,disc loss=0.6911160945892334, {hms_string(epoch_elapsed)}
# Epoch 138, gen loss=2.9277472496032715,disc loss=0.6874804496765137, {hms_string(epoch_elapsed)}
# Epoch 139, gen loss=2.880836009979248,disc loss=0.6856981515884399, {hms_string(epoch_elapsed)}
# Epoch 140, gen loss=2.8714590072631836,disc loss=0.6752216219902039, {hms_string(epoch_elapsed)}
# Epoch 141, gen loss=2.918543815612793,disc loss=0.723841667175293, {hms_string(epoch_elapsed)}
# Epoch 142, gen loss=2.9034512042999268,disc loss=0.652785062789917, {hms_string(epoch_elapsed)}
# Epoch 143, gen loss=2.945962429046631,disc loss=0.6425697207450867, {hms_string(epoch_elapsed)}
# Epoch 144, gen loss=2.8806583881378174,disc loss=0.7279884815216064, {hms_string(epoch_elapsed)}
# Epoch 145, gen loss=3.1670427322387695,disc loss=0.6647840738296509, {hms_string(epoch_elapsed)}
# Epoch 146, gen loss=2.9934568405151367,disc loss=0.6597418189048767, {hms_string(epoch_elapsed)}
# Epoch 147, gen loss=2.988450288772583,disc loss=0.6745640635490417, {hms_string(epoch_elapsed)}
# Epoch 148, gen loss=2.935718059539795,disc loss=0.6846706867218018, {hms_string(epoch_elapsed)}
# Epoch 149, gen loss=3.0346767902374268,disc loss=0.6781027317047119, {hms_string(epoch_elapsed)}
# Epoch 150, gen loss=3.0118918418884277,disc loss=0.6562389135360718, {hms_string(epoch_elapsed)}
# Epoch 151, gen loss=3.0086371898651123,disc loss=0.6853094100952148, {hms_string(epoch_elapsed)}
# Epoch 152, gen loss=3.0378406047821045,disc loss=0.6552041172981262, {hms_string(epoch_elapsed)}
# Epoch 153, gen loss=3.042201280593872,disc loss=0.6525987982749939, {hms_string(epoch_elapsed)}
# Epoch 154, gen loss=3.0844855308532715,disc loss=0.6582379341125488, {hms_string(epoch_elapsed)}
# Epoch 155, gen loss=2.962127208709717,disc loss=0.6629136800765991, {hms_string(epoch_elapsed)}
# Epoch 156, gen loss=3.1007840633392334,disc loss=0.6473726034164429, {hms_string(epoch_elapsed)}
# Epoch 157, gen loss=3.088301181793213,disc loss=0.6560069918632507, {hms_string(epoch_elapsed)}
# Epoch 158, gen loss=3.1097614765167236,disc loss=0.6512341499328613, {hms_string(epoch_elapsed)}
# Epoch 159, gen loss=3.152203321456909,disc loss=0.6351407170295715, {hms_string(epoch_elapsed)}
# Epoch 160, gen loss=3.064375400543213,disc loss=0.6773297190666199, {hms_string(epoch_elapsed)}
# Epoch 161, gen loss=2.979903221130371,disc loss=0.6508445739746094, {hms_string(epoch_elapsed)}
# Epoch 162, gen loss=3.078005075454712,disc loss=0.6089533567428589, {hms_string(epoch_elapsed)}
# Epoch 163, gen loss=3.183330535888672,disc loss=0.6672537922859192, {hms_string(epoch_elapsed)}
# Epoch 164, gen loss=3.143592596054077,disc loss=0.6093317866325378, {hms_string(epoch_elapsed)}
# Epoch 165, gen loss=3.1575939655303955,disc loss=0.614323079586029, {hms_string(epoch_elapsed)}
# Epoch 166, gen loss=3.202648162841797,disc loss=0.6493154764175415, {hms_string(epoch_elapsed)}
# Epoch 167, gen loss=3.217250347137451,disc loss=0.6278911232948303, {hms_string(epoch_elapsed)}
# Epoch 168, gen loss=3.181619167327881,disc loss=0.6153256297111511, {hms_string(epoch_elapsed)}
# Epoch 169, gen loss=3.201902389526367,disc loss=0.6251013875007629, {hms_string(epoch_elapsed)}
# Epoch 170, gen loss=3.2414257526397705,disc loss=0.6247800588607788, {hms_string(epoch_elapsed)}
# Epoch 171, gen loss=3.2119786739349365,disc loss=0.6508013010025024, {hms_string(epoch_elapsed)}
# Epoch 172, gen loss=3.2246947288513184,disc loss=0.6207358837127686, {hms_string(epoch_elapsed)}
# Epoch 173, gen loss=3.3296544551849365,disc loss=0.5961319804191589, {hms_string(epoch_elapsed)}
# Epoch 174, gen loss=3.237260580062866,disc loss=0.6446303129196167, {hms_string(epoch_elapsed)}
# Epoch 175, gen loss=3.2792179584503174,disc loss=0.6519930362701416, {hms_string(epoch_elapsed)}
# Epoch 176, gen loss=3.2155258655548096,disc loss=0.6134703159332275, {hms_string(epoch_elapsed)}
# Epoch 177, gen loss=3.2679271697998047,disc loss=0.6145910024642944, {hms_string(epoch_elapsed)}
# Epoch 178, gen loss=3.377824544906616,disc loss=0.6057238578796387, {hms_string(epoch_elapsed)}
# Epoch 179, gen loss=3.2852563858032227,disc loss=0.6357020735740662, {hms_string(epoch_elapsed)}
# Epoch 180, gen loss=3.415778636932373,disc loss=0.5725177526473999, {hms_string(epoch_elapsed)}
# Epoch 181, gen loss=3.3531582355499268,disc loss=0.5894312858581543, {hms_string(epoch_elapsed)}
# Epoch 182, gen loss=3.395657777786255,disc loss=0.629299521446228, {hms_string(epoch_elapsed)}
# Epoch 183, gen loss=3.3389151096343994,disc loss=0.6148756146430969, {hms_string(epoch_elapsed)}
# Epoch 184, gen loss=3.3779516220092773,disc loss=0.6275926232337952, {hms_string(epoch_elapsed)}
# Epoch 185, gen loss=3.3785512447357178,disc loss=0.5650339722633362, {hms_string(epoch_elapsed)}
# Epoch 186, gen loss=3.3393986225128174,disc loss=0.6028348207473755, {hms_string(epoch_elapsed)}
# Epoch 187, gen loss=3.3852620124816895,disc loss=0.5745176672935486, {hms_string(epoch_elapsed)}
# Epoch 188, gen loss=3.333117723464966,disc loss=0.595491886138916, {hms_string(epoch_elapsed)}
# Epoch 189, gen loss=3.419555425643921,disc loss=0.5434486269950867, {hms_string(epoch_elapsed)}
# Epoch 190, gen loss=3.52274489402771,disc loss=0.5104082822799683, {hms_string(epoch_elapsed)}
# Epoch 191, gen loss=3.484006404876709,disc loss=0.5784013867378235, {hms_string(epoch_elapsed)}
# Epoch 192, gen loss=3.5174787044525146,disc loss=0.5373469591140747, {hms_string(epoch_elapsed)}
# Epoch 193, gen loss=3.469161033630371,disc loss=0.6042571067810059, {hms_string(epoch_elapsed)}
# Epoch 194, gen loss=3.4251515865325928,disc loss=0.6091457009315491, {hms_string(epoch_elapsed)}
# Epoch 195, gen loss=3.459514617919922,disc loss=0.5610646605491638, {hms_string(epoch_elapsed)}
# Epoch 196, gen loss=3.5383317470550537,disc loss=0.5829892754554749, {hms_string(epoch_elapsed)}
# Epoch 197, gen loss=3.4663870334625244,disc loss=0.5937458276748657, {hms_string(epoch_elapsed)}
# Epoch 198, gen loss=3.5611727237701416,disc loss=0.5447870492935181, {hms_string(epoch_elapsed)}
# Epoch 199, gen loss=3.506657600402832,disc loss=0.5760453939437866, {hms_string(epoch_elapsed)}
# Epoch 200, gen loss=3.5328056812286377,disc loss=0.5180097222328186, {hms_string(epoch_elapsed)}
# Epoch 201, gen loss=3.659844398498535,disc loss=0.5497581362724304, {hms_string(epoch_elapsed)}
# Epoch 202, gen loss=3.632218360900879,disc loss=0.5275259613990784, {hms_string(epoch_elapsed)}
# Epoch 203, gen loss=3.613750457763672,disc loss=0.592225193977356, {hms_string(epoch_elapsed)}
# Epoch 204, gen loss=3.589970827102661,disc loss=0.5394219756126404, {hms_string(epoch_elapsed)}
# Epoch 205, gen loss=3.634833574295044,disc loss=0.5348650813102722, {hms_string(epoch_elapsed)}
# Epoch 206, gen loss=3.806121587753296,disc loss=0.5127281546592712, {hms_string(epoch_elapsed)}
# Epoch 207, gen loss=3.7247655391693115,disc loss=0.5297553539276123, {hms_string(epoch_elapsed)}
# Epoch 208, gen loss=3.646831512451172,disc loss=0.5534564256668091, {hms_string(epoch_elapsed)}
# Epoch 209, gen loss=3.595642328262329,disc loss=0.5608083605766296, {hms_string(epoch_elapsed)}
# Epoch 210, gen loss=3.591937780380249,disc loss=0.5500859022140503, {hms_string(epoch_elapsed)}
# Epoch 211, gen loss=3.7397119998931885,disc loss=0.5153921842575073, {hms_string(epoch_elapsed)}
# Epoch 212, gen loss=3.72982120513916,disc loss=0.5762401223182678, {hms_string(epoch_elapsed)}
# Epoch 213, gen loss=3.7314929962158203,disc loss=0.5743454098701477, {hms_string(epoch_elapsed)}
# Epoch 214, gen loss=3.727123260498047,disc loss=0.49872273206710815, {hms_string(epoch_elapsed)}
# Epoch 215, gen loss=3.7354979515075684,disc loss=0.49060460925102234, {hms_string(epoch_elapsed)}
# Epoch 216, gen loss=3.716520071029663,disc loss=0.5418739914894104, {hms_string(epoch_elapsed)}
# Epoch 217, gen loss=3.7633180618286133,disc loss=0.5226337909698486, {hms_string(epoch_elapsed)}
# Epoch 218, gen loss=3.830515146255493,disc loss=0.5037895441055298, {hms_string(epoch_elapsed)}
# Epoch 219, gen loss=3.8083317279815674,disc loss=0.5290932059288025, {hms_string(epoch_elapsed)}
# Epoch 220, gen loss=3.7774622440338135,disc loss=0.5188205242156982, {hms_string(epoch_elapsed)}
# Epoch 221, gen loss=3.855902910232544,disc loss=0.4880698025226593, {hms_string(epoch_elapsed)}
# Epoch 222, gen loss=3.896390676498413,disc loss=0.4944339692592621, {hms_string(epoch_elapsed)}
# Epoch 223, gen loss=3.7824785709381104,disc loss=0.5051996111869812, {hms_string(epoch_elapsed)}
# Epoch 224, gen loss=3.8582911491394043,disc loss=0.4907185733318329, {hms_string(epoch_elapsed)}
# Epoch 225, gen loss=3.8777425289154053,disc loss=0.4994937777519226, {hms_string(epoch_elapsed)}
# Epoch 226, gen loss=3.8438475131988525,disc loss=0.4964779019355774, {hms_string(epoch_elapsed)}
# Epoch 227, gen loss=3.9221692085266113,disc loss=0.4757539927959442, {hms_string(epoch_elapsed)}
# Epoch 228, gen loss=3.92887282371521,disc loss=0.4953695833683014, {hms_string(epoch_elapsed)}
# Epoch 229, gen loss=3.919163227081299,disc loss=0.4826890826225281, {hms_string(epoch_elapsed)}
# Epoch 230, gen loss=4.004237651824951,disc loss=0.5163385272026062, {hms_string(epoch_elapsed)}
# Epoch 231, gen loss=3.999171733856201,disc loss=0.48803067207336426, {hms_string(epoch_elapsed)}
# Epoch 232, gen loss=3.9882256984710693,disc loss=0.4961109161376953, {hms_string(epoch_elapsed)}
# Epoch 233, gen loss=3.9485514163970947,disc loss=0.4839455187320709, {hms_string(epoch_elapsed)}
# Epoch 234, gen loss=3.9733424186706543,disc loss=0.4816821813583374, {hms_string(epoch_elapsed)}
# Epoch 235, gen loss=3.9724984169006348,disc loss=0.45972010493278503, {hms_string(epoch_elapsed)}
# Epoch 236, gen loss=3.854783058166504,disc loss=0.48938316106796265, {hms_string(epoch_elapsed)}
# Epoch 237, gen loss=4.124920845031738,disc loss=0.48018380999565125, {hms_string(epoch_elapsed)}
# Epoch 238, gen loss=4.034315586090088,disc loss=0.49559709429740906, {hms_string(epoch_elapsed)}
# Epoch 239, gen loss=4.004596710205078,disc loss=0.49757546186447144, {hms_string(epoch_elapsed)}
# Epoch 240, gen loss=4.10107421875,disc loss=0.46676430106163025, {hms_string(epoch_elapsed)}
# Epoch 241, gen loss=4.022525310516357,disc loss=0.5307928323745728, {hms_string(epoch_elapsed)}
# Epoch 242, gen loss=4.068760395050049,disc loss=0.46803373098373413, {hms_string(epoch_elapsed)}
# Epoch 243, gen loss=4.057098388671875,disc loss=0.4799530506134033, {hms_string(epoch_elapsed)}
# Epoch 244, gen loss=4.209046363830566,disc loss=0.48148128390312195, {hms_string(epoch_elapsed)}
# Epoch 245, gen loss=4.120318412780762,disc loss=0.5115107297897339, {hms_string(epoch_elapsed)}
# Epoch 246, gen loss=4.021429538726807,disc loss=0.5045120120048523, {hms_string(epoch_elapsed)}
# Epoch 247, gen loss=4.114158630371094,disc loss=0.42665737867355347, {hms_string(epoch_elapsed)}
# Epoch 248, gen loss=4.040318489074707,disc loss=0.48813387751579285, {hms_string(epoch_elapsed)}
# Epoch 249, gen loss=4.00575065612793,disc loss=0.44312241673469543, {hms_string(epoch_elapsed)}
# Epoch 250, gen loss=4.05916166305542,disc loss=0.5094727277755737, {hms_string(epoch_elapsed)}
# Epoch 251, gen loss=4.1462578773498535,disc loss=0.5146624445915222, {hms_string(epoch_elapsed)}
# Epoch 252, gen loss=4.102557182312012,disc loss=0.4587886333465576, {hms_string(epoch_elapsed)}
# Epoch 253, gen loss=4.230635166168213,disc loss=0.41082829236984253, {hms_string(epoch_elapsed)}
# Epoch 254, gen loss=4.175527572631836,disc loss=0.4699328541755676, {hms_string(epoch_elapsed)}
# Epoch 255, gen loss=4.185814380645752,disc loss=0.4510284960269928, {hms_string(epoch_elapsed)}
# Epoch 256, gen loss=4.248493194580078,disc loss=0.45003217458724976, {hms_string(epoch_elapsed)}
# Epoch 257, gen loss=4.159698486328125,disc loss=0.4975757598876953, {hms_string(epoch_elapsed)}
# Epoch 258, gen loss=4.167898178100586,disc loss=0.5066717267036438, {hms_string(epoch_elapsed)}
# Epoch 259, gen loss=4.152925491333008,disc loss=0.4307446777820587, {hms_string(epoch_elapsed)}
# Epoch 260, gen loss=4.240726470947266,disc loss=0.41687023639678955, {hms_string(epoch_elapsed)}
# Epoch 261, gen loss=4.258831977844238,disc loss=0.4581623673439026, {hms_string(epoch_elapsed)}
# Epoch 262, gen loss=4.252925872802734,disc loss=0.42687031626701355, {hms_string(epoch_elapsed)}
# Epoch 263, gen loss=4.207147598266602,disc loss=0.43238362669944763, {hms_string(epoch_elapsed)}
# Epoch 264, gen loss=4.2341179847717285,disc loss=0.46441981196403503, {hms_string(epoch_elapsed)}
# Epoch 265, gen loss=4.25397253036499,disc loss=0.47252365946769714, {hms_string(epoch_elapsed)}
# Epoch 266, gen loss=4.279551029205322,disc loss=0.4611565172672272, {hms_string(epoch_elapsed)}
# Epoch 267, gen loss=4.36279296875,disc loss=0.4377021789550781, {hms_string(epoch_elapsed)}
# Epoch 268, gen loss=4.257439136505127,disc loss=0.48978710174560547, {hms_string(epoch_elapsed)}
# Epoch 269, gen loss=4.3970160484313965,disc loss=0.4489980936050415, {hms_string(epoch_elapsed)}
# Epoch 270, gen loss=4.290968418121338,disc loss=0.4657285809516907, {hms_string(epoch_elapsed)}
# Epoch 271, gen loss=4.295320510864258,disc loss=0.44460687041282654, {hms_string(epoch_elapsed)}
# Epoch 272, gen loss=4.2808146476745605,disc loss=0.42340314388275146, {hms_string(epoch_elapsed)}
# Epoch 273, gen loss=4.372857570648193,disc loss=0.4493391811847687, {hms_string(epoch_elapsed)}
# Epoch 274, gen loss=4.388617038726807,disc loss=0.419185996055603, {hms_string(epoch_elapsed)}
# Epoch 275, gen loss=4.461165904998779,disc loss=0.43824493885040283, {hms_string(epoch_elapsed)}
# Epoch 276, gen loss=4.354650020599365,disc loss=0.4074491858482361, {hms_string(epoch_elapsed)}
# Epoch 277, gen loss=4.504885673522949,disc loss=0.3985868990421295, {hms_string(epoch_elapsed)}
# Epoch 278, gen loss=4.3877034187316895,disc loss=0.4374839663505554, {hms_string(epoch_elapsed)}
# Epoch 279, gen loss=4.405343055725098,disc loss=0.49048706889152527, {hms_string(epoch_elapsed)}
# Epoch 280, gen loss=4.369711399078369,disc loss=0.4435606002807617, {hms_string(epoch_elapsed)}
# Epoch 281, gen loss=4.400965213775635,disc loss=0.43618929386138916, {hms_string(epoch_elapsed)}
# Epoch 282, gen loss=4.381807804107666,disc loss=0.4422873258590698, {hms_string(epoch_elapsed)}
# Epoch 283, gen loss=4.370336055755615,disc loss=0.4199182987213135, {hms_string(epoch_elapsed)}
# Epoch 284, gen loss=4.429073333740234,disc loss=0.3965540826320648, {hms_string(epoch_elapsed)}
# Epoch 285, gen loss=4.547245025634766,disc loss=0.4267466962337494, {hms_string(epoch_elapsed)}
# Epoch 286, gen loss=4.424598693847656,disc loss=0.43838009238243103, {hms_string(epoch_elapsed)}
# Epoch 287, gen loss=4.504386901855469,disc loss=0.4378003478050232, {hms_string(epoch_elapsed)}
# Epoch 288, gen loss=4.358922004699707,disc loss=0.4028223156929016, {hms_string(epoch_elapsed)}
# Epoch 289, gen loss=4.49164342880249,disc loss=0.4128307104110718, {hms_string(epoch_elapsed)}
# Epoch 290, gen loss=4.501946926116943,disc loss=0.3907972276210785, {hms_string(epoch_elapsed)}
# Epoch 291, gen loss=4.471343040466309,disc loss=0.41360679268836975, {hms_string(epoch_elapsed)}
# Epoch 292, gen loss=4.554319858551025,disc loss=0.41877281665802, {hms_string(epoch_elapsed)}
# Epoch 293, gen loss=4.423343658447266,disc loss=0.4306941628456116, {hms_string(epoch_elapsed)}
# Epoch 294, gen loss=4.399779796600342,disc loss=0.4715960919857025, {hms_string(epoch_elapsed)}
# Epoch 295, gen loss=4.4698486328125,disc loss=0.41811585426330566, {hms_string(epoch_elapsed)}
# Epoch 296, gen loss=4.564062595367432,disc loss=0.41809019446372986, {hms_string(epoch_elapsed)}
# Epoch 297, gen loss=4.564684867858887,disc loss=0.4199729263782501, {hms_string(epoch_elapsed)}
# Epoch 298, gen loss=4.592519760131836,disc loss=0.4055793285369873, {hms_string(epoch_elapsed)}
# Epoch 299, gen loss=4.642462253570557,disc loss=0.4009246528148651, {hms_string(epoch_elapsed)}
# Epoch 300, gen loss=4.558951377868652,disc loss=0.4320003092288971, {hms_string(epoch_elapsed)}
# Epoch 301, gen loss=4.612316131591797,disc loss=0.3963238596916199, {hms_string(epoch_elapsed)}
# Epoch 302, gen loss=4.547791957855225,disc loss=0.43269652128219604, {hms_string(epoch_elapsed)}
# Epoch 303, gen loss=4.530040740966797,disc loss=0.41255784034729004, {hms_string(epoch_elapsed)}
# Epoch 304, gen loss=4.603247165679932,disc loss=0.404706209897995, {hms_string(epoch_elapsed)}
# Epoch 305, gen loss=4.661172866821289,disc loss=0.4036489427089691, {hms_string(epoch_elapsed)}
# Epoch 306, gen loss=4.583099365234375,disc loss=0.41389700770378113, {hms_string(epoch_elapsed)}
# Epoch 307, gen loss=4.624884605407715,disc loss=0.3962838351726532, {hms_string(epoch_elapsed)}
# Epoch 308, gen loss=4.675004482269287,disc loss=0.3892394006252289, {hms_string(epoch_elapsed)}
# Epoch 309, gen loss=4.5891642570495605,disc loss=0.39851564168930054, {hms_string(epoch_elapsed)}
# Epoch 310, gen loss=4.705364227294922,disc loss=0.37132352590560913, {hms_string(epoch_elapsed)}
# Epoch 311, gen loss=4.64262580871582,disc loss=0.42809996008872986, {hms_string(epoch_elapsed)}
# Epoch 312, gen loss=4.657232761383057,disc loss=0.39573124051094055, {hms_string(epoch_elapsed)}
# Epoch 313, gen loss=4.740621089935303,disc loss=0.38054192066192627, {hms_string(epoch_elapsed)}
# Epoch 314, gen loss=4.73221492767334,disc loss=0.40684425830841064, {hms_string(epoch_elapsed)}
# Epoch 315, gen loss=4.668736457824707,disc loss=0.4025762975215912, {hms_string(epoch_elapsed)}
# Epoch 316, gen loss=4.814050674438477,disc loss=0.39291930198669434, {hms_string(epoch_elapsed)}
# Epoch 317, gen loss=4.692800998687744,disc loss=0.4229978024959564, {hms_string(epoch_elapsed)}
# Epoch 318, gen loss=4.686153411865234,disc loss=0.431591659784317, {hms_string(epoch_elapsed)}
# Epoch 319, gen loss=4.791533946990967,disc loss=0.3567677140235901, {hms_string(epoch_elapsed)}
# Epoch 320, gen loss=4.746015548706055,disc loss=0.3983379900455475, {hms_string(epoch_elapsed)}
# Epoch 321, gen loss=4.821585178375244,disc loss=0.3835313022136688, {hms_string(epoch_elapsed)}
# Epoch 322, gen loss=4.617305755615234,disc loss=0.4145698547363281, {hms_string(epoch_elapsed)}
# Epoch 323, gen loss=4.7054443359375,disc loss=0.37677350640296936, {hms_string(epoch_elapsed)}
# Epoch 324, gen loss=4.8119378089904785,disc loss=0.4030141532421112, {hms_string(epoch_elapsed)}
# Epoch 325, gen loss=4.754557132720947,disc loss=0.39305979013442993, {hms_string(epoch_elapsed)}
# Epoch 326, gen loss=4.932464122772217,disc loss=0.38788560032844543, {hms_string(epoch_elapsed)}
# Epoch 327, gen loss=4.791615009307861,disc loss=0.3937549293041229, {hms_string(epoch_elapsed)}
# Epoch 328, gen loss=4.9607367515563965,disc loss=0.3874605596065521, {hms_string(epoch_elapsed)}
# Epoch 329, gen loss=4.995021343231201,disc loss=0.3954078257083893, {hms_string(epoch_elapsed)}
# Epoch 330, gen loss=4.849685192108154,disc loss=0.38372448086738586, {hms_string(epoch_elapsed)}
# Epoch 331, gen loss=4.926590919494629,disc loss=0.3995615839958191, {hms_string(epoch_elapsed)}
# Epoch 332, gen loss=4.90781307220459,disc loss=0.40119248628616333, {hms_string(epoch_elapsed)}
# Epoch 333, gen loss=4.952366352081299,disc loss=0.3506981134414673, {hms_string(epoch_elapsed)}
# Epoch 334, gen loss=4.796505928039551,disc loss=0.3759896457195282, {hms_string(epoch_elapsed)}
# Epoch 335, gen loss=4.7272186279296875,disc loss=0.40614551305770874, {hms_string(epoch_elapsed)}
# Epoch 336, gen loss=4.809091567993164,disc loss=0.371643990278244, {hms_string(epoch_elapsed)}
# Epoch 337, gen loss=4.905658721923828,disc loss=0.3651418387889862, {hms_string(epoch_elapsed)}
# Epoch 338, gen loss=4.908409118652344,disc loss=0.3418630063533783, {hms_string(epoch_elapsed)}
# Epoch 339, gen loss=5.051370620727539,disc loss=0.3654317855834961, {hms_string(epoch_elapsed)}
# Epoch 340, gen loss=4.909139633178711,disc loss=0.3597293794155121, {hms_string(epoch_elapsed)}
# Epoch 341, gen loss=5.0111985206604,disc loss=0.38999471068382263, {hms_string(epoch_elapsed)}
# Epoch 342, gen loss=4.94402551651001,disc loss=0.36226123571395874, {hms_string(epoch_elapsed)}
# Epoch 343, gen loss=5.091481685638428,disc loss=0.33610811829566956, {hms_string(epoch_elapsed)}
# Epoch 344, gen loss=4.983104705810547,disc loss=0.4106561243534088, {hms_string(epoch_elapsed)}
# Epoch 345, gen loss=4.938624858856201,disc loss=0.3670671582221985, {hms_string(epoch_elapsed)}
# Epoch 346, gen loss=4.997088432312012,disc loss=0.34459537267684937, {hms_string(epoch_elapsed)}
# Epoch 347, gen loss=4.931611061096191,disc loss=0.3871798813343048, {hms_string(epoch_elapsed)}
# Epoch 348, gen loss=5.036393165588379,disc loss=0.3846501111984253, {hms_string(epoch_elapsed)}
# Epoch 349, gen loss=5.072198390960693,disc loss=0.364018052816391, {hms_string(epoch_elapsed)}
# Epoch 350, gen loss=4.772589683532715,disc loss=0.3825218677520752, {hms_string(epoch_elapsed)}
# Epoch 351, gen loss=4.9733405113220215,disc loss=0.3659839630126953, {hms_string(epoch_elapsed)}
# Epoch 352, gen loss=5.0171027183532715,disc loss=0.35152706503868103, {hms_string(epoch_elapsed)}
# Epoch 353, gen loss=5.064813137054443,disc loss=0.35450318455696106, {hms_string(epoch_elapsed)}
# Epoch 354, gen loss=5.053070068359375,disc loss=0.37274351716041565, {hms_string(epoch_elapsed)}
# Epoch 355, gen loss=4.987170219421387,disc loss=0.38251793384552, {hms_string(epoch_elapsed)}
# Epoch 356, gen loss=4.953358173370361,disc loss=0.37111321091651917, {hms_string(epoch_elapsed)}
# Epoch 357, gen loss=5.043676853179932,disc loss=0.3459479808807373, {hms_string(epoch_elapsed)}
# Epoch 358, gen loss=4.984048366546631,disc loss=0.34121736884117126, {hms_string(epoch_elapsed)}
# Epoch 359, gen loss=4.915440559387207,disc loss=0.39517879486083984, {hms_string(epoch_elapsed)}
# Epoch 360, gen loss=5.147397518157959,disc loss=0.33929964900016785, {hms_string(epoch_elapsed)}
# Epoch 361, gen loss=5.047657489776611,disc loss=0.3558894991874695, {hms_string(epoch_elapsed)}
# Epoch 362, gen loss=5.018768310546875,disc loss=0.37536972761154175, {hms_string(epoch_elapsed)}
# Epoch 363, gen loss=5.146574974060059,disc loss=0.3568435609340668, {hms_string(epoch_elapsed)}
# Epoch 364, gen loss=5.107899188995361,disc loss=0.3670383393764496, {hms_string(epoch_elapsed)}
# Epoch 365, gen loss=5.107448101043701,disc loss=0.35164299607276917, {hms_string(epoch_elapsed)}
# Epoch 366, gen loss=5.2106757164001465,disc loss=0.30864933133125305, {hms_string(epoch_elapsed)}
# Epoch 367, gen loss=5.2049560546875,disc loss=0.33214399218559265, {hms_string(epoch_elapsed)}
# Epoch 368, gen loss=5.19201135635376,disc loss=0.3354528546333313, {hms_string(epoch_elapsed)}
# Epoch 369, gen loss=5.2443647384643555,disc loss=0.3835064172744751, {hms_string(epoch_elapsed)}
# Epoch 370, gen loss=5.048220157623291,disc loss=0.34125757217407227, {hms_string(epoch_elapsed)}
# Epoch 371, gen loss=5.1221795082092285,disc loss=0.34689345955848694, {hms_string(epoch_elapsed)}
# Epoch 372, gen loss=5.155458927154541,disc loss=0.3477077782154083, {hms_string(epoch_elapsed)}
# Epoch 373, gen loss=5.273077011108398,disc loss=0.3718976676464081, {hms_string(epoch_elapsed)}
# Epoch 374, gen loss=5.252570629119873,disc loss=0.3435532748699188, {hms_string(epoch_elapsed)}
# Epoch 375, gen loss=5.210580348968506,disc loss=0.3325304687023163, {hms_string(epoch_elapsed)}
# Epoch 376, gen loss=5.187020778656006,disc loss=0.3682817816734314, {hms_string(epoch_elapsed)}
# Epoch 377, gen loss=5.243368148803711,disc loss=0.3372979760169983, {hms_string(epoch_elapsed)}
# Epoch 378, gen loss=5.0806779861450195,disc loss=0.36602726578712463, {hms_string(epoch_elapsed)}
# Epoch 379, gen loss=5.29814338684082,disc loss=0.3229929208755493, {hms_string(epoch_elapsed)}
# Epoch 380, gen loss=5.285259246826172,disc loss=0.34976327419281006, {hms_string(epoch_elapsed)}
# Epoch 381, gen loss=5.35233736038208,disc loss=0.3499414324760437, {hms_string(epoch_elapsed)}
# Epoch 382, gen loss=5.3593926429748535,disc loss=0.3175121247768402, {hms_string(epoch_elapsed)}
# Epoch 383, gen loss=5.242530822753906,disc loss=0.31782400608062744, {hms_string(epoch_elapsed)}
# Epoch 384, gen loss=5.329925537109375,disc loss=0.3231349587440491, {hms_string(epoch_elapsed)}
# Epoch 385, gen loss=5.325758934020996,disc loss=0.32019752264022827, {hms_string(epoch_elapsed)}
# Epoch 386, gen loss=5.3878068923950195,disc loss=0.34511297941207886, {hms_string(epoch_elapsed)}
# Epoch 387, gen loss=5.267952919006348,disc loss=0.3365650177001953, {hms_string(epoch_elapsed)}
# Epoch 388, gen loss=5.2544074058532715,disc loss=0.36218714714050293, {hms_string(epoch_elapsed)}
# Epoch 389, gen loss=5.437135219573975,disc loss=0.33334532380104065, {hms_string(epoch_elapsed)}
# Epoch 390, gen loss=5.4229559898376465,disc loss=0.34047359228134155, {hms_string(epoch_elapsed)}
# Epoch 391, gen loss=5.246072769165039,disc loss=0.34968098998069763, {hms_string(epoch_elapsed)}
# Epoch 392, gen loss=5.272040367126465,disc loss=0.32165107131004333, {hms_string(epoch_elapsed)}
# Epoch 393, gen loss=5.5599045753479,disc loss=0.2858158051967621, {hms_string(epoch_elapsed)}
# Epoch 394, gen loss=5.273959636688232,disc loss=0.3202626705169678, {hms_string(epoch_elapsed)}
# Epoch 395, gen loss=5.417148113250732,disc loss=0.32118546962738037, {hms_string(epoch_elapsed)}
# Epoch 396, gen loss=5.313933849334717,disc loss=0.35865864157676697, {hms_string(epoch_elapsed)}
# Epoch 397, gen loss=5.495626926422119,disc loss=0.3066672384738922, {hms_string(epoch_elapsed)}
# Epoch 398, gen loss=5.546394348144531,disc loss=0.3130137324333191, {hms_string(epoch_elapsed)}
# Epoch 399, gen loss=5.430387496948242,disc loss=0.33235639333724976, {hms_string(epoch_elapsed)}
# Epoch 400, gen loss=5.315498352050781,disc loss=0.33590471744537354, {hms_string(epoch_elapsed)}
# Epoch 401, gen loss=5.3519697189331055,disc loss=0.38625749945640564, {hms_string(epoch_elapsed)}
# Epoch 402, gen loss=5.3225531578063965,disc loss=0.3347770869731903, {hms_string(epoch_elapsed)}
# Epoch 403, gen loss=5.503950595855713,disc loss=0.3101654350757599, {hms_string(epoch_elapsed)}
# Epoch 404, gen loss=5.42154598236084,disc loss=0.3496343493461609, {hms_string(epoch_elapsed)}
# Epoch 405, gen loss=5.387209892272949,disc loss=0.3822963237762451, {hms_string(epoch_elapsed)}
# Epoch 406, gen loss=5.4330854415893555,disc loss=0.3119565546512604, {hms_string(epoch_elapsed)}
# Epoch 407, gen loss=5.2922043800354,disc loss=0.3671865165233612, {hms_string(epoch_elapsed)}
# Epoch 408, gen loss=5.544874668121338,disc loss=0.28851351141929626, {hms_string(epoch_elapsed)}
# Epoch 409, gen loss=5.44450569152832,disc loss=0.30848488211631775, {hms_string(epoch_elapsed)}
# Epoch 410, gen loss=5.646425724029541,disc loss=0.32179197669029236, {hms_string(epoch_elapsed)}
# Epoch 411, gen loss=5.504061222076416,disc loss=0.3157198429107666, {hms_string(epoch_elapsed)}
# Epoch 412, gen loss=5.451915264129639,disc loss=0.2991153299808502, {hms_string(epoch_elapsed)}
# Epoch 413, gen loss=5.444907188415527,disc loss=0.2964862585067749, {hms_string(epoch_elapsed)}
# Epoch 414, gen loss=5.433367729187012,disc loss=0.3164544105529785, {hms_string(epoch_elapsed)}
# Epoch 415, gen loss=5.489840030670166,disc loss=0.2902970612049103, {hms_string(epoch_elapsed)}
# Epoch 416, gen loss=5.571533203125,disc loss=0.3217378854751587, {hms_string(epoch_elapsed)}
# Epoch 417, gen loss=5.564021587371826,disc loss=0.3045724928379059, {hms_string(epoch_elapsed)}
# Epoch 418, gen loss=5.4365692138671875,disc loss=0.32314300537109375, {hms_string(epoch_elapsed)}
# Epoch 419, gen loss=5.440136432647705,disc loss=0.31095466017723083, {hms_string(epoch_elapsed)}
# Epoch 420, gen loss=5.554573059082031,disc loss=0.3148897886276245, {hms_string(epoch_elapsed)}
# Epoch 421, gen loss=5.65030574798584,disc loss=0.321633905172348, {hms_string(epoch_elapsed)}
# Epoch 422, gen loss=5.576872825622559,disc loss=0.3141995370388031, {hms_string(epoch_elapsed)}
# Epoch 423, gen loss=5.759598255157471,disc loss=0.31352499127388, {hms_string(epoch_elapsed)}
# Epoch 424, gen loss=5.539886474609375,disc loss=0.3156249225139618, {hms_string(epoch_elapsed)}
# Epoch 425, gen loss=5.5903000831604,disc loss=0.3209734559059143, {hms_string(epoch_elapsed)}
# Epoch 426, gen loss=5.5912041664123535,disc loss=0.32242122292518616, {hms_string(epoch_elapsed)}
# Epoch 427, gen loss=5.570516586303711,disc loss=0.30020028352737427, {hms_string(epoch_elapsed)}
# Epoch 428, gen loss=5.539872169494629,disc loss=0.3110915720462799, {hms_string(epoch_elapsed)}
# Epoch 429, gen loss=5.674652099609375,disc loss=0.3256102502346039, {hms_string(epoch_elapsed)}
# Epoch 430, gen loss=5.512735366821289,disc loss=0.30911868810653687, {hms_string(epoch_elapsed)}
# Epoch 431, gen loss=5.704541206359863,disc loss=0.275226891040802, {hms_string(epoch_elapsed)}
# Epoch 432, gen loss=5.683475971221924,disc loss=0.3435307443141937, {hms_string(epoch_elapsed)}
# Epoch 433, gen loss=5.5953192710876465,disc loss=0.33909937739372253, {hms_string(epoch_elapsed)}
# Epoch 434, gen loss=5.665191650390625,disc loss=0.32551395893096924, {hms_string(epoch_elapsed)}
# Epoch 435, gen loss=5.580010890960693,disc loss=0.2978275418281555, {hms_string(epoch_elapsed)}
# Epoch 436, gen loss=5.654983997344971,disc loss=0.3012849986553192, {hms_string(epoch_elapsed)}
# Epoch 437, gen loss=5.70193338394165,disc loss=0.322243869304657, {hms_string(epoch_elapsed)}
# Epoch 438, gen loss=5.6945343017578125,disc loss=0.28297653794288635, {hms_string(epoch_elapsed)}
# Epoch 439, gen loss=5.600811958312988,disc loss=0.308590829372406, {hms_string(epoch_elapsed)}
# Epoch 440, gen loss=5.75545072555542,disc loss=0.3123553693294525, {hms_string(epoch_elapsed)}
# Epoch 441, gen loss=5.6686248779296875,disc loss=0.27260810136795044, {hms_string(epoch_elapsed)}
# Epoch 442, gen loss=5.693347454071045,disc loss=0.3025866150856018, {hms_string(epoch_elapsed)}
# Epoch 443, gen loss=5.637359619140625,disc loss=0.31862470507621765, {hms_string(epoch_elapsed)}
# Epoch 444, gen loss=5.643191337585449,disc loss=0.2933152914047241, {hms_string(epoch_elapsed)}
# Epoch 445, gen loss=5.691156387329102,disc loss=0.30629223585128784, {hms_string(epoch_elapsed)}
# Epoch 446, gen loss=5.724874019622803,disc loss=0.2802477478981018, {hms_string(epoch_elapsed)}
# Epoch 447, gen loss=5.8215413093566895,disc loss=0.26092779636383057, {hms_string(epoch_elapsed)}
# Epoch 448, gen loss=5.689791679382324,disc loss=0.2937130630016327, {hms_string(epoch_elapsed)}
# Epoch 449, gen loss=5.9175333976745605,disc loss=0.28057780861854553, {hms_string(epoch_elapsed)}
# Epoch 450, gen loss=5.885976314544678,disc loss=0.3146243691444397, {hms_string(epoch_elapsed)}
# Epoch 451, gen loss=5.765749454498291,disc loss=0.2746635377407074, {hms_string(epoch_elapsed)}
# Epoch 452, gen loss=5.89638090133667,disc loss=0.3010462522506714, {hms_string(epoch_elapsed)}
# Epoch 453, gen loss=5.837234973907471,disc loss=0.27797043323516846, {hms_string(epoch_elapsed)}
# Epoch 454, gen loss=5.8443403244018555,disc loss=0.3105381727218628, {hms_string(epoch_elapsed)}
# Epoch 455, gen loss=5.777259349822998,disc loss=0.28073710203170776, {hms_string(epoch_elapsed)}
# Epoch 456, gen loss=5.802351951599121,disc loss=0.2930073142051697, {hms_string(epoch_elapsed)}
# Epoch 457, gen loss=5.817397117614746,disc loss=0.28966277837753296, {hms_string(epoch_elapsed)}
# Epoch 458, gen loss=5.807850360870361,disc loss=0.30524152517318726, {hms_string(epoch_elapsed)}
# Epoch 459, gen loss=5.855892181396484,disc loss=0.29338499903678894, {hms_string(epoch_elapsed)}
# Epoch 460, gen loss=5.8889079093933105,disc loss=0.30093276500701904, {hms_string(epoch_elapsed)}
# Epoch 461, gen loss=5.9297614097595215,disc loss=0.28513386845588684, {hms_string(epoch_elapsed)}
# Epoch 462, gen loss=5.958962917327881,disc loss=0.2867424786090851, {hms_string(epoch_elapsed)}
# Epoch 463, gen loss=5.9202656745910645,disc loss=0.26640570163726807, {hms_string(epoch_elapsed)}
# Epoch 464, gen loss=5.934256076812744,disc loss=0.2644498348236084, {hms_string(epoch_elapsed)}
# Epoch 465, gen loss=5.839117527008057,disc loss=0.2954358458518982, {hms_string(epoch_elapsed)}
# Epoch 466, gen loss=5.876286506652832,disc loss=0.3075781762599945, {hms_string(epoch_elapsed)}
# Epoch 467, gen loss=6.096280097961426,disc loss=0.27010756731033325, {hms_string(epoch_elapsed)}
# Epoch 468, gen loss=6.027567386627197,disc loss=0.28339794278144836, {hms_string(epoch_elapsed)}
# Epoch 469, gen loss=5.901913166046143,disc loss=0.2930919826030731, {hms_string(epoch_elapsed)}
# Epoch 470, gen loss=5.894301414489746,disc loss=0.2878279983997345, {hms_string(epoch_elapsed)}
# Epoch 471, gen loss=6.009924411773682,disc loss=0.27175548672676086, {hms_string(epoch_elapsed)}
# Epoch 472, gen loss=5.873476982116699,disc loss=0.27959007024765015, {hms_string(epoch_elapsed)}
# Epoch 473, gen loss=5.912163734436035,disc loss=0.27530911564826965, {hms_string(epoch_elapsed)}
# Epoch 474, gen loss=5.8719940185546875,disc loss=0.3148159086704254, {hms_string(epoch_elapsed)}
# Epoch 475, gen loss=5.986361026763916,disc loss=0.29261207580566406, {hms_string(epoch_elapsed)}
# Epoch 476, gen loss=5.908120155334473,disc loss=0.26332715153694153, {hms_string(epoch_elapsed)}
# Epoch 477, gen loss=5.982283115386963,disc loss=0.2709992825984955, {hms_string(epoch_elapsed)}
# Epoch 478, gen loss=5.965452194213867,disc loss=0.2967260777950287, {hms_string(epoch_elapsed)}
# Epoch 479, gen loss=5.90607213973999,disc loss=0.2594550549983978, {hms_string(epoch_elapsed)}
# Epoch 480, gen loss=5.967906951904297,disc loss=0.2592886686325073, {hms_string(epoch_elapsed)}
# Epoch 481, gen loss=5.943900108337402,disc loss=0.3058440685272217, {hms_string(epoch_elapsed)}
# Epoch 482, gen loss=5.978530406951904,disc loss=0.30105751752853394, {hms_string(epoch_elapsed)}
# Epoch 483, gen loss=6.090335845947266,disc loss=0.2782006561756134, {hms_string(epoch_elapsed)}
# Epoch 484, gen loss=5.953649044036865,disc loss=0.29304787516593933, {hms_string(epoch_elapsed)}
# Epoch 485, gen loss=6.054217338562012,disc loss=0.3026302456855774, {hms_string(epoch_elapsed)}
# Epoch 486, gen loss=6.101678848266602,disc loss=0.276554137468338, {hms_string(epoch_elapsed)}
# Epoch 487, gen loss=5.938334941864014,disc loss=0.2724674344062805, {hms_string(epoch_elapsed)}
# Epoch 488, gen loss=5.981497764587402,disc loss=0.24565331637859344, {hms_string(epoch_elapsed)}
# Epoch 489, gen loss=6.009074687957764,disc loss=0.29260143637657166, {hms_string(epoch_elapsed)}
# Epoch 490, gen loss=5.977915287017822,disc loss=0.27600714564323425, {hms_string(epoch_elapsed)}
# Epoch 491, gen loss=6.068377494812012,disc loss=0.3045486807823181, {hms_string(epoch_elapsed)}
# Epoch 492, gen loss=5.962036609649658,disc loss=0.26951801776885986, {hms_string(epoch_elapsed)}
# Epoch 493, gen loss=6.111303329467773,disc loss=0.30519673228263855, {hms_string(epoch_elapsed)}
# Epoch 494, gen loss=6.169513702392578,disc loss=0.28710684180259705, {hms_string(epoch_elapsed)}
# Epoch 495, gen loss=6.061205863952637,disc loss=0.25252944231033325, {hms_string(epoch_elapsed)}
# Epoch 496, gen loss=6.0759077072143555,disc loss=0.2831248342990875, {hms_string(epoch_elapsed)}
# Epoch 497, gen loss=6.086546421051025,disc loss=0.2544574439525604, {hms_string(epoch_elapsed)}
# Epoch 498, gen loss=6.014014720916748,disc loss=0.3101155459880829, {hms_string(epoch_elapsed)}
# Epoch 499, gen loss=6.17879056930542,disc loss=0.2630442678928375, {hms_string(epoch_elapsed)}
# ...
# Epoch 836, gen loss=7.9811296463012695,disc loss=0.17990991473197937, {hms_string(epoch_elapsed)}
# Epoch 837, gen loss=7.8198747634887695,disc loss=0.19598768651485443, {hms_string(epoch_elapsed)}
# Epoch 838, gen loss=7.81880521774292,disc loss=0.16349926590919495, {hms_string(epoch_elapsed)}
# Epoch 839, gen loss=7.875906944274902,disc loss=0.17790277302265167, {hms_string(epoch_elapsed)}
# Epoch 840, gen loss=7.84221076965332,disc loss=0.18090514838695526, {hms_string(epoch_elapsed)}
# Epoch 841, gen loss=7.869734287261963,disc loss=0.1576031744480133, {hms_string(epoch_elapsed)}
# Epoch 842, gen loss=7.9575910568237305,disc loss=0.201804056763649, {hms_string(epoch_elapsed)}
# Epoch 843, gen loss=8.03110408782959,disc loss=0.1756536066532135, {hms_string(epoch_elapsed)}
# Epoch 844, gen loss=7.705670356750488,disc loss=0.18932780623435974, {hms_string(epoch_elapsed)}
# Epoch 845, gen loss=7.995652198791504,disc loss=0.1593245565891266, {hms_string(epoch_elapsed)}
# Epoch 846, gen loss=7.917344570159912,disc loss=0.1601329892873764, {hms_string(epoch_elapsed)}
# Epoch 847, gen loss=8.118220329284668,disc loss=0.1812722384929657, {hms_string(epoch_elapsed)}
# Epoch 848, gen loss=7.9316534996032715,disc loss=0.1971190869808197, {hms_string(epoch_elapsed)}
# Epoch 849, gen loss=7.857076644897461,disc loss=0.18826527893543243, {hms_string(epoch_elapsed)}
# Epoch 850, gen loss=8.145322799682617,disc loss=0.15625792741775513, {hms_string(epoch_elapsed)}
# Epoch 851, gen loss=8.080962181091309,disc loss=0.17554472386837006, {hms_string(epoch_elapsed)}
# Epoch 852, gen loss=7.838743209838867,disc loss=0.19726017117500305, {hms_string(epoch_elapsed)}
# Epoch 853, gen loss=8.013496398925781,disc loss=0.19074444472789764, {hms_string(epoch_elapsed)}
# Epoch 854, gen loss=7.887127876281738,disc loss=0.16816525161266327, {hms_string(epoch_elapsed)}
# Epoch 855, gen loss=8.074911117553711,disc loss=0.16450896859169006, {hms_string(epoch_elapsed)}
# Epoch 856, gen loss=8.120346069335938,disc loss=0.16473166644573212, {hms_string(epoch_elapsed)}
# Epoch 857, gen loss=8.030665397644043,disc loss=0.16533556580543518, {hms_string(epoch_elapsed)}
# Epoch 858, gen loss=8.011412620544434,disc loss=0.1844838261604309, {hms_string(epoch_elapsed)}
# Epoch 859, gen loss=7.890614032745361,disc loss=0.17886404693126678, {hms_string(epoch_elapsed)}
# Epoch 860, gen loss=7.97119140625,disc loss=0.2303900271654129, {hms_string(epoch_elapsed)}
# Epoch 861, gen loss=8.043708801269531,disc loss=0.17520791292190552, {hms_string(epoch_elapsed)}
# Epoch 862, gen loss=7.83256196975708,disc loss=0.18211200833320618, {hms_string(epoch_elapsed)}
# Epoch 863, gen loss=8.023056983947754,disc loss=0.19340983033180237, {hms_string(epoch_elapsed)}
# Epoch 864, gen loss=8.093082427978516,disc loss=0.17454558610916138, {hms_string(epoch_elapsed)}
# Epoch 865, gen loss=8.053303718566895,disc loss=0.1977362334728241, {hms_string(epoch_elapsed)}
# Epoch 866, gen loss=7.925720691680908,disc loss=0.19598053395748138, {hms_string(epoch_elapsed)}
# Epoch 867, gen loss=7.990098476409912,disc loss=0.20195485651493073, {hms_string(epoch_elapsed)}
# Epoch 868, gen loss=7.9481587409973145,disc loss=0.18997973203659058, {hms_string(epoch_elapsed)}
# Epoch 869, gen loss=8.039130210876465,disc loss=0.18770572543144226, {hms_string(epoch_elapsed)}
# Epoch 870, gen loss=8.01687240600586,disc loss=0.17597143352031708, {hms_string(epoch_elapsed)}
# Epoch 871, gen loss=7.931140422821045,disc loss=0.18877820670604706, {hms_string(epoch_elapsed)}
# Epoch 872, gen loss=8.326485633850098,disc loss=0.14046473801136017, {hms_string(epoch_elapsed)}
# Epoch 873, gen loss=7.918890953063965,disc loss=0.23363864421844482, {hms_string(epoch_elapsed)}
# Epoch 874, gen loss=8.11782169342041,disc loss=0.19265422224998474, {hms_string(epoch_elapsed)}
# Epoch 875, gen loss=8.107880592346191,disc loss=0.15533603727817535, {hms_string(epoch_elapsed)}
# Epoch 876, gen loss=8.103116035461426,disc loss=0.1679782271385193, {hms_string(epoch_elapsed)}
# Epoch 877, gen loss=7.964120388031006,disc loss=0.20069073140621185, {hms_string(epoch_elapsed)}
# Epoch 878, gen loss=7.9869513511657715,disc loss=0.15443220734596252, {hms_string(epoch_elapsed)}
# Epoch 879, gen loss=8.005017280578613,disc loss=0.17414391040802002, {hms_string(epoch_elapsed)}
# Epoch 880, gen loss=8.068668365478516,disc loss=0.16871999204158783, {hms_string(epoch_elapsed)}
# Epoch 881, gen loss=8.234496116638184,disc loss=0.17454861104488373, {hms_string(epoch_elapsed)}
# Epoch 882, gen loss=8.112245559692383,disc loss=0.2005177140235901, {hms_string(epoch_elapsed)}
# Epoch 883, gen loss=8.067146301269531,disc loss=0.17729099094867706, {hms_string(epoch_elapsed)}
# Epoch 884, gen loss=8.013318061828613,disc loss=0.17993563413619995, {hms_string(epoch_elapsed)}
# Epoch 885, gen loss=8.238727569580078,disc loss=0.16919928789138794, {hms_string(epoch_elapsed)}
# Epoch 886, gen loss=8.198315620422363,disc loss=0.18328160047531128, {hms_string(epoch_elapsed)}
# Epoch 887, gen loss=8.234997749328613,disc loss=0.17907632887363434, {hms_string(epoch_elapsed)}
# Epoch 888, gen loss=8.149876594543457,disc loss=0.16650938987731934, {hms_string(epoch_elapsed)}
# Epoch 889, gen loss=8.052796363830566,disc loss=0.18098175525665283, {hms_string(epoch_elapsed)}
# Epoch 890, gen loss=8.285797119140625,disc loss=0.14831368625164032, {hms_string(epoch_elapsed)}
# Epoch 891, gen loss=8.270151138305664,disc loss=0.1787814199924469, {hms_string(epoch_elapsed)}
# Epoch 892, gen loss=8.179094314575195,disc loss=0.15817543864250183, {hms_string(epoch_elapsed)}
# Epoch 893, gen loss=8.133342742919922,disc loss=0.17624828219413757, {hms_string(epoch_elapsed)}
# Epoch 894, gen loss=7.983705043792725,disc loss=0.1791386604309082, {hms_string(epoch_elapsed)}
# Epoch 895, gen loss=8.276963233947754,disc loss=0.1777331382036209, {hms_string(epoch_elapsed)}
# Epoch 896, gen loss=8.1646146774292,disc loss=0.19578683376312256, {hms_string(epoch_elapsed)}
# Epoch 897, gen loss=8.078417778015137,disc loss=0.1730951964855194, {hms_string(epoch_elapsed)}
# Epoch 898, gen loss=8.176477432250977,disc loss=0.15641261637210846, {hms_string(epoch_elapsed)}
# Epoch 899, gen loss=8.029510498046875,disc loss=0.16322708129882812, {hms_string(epoch_elapsed)}
# Epoch 900, gen loss=7.961828708648682,disc loss=0.19220878183841705, {hms_string(epoch_elapsed)}
# Epoch 901, gen loss=7.922232151031494,disc loss=0.17626774311065674, {hms_string(epoch_elapsed)}
# Epoch 902, gen loss=8.236333847045898,disc loss=0.218510702252388, {hms_string(epoch_elapsed)}
# Epoch 903, gen loss=7.930004119873047,disc loss=0.20105494558811188, {hms_string(epoch_elapsed)}
# Epoch 904, gen loss=8.027254104614258,disc loss=0.1637752205133438, {hms_string(epoch_elapsed)}
# Epoch 905, gen loss=7.957037448883057,disc loss=0.17315416038036346, {hms_string(epoch_elapsed)}
# Epoch 906, gen loss=8.32183837890625,disc loss=0.1695978194475174, {hms_string(epoch_elapsed)}
# Epoch 907, gen loss=8.104329109191895,disc loss=0.15448345243930817, {hms_string(epoch_elapsed)}
# Epoch 908, gen loss=8.317109107971191,disc loss=0.18026715517044067, {hms_string(epoch_elapsed)}
# Epoch 909, gen loss=8.134575843811035,disc loss=0.17822569608688354, {hms_string(epoch_elapsed)}
# Epoch 910, gen loss=8.1705961227417,disc loss=0.1509830504655838, {hms_string(epoch_elapsed)}
# Epoch 911, gen loss=8.136513710021973,disc loss=0.1597852110862732, {hms_string(epoch_elapsed)}
# Epoch 912, gen loss=8.17131233215332,disc loss=0.14875558018684387, {hms_string(epoch_elapsed)}
# Epoch 913, gen loss=8.169129371643066,disc loss=0.1893247663974762, {hms_string(epoch_elapsed)}
# Epoch 914, gen loss=8.090922355651855,disc loss=0.1811637580394745, {hms_string(epoch_elapsed)}
# Epoch 915, gen loss=8.045522689819336,disc loss=0.16692858934402466, {hms_string(epoch_elapsed)}
# Epoch 916, gen loss=7.9426350593566895,disc loss=0.17815259099006653, {hms_string(epoch_elapsed)}
# Epoch 917, gen loss=8.280508041381836,disc loss=0.18023918569087982, {hms_string(epoch_elapsed)}
# Epoch 918, gen loss=8.312087059020996,disc loss=0.17635983228683472, {hms_string(epoch_elapsed)}
# Epoch 919, gen loss=8.256815910339355,disc loss=0.17257358133792877, {hms_string(epoch_elapsed)}
# Epoch 920, gen loss=8.098823547363281,disc loss=0.20668452978134155, {hms_string(epoch_elapsed)}
# Epoch 921, gen loss=8.2159423828125,disc loss=0.21694321930408478, {hms_string(epoch_elapsed)}
# Epoch 922, gen loss=8.067364692687988,disc loss=0.19130957126617432, {hms_string(epoch_elapsed)}
# Epoch 923, gen loss=8.114232063293457,disc loss=0.19706518948078156, {hms_string(epoch_elapsed)}
# Epoch 924, gen loss=8.316937446594238,disc loss=0.16580477356910706, {hms_string(epoch_elapsed)}
# Epoch 925, gen loss=8.082045555114746,disc loss=0.17939262092113495, {hms_string(epoch_elapsed)}
# Epoch 926, gen loss=8.133338928222656,disc loss=0.16227588057518005, {hms_string(epoch_elapsed)}
# Epoch 927, gen loss=8.106480598449707,disc loss=0.16955320537090302, {hms_string(epoch_elapsed)}
# Epoch 928, gen loss=8.152284622192383,disc loss=0.16202303767204285, {hms_string(epoch_elapsed)}
# Epoch 929, gen loss=8.10832405090332,disc loss=0.19637057185173035, {hms_string(epoch_elapsed)}
# Epoch 930, gen loss=8.157214164733887,disc loss=0.18059179186820984, {hms_string(epoch_elapsed)}
# Epoch 931, gen loss=8.174656867980957,disc loss=0.15705987811088562, {hms_string(epoch_elapsed)}
# Epoch 932, gen loss=8.112326622009277,disc loss=0.15990237891674042, {hms_string(epoch_elapsed)}
# Epoch 933, gen loss=8.225423812866211,disc loss=0.18063531816005707, {hms_string(epoch_elapsed)}
# Epoch 934, gen loss=8.244929313659668,disc loss=0.17871056497097015, {hms_string(epoch_elapsed)}
# Epoch 935, gen loss=8.296814918518066,disc loss=0.17179164290428162, {hms_string(epoch_elapsed)}
# Epoch 936, gen loss=8.351341247558594,disc loss=0.1671779900789261, {hms_string(epoch_elapsed)}
# Epoch 937, gen loss=8.140046119689941,disc loss=0.18819241225719452, {hms_string(epoch_elapsed)}
# Epoch 938, gen loss=8.466358184814453,disc loss=0.1461217701435089, {hms_string(epoch_elapsed)}
# Epoch 939, gen loss=8.174750328063965,disc loss=0.16585826873779297, {hms_string(epoch_elapsed)}
# Epoch 940, gen loss=8.30943489074707,disc loss=0.18554262816905975, {hms_string(epoch_elapsed)}
# Epoch 941, gen loss=8.2041597366333,disc loss=0.1764483004808426, {hms_string(epoch_elapsed)}
# Epoch 942, gen loss=7.983402252197266,disc loss=0.16251859068870544, {hms_string(epoch_elapsed)}
# Epoch 943, gen loss=8.438187599182129,disc loss=0.18822087347507477, {hms_string(epoch_elapsed)}
# Epoch 944, gen loss=8.242629051208496,disc loss=0.19006779789924622, {hms_string(epoch_elapsed)}
# Epoch 945, gen loss=8.260819435119629,disc loss=0.17345064878463745, {hms_string(epoch_elapsed)}
# Epoch 946, gen loss=8.39600944519043,disc loss=0.1297496110200882, {hms_string(epoch_elapsed)}
# Epoch 947, gen loss=8.452533721923828,disc loss=0.19152231514453888, {hms_string(epoch_elapsed)}
# Epoch 948, gen loss=8.219071388244629,disc loss=0.19254754483699799, {hms_string(epoch_elapsed)}
# Epoch 949, gen loss=8.225915908813477,disc loss=0.16574925184249878, {hms_string(epoch_elapsed)}
# Epoch 950, gen loss=8.498852729797363,disc loss=0.17216672003269196, {hms_string(epoch_elapsed)}
# Epoch 951, gen loss=8.27304744720459,disc loss=0.1934688240289688, {hms_string(epoch_elapsed)}
# Epoch 952, gen loss=8.144208908081055,disc loss=0.16470356285572052, {hms_string(epoch_elapsed)}
# Epoch 953, gen loss=8.227924346923828,disc loss=0.15563306212425232, {hms_string(epoch_elapsed)}
# Epoch 954, gen loss=8.539528846740723,disc loss=0.15947610139846802, {hms_string(epoch_elapsed)}
# Epoch 955, gen loss=8.36155891418457,disc loss=0.17121300101280212, {hms_string(epoch_elapsed)}
# Epoch 956, gen loss=8.305431365966797,disc loss=0.19461144506931305, {hms_string(epoch_elapsed)}
# Epoch 957, gen loss=8.392541885375977,disc loss=0.17925085127353668, {hms_string(epoch_elapsed)}
# Epoch 958, gen loss=8.1163330078125,disc loss=0.15681682527065277, {hms_string(epoch_elapsed)}
# Epoch 959, gen loss=8.202767372131348,disc loss=0.16389307379722595, {hms_string(epoch_elapsed)}
# Epoch 960, gen loss=8.238396644592285,disc loss=0.16237479448318481, {hms_string(epoch_elapsed)}
# Epoch 961, gen loss=8.35378360748291,disc loss=0.1826043576002121, {hms_string(epoch_elapsed)}
# Epoch 962, gen loss=8.438155174255371,disc loss=0.14894770085811615, {hms_string(epoch_elapsed)}
# Epoch 963, gen loss=8.469740867614746,disc loss=0.1589880734682083, {hms_string(epoch_elapsed)}
# Epoch 964, gen loss=8.349276542663574,disc loss=0.16808757185935974, {hms_string(epoch_elapsed)}
# Epoch 965, gen loss=8.274020195007324,disc loss=0.1821267157793045, {hms_string(epoch_elapsed)}
# Epoch 966, gen loss=8.39810562133789,disc loss=0.15442810952663422, {hms_string(epoch_elapsed)}
# Epoch 967, gen loss=8.56903076171875,disc loss=0.1566302329301834, {hms_string(epoch_elapsed)}
# Epoch 968, gen loss=8.324487686157227,disc loss=0.16254736483097076, {hms_string(epoch_elapsed)}
# Epoch 969, gen loss=8.476651191711426,disc loss=0.1648058295249939, {hms_string(epoch_elapsed)}
# Epoch 970, gen loss=8.358319282531738,disc loss=0.17594704031944275, {hms_string(epoch_elapsed)}
# Epoch 971, gen loss=8.292560577392578,disc loss=0.17402887344360352, {hms_string(epoch_elapsed)}
# Epoch 972, gen loss=8.405735969543457,disc loss=0.2056586593389511, {hms_string(epoch_elapsed)}
# Epoch 973, gen loss=8.462753295898438,disc loss=0.18862853944301605, {hms_string(epoch_elapsed)}
# Epoch 974, gen loss=8.31566047668457,disc loss=0.15599042177200317, {hms_string(epoch_elapsed)}
# Epoch 975, gen loss=8.449450492858887,disc loss=0.18109636008739471, {hms_string(epoch_elapsed)}
# Epoch 976, gen loss=8.434612274169922,disc loss=0.19187942147254944, {hms_string(epoch_elapsed)}
# Epoch 977, gen loss=8.497331619262695,disc loss=0.19131186604499817, {hms_string(epoch_elapsed)}
# Epoch 978, gen loss=8.243810653686523,disc loss=0.16252271831035614, {hms_string(epoch_elapsed)}
# Epoch 979, gen loss=8.398026466369629,disc loss=0.16779959201812744, {hms_string(epoch_elapsed)}
# Epoch 980, gen loss=8.468619346618652,disc loss=0.17258983850479126, {hms_string(epoch_elapsed)}
# Epoch 981, gen loss=8.597225189208984,disc loss=0.16709792613983154, {hms_string(epoch_elapsed)}
# Epoch 982, gen loss=8.282909393310547,disc loss=0.19442635774612427, {hms_string(epoch_elapsed)}
# Epoch 983, gen loss=8.35728645324707,disc loss=0.1681489646434784, {hms_string(epoch_elapsed)}
# Epoch 984, gen loss=8.640620231628418,disc loss=0.14213509857654572, {hms_string(epoch_elapsed)}
# Epoch 985, gen loss=8.483713150024414,disc loss=0.14655537903308868, {hms_string(epoch_elapsed)}
# Epoch 986, gen loss=8.33233642578125,disc loss=0.16256500780582428, {hms_string(epoch_elapsed)}
# Epoch 987, gen loss=8.32041072845459,disc loss=0.19234371185302734, {hms_string(epoch_elapsed)}
# Epoch 988, gen loss=8.651822090148926,disc loss=0.17155152559280396, {hms_string(epoch_elapsed)}
# Epoch 989, gen loss=8.455896377563477,disc loss=0.15926282107830048, {hms_string(epoch_elapsed)}
# Epoch 990, gen loss=8.394268035888672,disc loss=0.16742105782032013, {hms_string(epoch_elapsed)}
# Epoch 991, gen loss=8.577617645263672,disc loss=0.17797639966011047, {hms_string(epoch_elapsed)}
# Epoch 992, gen loss=8.479751586914062,disc loss=0.18840743601322174, {hms_string(epoch_elapsed)}
# Epoch 993, gen loss=8.40710163116455,disc loss=0.14555397629737854, {hms_string(epoch_elapsed)}
# Epoch 994, gen loss=8.538599967956543,disc loss=0.16752637922763824, {hms_string(epoch_elapsed)}
# Epoch 995, gen loss=8.54765796661377,disc loss=0.1705019772052765, {hms_string(epoch_elapsed)}
# Epoch 996, gen loss=8.469978332519531,disc loss=0.17682883143424988, {hms_string(epoch_elapsed)}
# Epoch 997, gen loss=8.551767349243164,disc loss=0.15459121763706207, {hms_string(epoch_elapsed)}
# Epoch 998, gen loss=8.533533096313477,disc loss=0.16292081773281097, {hms_string(epoch_elapsed)}
# Epoch 999, gen loss=8.3588285446167,disc loss=0.14968129992485046, {hms_string(epoch_elapsed)}
# Epoch 1000, gen loss=8.804532051086426,disc loss=0.16898034512996674, {hms_string(epoch_elapsed)}
# Training time: 8453.613191604614
