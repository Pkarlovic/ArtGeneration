# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Reshape, Dropout, Dense 
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Activation, ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
import numpy as np
from PIL import Image
from tqdm import tqdm
import os 
import time
import matplotlib.pyplot as plt

# %%
GENERATE_RES = 3 # Generation resolution factor 
# (1=32, 2=64, 3=96, 4=128, etc.)
GENERATE_SQUARE = 32 * GENERATE_RES # rows/cols (should be square)
IMAGE_CHANNELS = 3

# Preview image 
PREVIEW_ROWS = 4
PREVIEW_COLS = 7
PREVIEW_MARGIN = 16

# Size vector to generate images from
SEED_SIZE = 100

# Configuration
DATA_PATH = '/content/drive/MyDrive/Bob Ross Paintings'
EPOCHS = 500
BATCH_SIZE = 32
BUFFER_SIZE = 60000

print(f"Will generate {GENERATE_SQUARE}px square images.")
# Out:
# Will generate 96px square images.

# %%
training_binary_path = os.path.join(DATA_PATH,
        f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}.npy')

print(f"Looking for file: {training_binary_path}")

if not os.path.isfile(training_binary_path):
  start = time.time()
  print("Loading training images...")

  training_data = []
  faces_path = os.path.join(DATA_PATH)
  for filename in tqdm(os.listdir(faces_path)):
      path = os.path.join(faces_path,filename)
      image = Image.open(path).resize((GENERATE_SQUARE,
            GENERATE_SQUARE),Image.ANTIALIAS)
      training_data.append(np.asarray(image))
  training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,
            GENERATE_SQUARE,IMAGE_CHANNELS))
  training_data = training_data.astype(np.float32)
  training_data = training_data / 127.5 - 1.


  print("Saving training image binary...")
  np.save(training_binary_path,training_data)
  elapsed = time.time()-start
  print (f'Image preprocess time: {hms_string(elapsed)}')
else:
  print("Loading previous training pickle...")
  training_data = np.load(training_binary_path)
# Out:
# Looking for file: /content/drive/MyDrive/Bob Ross Paintings/training_data_96_96.npy
# Loading training images...
# 100%|██████████| 403/403 [00:07<00:00, 56.20it/s]
# Saving training image binary...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e772a20664ce> in <module>()
#      24   np.save(training_binary_path,training_data)
#      25   elapsed = time.time()-start
# ---> 26   print (f'Image preprocess time: {hms_string(elapsed)}')
#      27 else:
#      28   print("Loading previous training pickle...")
#
# NameError: name 'hms_string' is not defined

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(training_data).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
 def build_generator(seed_size, channels):
    model = Sequential()

    model.add(Dense(4*4*256,activation="relu",input_dim=seed_size))
    model.add(Reshape((4,4,256)))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
   
    # Output resolution, additional upsampling
    model.add(UpSampling2D())
    model.add(Conv2D(128,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    if GENERATE_RES>1:
      model.add(UpSampling2D(size=(GENERATE_RES,GENERATE_RES)))
      model.add(Conv2D(128,kernel_size=3,padding="same"))
      model.add(BatchNormalization(momentum=0.8))
      model.add(Activation("relu"))

    # Final CNN layer
    model.add(Conv2D(channels,kernel_size=3,padding="same"))
    model.add(Activation("tanh"))

    return model


def build_discriminator(image_shape):
    model = Sequential()

    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=image_shape, 
                     padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(512, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))

    return model

# %%
def save_images(cnt,noise):
  image_array = np.full(( 
      PREVIEW_MARGIN + (PREVIEW_ROWS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 
      PREVIEW_MARGIN + (PREVIEW_COLS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 3), 
      255, dtype=np.uint8)
  
  generated_images = generator.predict(noise)

  generated_images = 0.5 * generated_images + 0.5

  image_count = 0
  for row in range(PREVIEW_ROWS):
      for col in range(PREVIEW_COLS):
        r = row * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        c = col * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        image_array[r:r+GENERATE_SQUARE,c:c+GENERATE_SQUARE] = generated_images[image_count] * 255
        image_count += 1

          
  output_path = os.path.join(DATA_PATH,'output')
  if not os.path.exists(output_path):
    os.makedirs(output_path)
  
  filename = os.path.join(output_path,f"train-{cnt}.png")
  im = Image.fromarray(image_array)
  im.save(filename)

# %%
generator = build_generator(SEED_SIZE, IMAGE_CHANNELS)

noise = tf.random.normal([1, SEED_SIZE])
generated_image = generator(noise, training=False)

plt.imshow(generated_image[0, :, :, 0])

# %%
image_shape = (GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS)

discriminator = build_discriminator(image_shape)
decision = discriminator(generated_image)
print (decision)
# Out:
# tf.Tensor([[0.5000844]], shape=(1, 1), dtype=float32)

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy()

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
generator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)

# %%
@tf.function
def train_step(images):
  seed = tf.random.normal([BATCH_SIZE, SEED_SIZE])

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator(seed, training=True)

    real_output = discriminator(images, training=True)
    fake_output = discriminator(generated_images, training=True)

    gen_loss = generator_loss(fake_output)
    disc_loss = discriminator_loss(real_output, fake_output)
    

    gradients_of_generator = gen_tape.gradient(
        gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(
        disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(
        gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(
        gradients_of_discriminator, 
        discriminator.trainable_variables))
  return gen_loss,disc_loss

# %%
def train(dataset, epochs):
  fixed_seed = np.random.normal(0, 1, (PREVIEW_ROWS * PREVIEW_COLS, 
                                       SEED_SIZE))
  start = time.time()

  for epoch in range(epochs):
    epoch_start = time.time()

    gen_loss_list = []
    disc_loss_list = []

    for image_batch in dataset:
      t = train_step(image_batch)
      gen_loss_list.append(t[0])
      disc_loss_list.append(t[1])

    g_loss = sum(gen_loss_list) / len(gen_loss_list)
    d_loss = sum(disc_loss_list) / len(disc_loss_list)

    epoch_elapsed = time.time()-epoch_start
    print (f'Epoch {epoch+1}, gen loss={g_loss},disc loss={d_loss},'
           ' {hms_string(epoch_elapsed)}')
    save_images(epoch,fixed_seed)

  elapsed = time.time()-start
  print (f'Training time: {hms_string(elapsed)}')

# %%
train(train_dataset, EPOCHS)
# Out:
# Epoch 1, gen loss=1.4142696857452393,disc loss=1.0743370056152344, {hms_string(epoch_elapsed)}
# Epoch 2, gen loss=1.6493422985076904,disc loss=1.3976117372512817, {hms_string(epoch_elapsed)}
# Epoch 3, gen loss=1.9296519756317139,disc loss=1.452407717704773, {hms_string(epoch_elapsed)}
# Epoch 4, gen loss=2.412402629852295,disc loss=1.3594129085540771, {hms_string(epoch_elapsed)}
# Epoch 5, gen loss=3.092754602432251,disc loss=1.0385349988937378, {hms_string(epoch_elapsed)}
# Epoch 6, gen loss=3.2904210090637207,disc loss=1.644095540046692, {hms_string(epoch_elapsed)}
# Epoch 7, gen loss=3.4437410831451416,disc loss=0.653386116027832, {hms_string(epoch_elapsed)}
# Epoch 8, gen loss=3.6955618858337402,disc loss=1.000331997871399, {hms_string(epoch_elapsed)}
# Epoch 9, gen loss=3.6031267642974854,disc loss=0.5892651081085205, {hms_string(epoch_elapsed)}
# Epoch 10, gen loss=4.905509948730469,disc loss=0.5715789198875427, {hms_string(epoch_elapsed)}
# Epoch 11, gen loss=2.7245748043060303,disc loss=0.9415407776832581, {hms_string(epoch_elapsed)}
# Epoch 12, gen loss=2.679826259613037,disc loss=1.039149284362793, {hms_string(epoch_elapsed)}
# Epoch 13, gen loss=2.684471368789673,disc loss=0.9610055685043335, {hms_string(epoch_elapsed)}
# Epoch 14, gen loss=3.708479881286621,disc loss=1.5840914249420166, {hms_string(epoch_elapsed)}
# Epoch 15, gen loss=3.4213948249816895,disc loss=0.48383429646492004, {hms_string(epoch_elapsed)}
# Epoch 16, gen loss=2.7663838863372803,disc loss=0.7969287633895874, {hms_string(epoch_elapsed)}
# Epoch 17, gen loss=3.602652072906494,disc loss=1.3389544486999512, {hms_string(epoch_elapsed)}
# Epoch 18, gen loss=3.040470600128174,disc loss=0.9281828999519348, {hms_string(epoch_elapsed)}
# Epoch 19, gen loss=4.874678134918213,disc loss=1.2028591632843018, {hms_string(epoch_elapsed)}
# Epoch 20, gen loss=3.274927854537964,disc loss=0.7093565464019775, {hms_string(epoch_elapsed)}
# Epoch 21, gen loss=2.609992504119873,disc loss=0.9581012725830078, {hms_string(epoch_elapsed)}
# Epoch 22, gen loss=2.2250590324401855,disc loss=1.5007283687591553, {hms_string(epoch_elapsed)}
# Epoch 23, gen loss=2.810126304626465,disc loss=1.4079787731170654, {hms_string(epoch_elapsed)}
# Epoch 24, gen loss=2.0024046897888184,disc loss=1.7258458137512207, {hms_string(epoch_elapsed)}
# Epoch 25, gen loss=2.1960644721984863,disc loss=1.399379014968872, {hms_string(epoch_elapsed)}
# Epoch 26, gen loss=2.0807690620422363,disc loss=1.2435568571090698, {hms_string(epoch_elapsed)}
# Epoch 27, gen loss=2.1434149742126465,disc loss=1.773801326751709, {hms_string(epoch_elapsed)}
# Epoch 28, gen loss=1.7191979885101318,disc loss=1.5309338569641113, {hms_string(epoch_elapsed)}
# Epoch 29, gen loss=1.6089625358581543,disc loss=1.5936814546585083, {hms_string(epoch_elapsed)}
# Epoch 30, gen loss=1.7360178232192993,disc loss=1.585986852645874, {hms_string(epoch_elapsed)}
# Epoch 31, gen loss=1.9202529191970825,disc loss=1.0325357913970947, {hms_string(epoch_elapsed)}
# Epoch 32, gen loss=1.7181265354156494,disc loss=1.3572007417678833, {hms_string(epoch_elapsed)}
# Epoch 33, gen loss=1.6673755645751953,disc loss=1.4073973894119263, {hms_string(epoch_elapsed)}
# Epoch 34, gen loss=1.6723179817199707,disc loss=1.3988454341888428, {hms_string(epoch_elapsed)}
# Epoch 35, gen loss=1.5228095054626465,disc loss=1.3011027574539185, {hms_string(epoch_elapsed)}
# Epoch 36, gen loss=1.7060920000076294,disc loss=1.300252914428711, {hms_string(epoch_elapsed)}
# Epoch 37, gen loss=1.6061803102493286,disc loss=1.0085774660110474, {hms_string(epoch_elapsed)}
# Epoch 38, gen loss=1.7851582765579224,disc loss=1.148027777671814, {hms_string(epoch_elapsed)}
# Epoch 39, gen loss=1.8459408283233643,disc loss=1.2009936571121216, {hms_string(epoch_elapsed)}
# Epoch 40, gen loss=1.7528191804885864,disc loss=1.3773844242095947, {hms_string(epoch_elapsed)}
# Epoch 41, gen loss=2.0690290927886963,disc loss=1.0728340148925781, {hms_string(epoch_elapsed)}
# Epoch 42, gen loss=2.118567943572998,disc loss=1.3085582256317139, {hms_string(epoch_elapsed)}
# Epoch 43, gen loss=2.5667648315429688,disc loss=0.9857916235923767, {hms_string(epoch_elapsed)}
# Epoch 44, gen loss=2.7037832736968994,disc loss=0.7761254906654358, {hms_string(epoch_elapsed)}
# Epoch 45, gen loss=2.1107022762298584,disc loss=1.2789725065231323, {hms_string(epoch_elapsed)}
# Epoch 46, gen loss=2.27720308303833,disc loss=1.0035372972488403, {hms_string(epoch_elapsed)}
# Epoch 47, gen loss=2.5373826026916504,disc loss=1.2129205465316772, {hms_string(epoch_elapsed)}
# Epoch 48, gen loss=2.104440212249756,disc loss=1.0859553813934326, {hms_string(epoch_elapsed)}
# Epoch 49, gen loss=2.321803092956543,disc loss=0.8076484203338623, {hms_string(epoch_elapsed)}
# Epoch 50, gen loss=2.1764612197875977,disc loss=1.199330449104309, {hms_string(epoch_elapsed)}
# Epoch 51, gen loss=1.8059877157211304,disc loss=1.378052830696106, {hms_string(epoch_elapsed)}
# Epoch 52, gen loss=2.0330018997192383,disc loss=1.4617902040481567, {hms_string(epoch_elapsed)}
# Epoch 53, gen loss=1.8096730709075928,disc loss=1.4368231296539307, {hms_string(epoch_elapsed)}
# Epoch 54, gen loss=2.2510833740234375,disc loss=1.1999455690383911, {hms_string(epoch_elapsed)}
# Epoch 55, gen loss=1.8103196620941162,disc loss=1.0626224279403687, {hms_string(epoch_elapsed)}
# Epoch 56, gen loss=1.941312313079834,disc loss=1.0866310596466064, {hms_string(epoch_elapsed)}
# Epoch 57, gen loss=1.9607460498809814,disc loss=1.365507960319519, {hms_string(epoch_elapsed)}
# Epoch 58, gen loss=1.7691773176193237,disc loss=1.3384768962860107, {hms_string(epoch_elapsed)}
# Epoch 59, gen loss=1.6427326202392578,disc loss=1.242580533027649, {hms_string(epoch_elapsed)}
# Epoch 60, gen loss=1.8650671243667603,disc loss=1.0501389503479004, {hms_string(epoch_elapsed)}
# Epoch 61, gen loss=1.7706847190856934,disc loss=1.1616947650909424, {hms_string(epoch_elapsed)}
# Epoch 62, gen loss=1.9183298349380493,disc loss=1.1347054243087769, {hms_string(epoch_elapsed)}
# Epoch 63, gen loss=2.255070924758911,disc loss=1.1117819547653198, {hms_string(epoch_elapsed)}
# Epoch 64, gen loss=2.8648934364318848,disc loss=1.271655559539795, {hms_string(epoch_elapsed)}
# Epoch 65, gen loss=3.057626485824585,disc loss=1.3545044660568237, {hms_string(epoch_elapsed)}
# Epoch 66, gen loss=1.932525634765625,disc loss=1.2154266834259033, {hms_string(epoch_elapsed)}
# Epoch 67, gen loss=2.0366528034210205,disc loss=1.179681658744812, {hms_string(epoch_elapsed)}
# Epoch 68, gen loss=1.8070811033248901,disc loss=1.2422962188720703, {hms_string(epoch_elapsed)}
# Epoch 69, gen loss=1.9484176635742188,disc loss=1.2381178140640259, {hms_string(epoch_elapsed)}
# Epoch 70, gen loss=2.05448317527771,disc loss=1.2306113243103027, {hms_string(epoch_elapsed)}
# Epoch 71, gen loss=1.858233094215393,disc loss=1.148008942604065, {hms_string(epoch_elapsed)}
# Epoch 72, gen loss=2.102776288986206,disc loss=1.2773873805999756, {hms_string(epoch_elapsed)}
# Epoch 73, gen loss=2.189040184020996,disc loss=1.0011975765228271, {hms_string(epoch_elapsed)}
# Epoch 74, gen loss=1.8350874185562134,disc loss=1.4066765308380127, {hms_string(epoch_elapsed)}
# Epoch 75, gen loss=2.1563851833343506,disc loss=1.422143816947937, {hms_string(epoch_elapsed)}
# Epoch 76, gen loss=2.00673508644104,disc loss=1.1393595933914185, {hms_string(epoch_elapsed)}
# Epoch 77, gen loss=2.2444417476654053,disc loss=1.0136866569519043, {hms_string(epoch_elapsed)}
# Epoch 78, gen loss=2.137924909591675,disc loss=1.0151243209838867, {hms_string(epoch_elapsed)}
# Epoch 79, gen loss=2.2359185218811035,disc loss=1.0007551908493042, {hms_string(epoch_elapsed)}
# Epoch 80, gen loss=1.9215501546859741,disc loss=1.1546292304992676, {hms_string(epoch_elapsed)}
# Epoch 81, gen loss=2.350313425064087,disc loss=0.8255630731582642, {hms_string(epoch_elapsed)}
# Epoch 82, gen loss=2.047086715698242,disc loss=1.0128962993621826, {hms_string(epoch_elapsed)}
# Epoch 83, gen loss=2.1030993461608887,disc loss=0.9396443963050842, {hms_string(epoch_elapsed)}
# Epoch 84, gen loss=2.3248472213745117,disc loss=0.8669312000274658, {hms_string(epoch_elapsed)}
# Epoch 85, gen loss=2.2049849033355713,disc loss=1.0309703350067139, {hms_string(epoch_elapsed)}
# Epoch 86, gen loss=2.1390573978424072,disc loss=1.0023839473724365, {hms_string(epoch_elapsed)}
# Epoch 87, gen loss=1.9925823211669922,disc loss=1.3135122060775757, {hms_string(epoch_elapsed)}
# Epoch 88, gen loss=2.0919294357299805,disc loss=1.3367403745651245, {hms_string(epoch_elapsed)}
# Epoch 89, gen loss=2.0764858722686768,disc loss=1.1484458446502686, {hms_string(epoch_elapsed)}
# Epoch 90, gen loss=1.8013741970062256,disc loss=1.2360320091247559, {hms_string(epoch_elapsed)}
# Epoch 91, gen loss=1.7784348726272583,disc loss=1.08665931224823, {hms_string(epoch_elapsed)}
# Epoch 92, gen loss=1.7849464416503906,disc loss=1.0723817348480225, {hms_string(epoch_elapsed)}
# Epoch 93, gen loss=1.8627657890319824,disc loss=1.073210597038269, {hms_string(epoch_elapsed)}
# Epoch 94, gen loss=1.9430129528045654,disc loss=1.1691524982452393, {hms_string(epoch_elapsed)}
# Epoch 95, gen loss=2.027585744857788,disc loss=1.1677113771438599, {hms_string(epoch_elapsed)}
# Epoch 96, gen loss=1.8480855226516724,disc loss=1.2744187116622925, {hms_string(epoch_elapsed)}
# Epoch 97, gen loss=1.9920897483825684,disc loss=1.1531554460525513, {hms_string(epoch_elapsed)}
# Epoch 98, gen loss=2.0122568607330322,disc loss=1.0576016902923584, {hms_string(epoch_elapsed)}
# Epoch 99, gen loss=1.8593406677246094,disc loss=1.2578004598617554, {hms_string(epoch_elapsed)}
# Epoch 100, gen loss=2.2639706134796143,disc loss=1.1869850158691406, {hms_string(epoch_elapsed)}
# Epoch 101, gen loss=2.0767481327056885,disc loss=1.049973726272583, {hms_string(epoch_elapsed)}
# Epoch 102, gen loss=1.9668896198272705,disc loss=1.3304896354675293, {hms_string(epoch_elapsed)}
# Epoch 103, gen loss=2.074953556060791,disc loss=1.0111953020095825, {hms_string(epoch_elapsed)}
# Epoch 104, gen loss=1.8790026903152466,disc loss=1.1785082817077637, {hms_string(epoch_elapsed)}
# Epoch 105, gen loss=2.0325255393981934,disc loss=0.8607491850852966, {hms_string(epoch_elapsed)}
# Epoch 106, gen loss=2.176563024520874,disc loss=1.064724326133728, {hms_string(epoch_elapsed)}
# Epoch 107, gen loss=1.876640796661377,disc loss=1.0946249961853027, {hms_string(epoch_elapsed)}
# Epoch 108, gen loss=2.0835208892822266,disc loss=1.1095573902130127, {hms_string(epoch_elapsed)}
# Epoch 109, gen loss=2.00779390335083,disc loss=1.06109619140625, {hms_string(epoch_elapsed)}
# Epoch 110, gen loss=2.065615653991699,disc loss=1.167783260345459, {hms_string(epoch_elapsed)}
# Epoch 111, gen loss=2.200627326965332,disc loss=1.019342064857483, {hms_string(epoch_elapsed)}
# Epoch 112, gen loss=2.0890307426452637,disc loss=1.2060519456863403, {hms_string(epoch_elapsed)}
# Epoch 113, gen loss=2.1459946632385254,disc loss=0.9050174355506897, {hms_string(epoch_elapsed)}
# Epoch 114, gen loss=2.152772903442383,disc loss=1.0867663621902466, {hms_string(epoch_elapsed)}
# Epoch 115, gen loss=1.9393094778060913,disc loss=1.1932651996612549, {hms_string(epoch_elapsed)}
# Epoch 116, gen loss=1.921995759010315,disc loss=1.2400351762771606, {hms_string(epoch_elapsed)}
# Epoch 117, gen loss=2.2324764728546143,disc loss=1.0767322778701782, {hms_string(epoch_elapsed)}
# Epoch 118, gen loss=2.14320707321167,disc loss=1.2677338123321533, {hms_string(epoch_elapsed)}
# Epoch 119, gen loss=2.0271241664886475,disc loss=1.237005352973938, {hms_string(epoch_elapsed)}
# Epoch 120, gen loss=2.212013006210327,disc loss=1.126809000968933, {hms_string(epoch_elapsed)}
# Epoch 121, gen loss=2.3436012268066406,disc loss=0.8691460490226746, {hms_string(epoch_elapsed)}
# Epoch 122, gen loss=2.203707695007324,disc loss=1.131127119064331, {hms_string(epoch_elapsed)}
# Epoch 123, gen loss=2.301037073135376,disc loss=0.8912128210067749, {hms_string(epoch_elapsed)}
# Epoch 124, gen loss=2.148463726043701,disc loss=1.009791612625122, {hms_string(epoch_elapsed)}
# Epoch 125, gen loss=2.3917882442474365,disc loss=0.9253395795822144, {hms_string(epoch_elapsed)}
# Epoch 126, gen loss=2.3968749046325684,disc loss=1.1609450578689575, {hms_string(epoch_elapsed)}
# Epoch 127, gen loss=2.3800933361053467,disc loss=0.8784583806991577, {hms_string(epoch_elapsed)}
# Epoch 128, gen loss=2.2437615394592285,disc loss=1.1105526685714722, {hms_string(epoch_elapsed)}
# Epoch 129, gen loss=2.301571846008301,disc loss=0.977970540523529, {hms_string(epoch_elapsed)}
# Epoch 130, gen loss=2.1820948123931885,disc loss=1.0209633111953735, {hms_string(epoch_elapsed)}
# Epoch 131, gen loss=2.186934471130371,disc loss=0.8739331364631653, {hms_string(epoch_elapsed)}
# Epoch 132, gen loss=2.326083183288574,disc loss=0.9243434071540833, {hms_string(epoch_elapsed)}
# Epoch 133, gen loss=2.2558629512786865,disc loss=1.0944321155548096, {hms_string(epoch_elapsed)}
# Epoch 134, gen loss=2.465538501739502,disc loss=0.9236814975738525, {hms_string(epoch_elapsed)}
# Epoch 135, gen loss=2.453122854232788,disc loss=1.2654120922088623, {hms_string(epoch_elapsed)}
# Epoch 136, gen loss=2.2952022552490234,disc loss=0.8567222952842712, {hms_string(epoch_elapsed)}
# Epoch 137, gen loss=2.252868413925171,disc loss=1.0043963193893433, {hms_string(epoch_elapsed)}
# Epoch 138, gen loss=2.387930393218994,disc loss=1.0876235961914062, {hms_string(epoch_elapsed)}
# Epoch 139, gen loss=2.1450417041778564,disc loss=0.9652146100997925, {hms_string(epoch_elapsed)}
# Epoch 140, gen loss=2.1069090366363525,disc loss=1.055987000465393, {hms_string(epoch_elapsed)}
# Epoch 141, gen loss=2.1583969593048096,disc loss=0.8754629492759705, {hms_string(epoch_elapsed)}
# Epoch 142, gen loss=2.0675244331359863,disc loss=1.0197066068649292, {hms_string(epoch_elapsed)}
# Epoch 143, gen loss=2.20234751701355,disc loss=0.9138599038124084, {hms_string(epoch_elapsed)}
# Epoch 144, gen loss=2.2255773544311523,disc loss=0.9331735372543335, {hms_string(epoch_elapsed)}
# Epoch 145, gen loss=2.4326155185699463,disc loss=1.2186875343322754, {hms_string(epoch_elapsed)}
# Epoch 146, gen loss=2.361762762069702,disc loss=1.0616472959518433, {hms_string(epoch_elapsed)}
# Epoch 147, gen loss=2.2277727127075195,disc loss=0.9085745215415955, {hms_string(epoch_elapsed)}
# Epoch 148, gen loss=2.1524648666381836,disc loss=0.9866793751716614, {hms_string(epoch_elapsed)}
# Epoch 149, gen loss=2.1962952613830566,disc loss=0.9941474199295044, {hms_string(epoch_elapsed)}
# Epoch 150, gen loss=2.139003276824951,disc loss=0.9139974117279053, {hms_string(epoch_elapsed)}
# Epoch 151, gen loss=2.06655216217041,disc loss=0.9029118418693542, {hms_string(epoch_elapsed)}
# Epoch 152, gen loss=2.3481738567352295,disc loss=1.0560003519058228, {hms_string(epoch_elapsed)}
# Epoch 153, gen loss=2.3558714389801025,disc loss=0.7903533577919006, {hms_string(epoch_elapsed)}
# Epoch 154, gen loss=2.5343854427337646,disc loss=0.7792249917984009, {hms_string(epoch_elapsed)}
# Epoch 155, gen loss=2.8358659744262695,disc loss=0.8876714110374451, {hms_string(epoch_elapsed)}
# Epoch 156, gen loss=2.328462600708008,disc loss=1.0304770469665527, {hms_string(epoch_elapsed)}
# Epoch 157, gen loss=2.0774993896484375,disc loss=0.7885342836380005, {hms_string(epoch_elapsed)}
# Epoch 158, gen loss=2.3653814792633057,disc loss=0.730377733707428, {hms_string(epoch_elapsed)}
# Epoch 159, gen loss=2.4286510944366455,disc loss=0.8834806084632874, {hms_string(epoch_elapsed)}
# Epoch 160, gen loss=2.220240592956543,disc loss=0.7747305631637573, {hms_string(epoch_elapsed)}
# Epoch 161, gen loss=2.3551976680755615,disc loss=0.7691559195518494, {hms_string(epoch_elapsed)}
# Epoch 162, gen loss=2.277548313140869,disc loss=0.8854088187217712, {hms_string(epoch_elapsed)}
# Epoch 163, gen loss=2.0734994411468506,disc loss=0.8917993903160095, {hms_string(epoch_elapsed)}
# Epoch 164, gen loss=2.573991537094116,disc loss=1.215200662612915, {hms_string(epoch_elapsed)}
# Epoch 165, gen loss=2.339776039123535,disc loss=0.9738573431968689, {hms_string(epoch_elapsed)}
# Epoch 166, gen loss=2.156560182571411,disc loss=0.9923533201217651, {hms_string(epoch_elapsed)}
# Epoch 167, gen loss=2.332348108291626,disc loss=0.8461440801620483, {hms_string(epoch_elapsed)}
# Epoch 168, gen loss=2.2040419578552246,disc loss=0.7910041809082031, {hms_string(epoch_elapsed)}
# Epoch 169, gen loss=2.176786184310913,disc loss=0.8298070430755615, {hms_string(epoch_elapsed)}
# Epoch 170, gen loss=2.5014491081237793,disc loss=1.0143043994903564, {hms_string(epoch_elapsed)}
# Epoch 171, gen loss=2.3518667221069336,disc loss=1.1169474124908447, {hms_string(epoch_elapsed)}
# Epoch 172, gen loss=2.273885488510132,disc loss=0.8021999001502991, {hms_string(epoch_elapsed)}
# Epoch 173, gen loss=2.3602564334869385,disc loss=0.9878199100494385, {hms_string(epoch_elapsed)}
# Epoch 174, gen loss=2.0479586124420166,disc loss=0.8335663676261902, {hms_string(epoch_elapsed)}
# Epoch 175, gen loss=2.2522075176239014,disc loss=0.866092324256897, {hms_string(epoch_elapsed)}
# Epoch 176, gen loss=2.27297306060791,disc loss=0.8639093041419983, {hms_string(epoch_elapsed)}
# Epoch 177, gen loss=2.4127745628356934,disc loss=0.8112651109695435, {hms_string(epoch_elapsed)}
# Epoch 178, gen loss=2.1561694145202637,disc loss=0.824005663394928, {hms_string(epoch_elapsed)}
# Epoch 179, gen loss=2.348740577697754,disc loss=0.7303575277328491, {hms_string(epoch_elapsed)}
# Epoch 180, gen loss=2.4011173248291016,disc loss=0.7633618712425232, {hms_string(epoch_elapsed)}
# Epoch 181, gen loss=2.509842872619629,disc loss=0.8598929643630981, {hms_string(epoch_elapsed)}
# Epoch 182, gen loss=2.3287229537963867,disc loss=0.6814385652542114, {hms_string(epoch_elapsed)}
# Epoch 183, gen loss=2.488757610321045,disc loss=0.7458155155181885, {hms_string(epoch_elapsed)}
# Epoch 184, gen loss=2.335183620452881,disc loss=0.7992052435874939, {hms_string(epoch_elapsed)}
# Epoch 185, gen loss=2.517000675201416,disc loss=0.7015279531478882, {hms_string(epoch_elapsed)}
# Epoch 186, gen loss=2.4283652305603027,disc loss=0.6735185384750366, {hms_string(epoch_elapsed)}
# Epoch 187, gen loss=2.494015693664551,disc loss=0.6634771823883057, {hms_string(epoch_elapsed)}
# Epoch 188, gen loss=2.4162099361419678,disc loss=0.692018449306488, {hms_string(epoch_elapsed)}
# Epoch 189, gen loss=2.5155436992645264,disc loss=0.6726173758506775, {hms_string(epoch_elapsed)}
# Epoch 190, gen loss=2.8030624389648438,disc loss=0.679132878780365, {hms_string(epoch_elapsed)}
# Epoch 191, gen loss=2.4235424995422363,disc loss=0.7304276823997498, {hms_string(epoch_elapsed)}
# Epoch 192, gen loss=2.712827444076538,disc loss=0.7838706970214844, {hms_string(epoch_elapsed)}
# Epoch 193, gen loss=2.477795124053955,disc loss=0.7483818531036377, {hms_string(epoch_elapsed)}
# Epoch 194, gen loss=2.558607578277588,disc loss=0.7144585847854614, {hms_string(epoch_elapsed)}
# Epoch 195, gen loss=2.428069591522217,disc loss=0.7497667074203491, {hms_string(epoch_elapsed)}
# Epoch 196, gen loss=2.5749707221984863,disc loss=0.7455349564552307, {hms_string(epoch_elapsed)}
# Epoch 197, gen loss=2.839127779006958,disc loss=0.6169835329055786, {hms_string(epoch_elapsed)}
# Epoch 198, gen loss=2.676809549331665,disc loss=0.6298909783363342, {hms_string(epoch_elapsed)}
# Epoch 199, gen loss=2.527432441711426,disc loss=0.7611991167068481, {hms_string(epoch_elapsed)}
# Epoch 200, gen loss=2.7380194664001465,disc loss=0.6965979337692261, {hms_string(epoch_elapsed)}
# Epoch 201, gen loss=2.58363676071167,disc loss=0.6392687559127808, {hms_string(epoch_elapsed)}
# Epoch 202, gen loss=2.9181056022644043,disc loss=0.744563639163971, {hms_string(epoch_elapsed)}
# Epoch 203, gen loss=2.9067864418029785,disc loss=0.6795511841773987, {hms_string(epoch_elapsed)}
# Epoch 204, gen loss=2.545644521713257,disc loss=0.7344350218772888, {hms_string(epoch_elapsed)}
# Epoch 205, gen loss=3.058926582336426,disc loss=0.6529425978660583, {hms_string(epoch_elapsed)}
# Epoch 206, gen loss=2.681065797805786,disc loss=0.6680062413215637, {hms_string(epoch_elapsed)}
# Epoch 207, gen loss=2.5350592136383057,disc loss=0.8159177303314209, {hms_string(epoch_elapsed)}
# Epoch 208, gen loss=2.680347204208374,disc loss=0.7404429316520691, {hms_string(epoch_elapsed)}
# Epoch 209, gen loss=2.8606457710266113,disc loss=0.6825453042984009, {hms_string(epoch_elapsed)}
# Epoch 210, gen loss=2.945941925048828,disc loss=0.6484110355377197, {hms_string(epoch_elapsed)}
# Epoch 211, gen loss=2.874156951904297,disc loss=0.5975309610366821, {hms_string(epoch_elapsed)}
# Epoch 212, gen loss=2.985102415084839,disc loss=0.6204026341438293, {hms_string(epoch_elapsed)}
# Epoch 213, gen loss=2.722782611846924,disc loss=0.6770451664924622, {hms_string(epoch_elapsed)}
# Epoch 214, gen loss=2.972846746444702,disc loss=0.5945131778717041, {hms_string(epoch_elapsed)}
# Epoch 215, gen loss=2.6855685710906982,disc loss=0.7515662312507629, {hms_string(epoch_elapsed)}
# Epoch 216, gen loss=3.030874013900757,disc loss=0.7143799066543579, {hms_string(epoch_elapsed)}
# Epoch 217, gen loss=3.029555082321167,disc loss=0.5666292905807495, {hms_string(epoch_elapsed)}
# Epoch 218, gen loss=3.09991455078125,disc loss=0.6208661794662476, {hms_string(epoch_elapsed)}
# Epoch 219, gen loss=2.8229639530181885,disc loss=0.560556173324585, {hms_string(epoch_elapsed)}
# Epoch 220, gen loss=2.989978313446045,disc loss=0.6542729735374451, {hms_string(epoch_elapsed)}
# Epoch 221, gen loss=3.1727497577667236,disc loss=0.5542833805084229, {hms_string(epoch_elapsed)}
# Epoch 222, gen loss=2.950727701187134,disc loss=0.5246332883834839, {hms_string(epoch_elapsed)}
# Epoch 223, gen loss=2.969566583633423,disc loss=0.6497942805290222, {hms_string(epoch_elapsed)}
# Epoch 224, gen loss=2.958223819732666,disc loss=0.47673970460891724, {hms_string(epoch_elapsed)}
# Epoch 225, gen loss=3.095334768295288,disc loss=0.6470649242401123, {hms_string(epoch_elapsed)}
# Epoch 226, gen loss=2.954263925552368,disc loss=0.6955980062484741, {hms_string(epoch_elapsed)}
# Epoch 227, gen loss=3.0146021842956543,disc loss=0.4743507206439972, {hms_string(epoch_elapsed)}
# Epoch 228, gen loss=2.993605136871338,disc loss=0.5138553977012634, {hms_string(epoch_elapsed)}
# Epoch 229, gen loss=3.1996512413024902,disc loss=0.4617597758769989, {hms_string(epoch_elapsed)}
# Epoch 230, gen loss=2.8680012226104736,disc loss=0.646696150302887, {hms_string(epoch_elapsed)}
# Epoch 231, gen loss=3.0870213508605957,disc loss=0.6406797766685486, {hms_string(epoch_elapsed)}
# Epoch 232, gen loss=3.105525493621826,disc loss=0.6498874425888062, {hms_string(epoch_elapsed)}
# Epoch 233, gen loss=3.0499496459960938,disc loss=0.530247151851654, {hms_string(epoch_elapsed)}
# Epoch 234, gen loss=3.0392494201660156,disc loss=0.5295500159263611, {hms_string(epoch_elapsed)}
# Epoch 235, gen loss=2.882739543914795,disc loss=0.5029264688491821, {hms_string(epoch_elapsed)}
# Epoch 236, gen loss=3.1269102096557617,disc loss=0.49662303924560547, {hms_string(epoch_elapsed)}
# Epoch 237, gen loss=3.0275256633758545,disc loss=0.7487757802009583, {hms_string(epoch_elapsed)}
# Epoch 238, gen loss=3.262486457824707,disc loss=0.5962746739387512, {hms_string(epoch_elapsed)}
# Epoch 239, gen loss=3.0319736003875732,disc loss=0.5594853758811951, {hms_string(epoch_elapsed)}
# Epoch 240, gen loss=3.0313076972961426,disc loss=0.49927186965942383, {hms_string(epoch_elapsed)}
# Epoch 241, gen loss=3.0016441345214844,disc loss=0.4900830388069153, {hms_string(epoch_elapsed)}
# Epoch 242, gen loss=3.2764029502868652,disc loss=0.5459890365600586, {hms_string(epoch_elapsed)}
# Epoch 243, gen loss=3.4716567993164062,disc loss=0.6827525496482849, {hms_string(epoch_elapsed)}
# Epoch 244, gen loss=3.7192370891571045,disc loss=0.5261126160621643, {hms_string(epoch_elapsed)}
# Epoch 245, gen loss=3.211412191390991,disc loss=0.4652843177318573, {hms_string(epoch_elapsed)}
# Epoch 246, gen loss=3.137362480163574,disc loss=0.4925234019756317, {hms_string(epoch_elapsed)}
# Epoch 247, gen loss=3.1504502296447754,disc loss=0.5279678106307983, {hms_string(epoch_elapsed)}
# Epoch 248, gen loss=3.2999305725097656,disc loss=0.4886702001094818, {hms_string(epoch_elapsed)}
# Epoch 249, gen loss=3.370897054672241,disc loss=0.5109413862228394, {hms_string(epoch_elapsed)}
# Epoch 250, gen loss=3.5784897804260254,disc loss=0.518828809261322, {hms_string(epoch_elapsed)}
# Epoch 251, gen loss=3.3058786392211914,disc loss=0.46167799830436707, {hms_string(epoch_elapsed)}
# Epoch 252, gen loss=3.2509846687316895,disc loss=0.6020642518997192, {hms_string(epoch_elapsed)}
# Epoch 253, gen loss=3.1810126304626465,disc loss=0.4125712811946869, {hms_string(epoch_elapsed)}
# Epoch 254, gen loss=3.224876880645752,disc loss=0.46516165137290955, {hms_string(epoch_elapsed)}
# Epoch 255, gen loss=3.3893139362335205,disc loss=0.50064617395401, {hms_string(epoch_elapsed)}
# Epoch 256, gen loss=3.2615931034088135,disc loss=0.5647249817848206, {hms_string(epoch_elapsed)}
# Epoch 257, gen loss=3.4009649753570557,disc loss=0.44925981760025024, {hms_string(epoch_elapsed)}
# Epoch 258, gen loss=3.314645528793335,disc loss=0.4370599389076233, {hms_string(epoch_elapsed)}
# Epoch 259, gen loss=3.3636462688446045,disc loss=0.4473573863506317, {hms_string(epoch_elapsed)}
# Epoch 260, gen loss=3.4681081771850586,disc loss=0.5406177639961243, {hms_string(epoch_elapsed)}
# Epoch 261, gen loss=3.2672715187072754,disc loss=0.5941657423973083, {hms_string(epoch_elapsed)}
# Epoch 262, gen loss=3.522979497909546,disc loss=0.5073849558830261, {hms_string(epoch_elapsed)}
# Epoch 263, gen loss=3.3584845066070557,disc loss=0.5712597966194153, {hms_string(epoch_elapsed)}
# Epoch 264, gen loss=3.2676286697387695,disc loss=0.5327662825584412, {hms_string(epoch_elapsed)}
# Epoch 265, gen loss=3.7923672199249268,disc loss=0.528230607509613, {hms_string(epoch_elapsed)}
# Epoch 266, gen loss=3.3562846183776855,disc loss=0.6006841063499451, {hms_string(epoch_elapsed)}
# Epoch 267, gen loss=3.538712739944458,disc loss=0.4101417660713196, {hms_string(epoch_elapsed)}
# Epoch 268, gen loss=3.5415964126586914,disc loss=0.43889957666397095, {hms_string(epoch_elapsed)}
# Epoch 269, gen loss=3.4761412143707275,disc loss=0.5745276212692261, {hms_string(epoch_elapsed)}
# Epoch 270, gen loss=3.4676873683929443,disc loss=0.4385679066181183, {hms_string(epoch_elapsed)}
# Epoch 271, gen loss=3.6902029514312744,disc loss=0.5082036852836609, {hms_string(epoch_elapsed)}
# Epoch 272, gen loss=3.617246150970459,disc loss=0.42247915267944336, {hms_string(epoch_elapsed)}
# Epoch 273, gen loss=3.364332675933838,disc loss=0.4729720652103424, {hms_string(epoch_elapsed)}
# Epoch 274, gen loss=3.1749746799468994,disc loss=0.42722511291503906, {hms_string(epoch_elapsed)}
# Epoch 275, gen loss=3.3715009689331055,disc loss=0.547848641872406, {hms_string(epoch_elapsed)}
# Epoch 276, gen loss=3.7049543857574463,disc loss=0.47397035360336304, {hms_string(epoch_elapsed)}
# Epoch 277, gen loss=3.5794146060943604,disc loss=0.42614060640335083, {hms_string(epoch_elapsed)}
# Epoch 278, gen loss=3.312784433364868,disc loss=0.3955116868019104, {hms_string(epoch_elapsed)}
# Epoch 279, gen loss=3.3301279544830322,disc loss=0.5522846579551697, {hms_string(epoch_elapsed)}
# Epoch 280, gen loss=3.7570130825042725,disc loss=0.4207652807235718, {hms_string(epoch_elapsed)}
# Epoch 281, gen loss=3.677388906478882,disc loss=0.4236921966075897, {hms_string(epoch_elapsed)}
# Epoch 282, gen loss=3.5045855045318604,disc loss=0.5185889005661011, {hms_string(epoch_elapsed)}
# Epoch 283, gen loss=3.4491610527038574,disc loss=0.49343377351760864, {hms_string(epoch_elapsed)}
# Epoch 284, gen loss=4.070256233215332,disc loss=0.3574228882789612, {hms_string(epoch_elapsed)}
# Epoch 285, gen loss=3.823918342590332,disc loss=0.5475049614906311, {hms_string(epoch_elapsed)}
# Epoch 286, gen loss=3.5604357719421387,disc loss=0.4420658349990845, {hms_string(epoch_elapsed)}
# Epoch 287, gen loss=3.292609214782715,disc loss=0.4480554163455963, {hms_string(epoch_elapsed)}
# Epoch 288, gen loss=3.977386474609375,disc loss=0.5491030216217041, {hms_string(epoch_elapsed)}
# Epoch 289, gen loss=3.6071977615356445,disc loss=0.4406125843524933, {hms_string(epoch_elapsed)}
# Epoch 290, gen loss=3.8683366775512695,disc loss=0.37775924801826477, {hms_string(epoch_elapsed)}
# Epoch 291, gen loss=3.5232560634613037,disc loss=0.5053090453147888, {hms_string(epoch_elapsed)}
# Epoch 292, gen loss=3.5876481533050537,disc loss=0.4067569375038147, {hms_string(epoch_elapsed)}
# Epoch 293, gen loss=3.521091938018799,disc loss=0.4103347659111023, {hms_string(epoch_elapsed)}
# Epoch 294, gen loss=3.331634998321533,disc loss=0.3704483211040497, {hms_string(epoch_elapsed)}
# Epoch 295, gen loss=3.613576650619507,disc loss=0.4553249478340149, {hms_string(epoch_elapsed)}
# Epoch 296, gen loss=3.8455328941345215,disc loss=0.5075322389602661, {hms_string(epoch_elapsed)}
# Epoch 297, gen loss=3.839097023010254,disc loss=0.30281099677085876, {hms_string(epoch_elapsed)}
# Epoch 298, gen loss=3.801321268081665,disc loss=0.4376824200153351, {hms_string(epoch_elapsed)}
# Epoch 299, gen loss=3.4551234245300293,disc loss=0.37457355856895447, {hms_string(epoch_elapsed)}
# Epoch 300, gen loss=3.5773825645446777,disc loss=0.489908367395401, {hms_string(epoch_elapsed)}
# Epoch 301, gen loss=3.949481725692749,disc loss=0.4857673943042755, {hms_string(epoch_elapsed)}
# Epoch 302, gen loss=3.394509792327881,disc loss=0.38108745217323303, {hms_string(epoch_elapsed)}
# Epoch 303, gen loss=3.816406011581421,disc loss=0.38420772552490234, {hms_string(epoch_elapsed)}
# Epoch 304, gen loss=3.6956241130828857,disc loss=0.4068344235420227, {hms_string(epoch_elapsed)}
# Epoch 305, gen loss=3.9787073135375977,disc loss=0.3517894148826599, {hms_string(epoch_elapsed)}
# Epoch 306, gen loss=3.813331365585327,disc loss=0.3924996554851532, {hms_string(epoch_elapsed)}
# Epoch 307, gen loss=3.854334831237793,disc loss=0.30661237239837646, {hms_string(epoch_elapsed)}
# Epoch 308, gen loss=3.837332248687744,disc loss=0.41260334849357605, {hms_string(epoch_elapsed)}
# Epoch 309, gen loss=4.165136814117432,disc loss=0.4717879891395569, {hms_string(epoch_elapsed)}
# Epoch 310, gen loss=3.9230077266693115,disc loss=0.3649139106273651, {hms_string(epoch_elapsed)}
# Epoch 311, gen loss=3.8817977905273438,disc loss=0.4345225989818573, {hms_string(epoch_elapsed)}
# Epoch 312, gen loss=3.982954740524292,disc loss=0.3103507161140442, {hms_string(epoch_elapsed)}
# Epoch 313, gen loss=3.8741350173950195,disc loss=0.33476173877716064, {hms_string(epoch_elapsed)}
# Epoch 314, gen loss=3.8500313758850098,disc loss=0.36182865500450134, {hms_string(epoch_elapsed)}
# Epoch 315, gen loss=3.9375722408294678,disc loss=0.32824432849884033, {hms_string(epoch_elapsed)}
# Epoch 316, gen loss=3.9256112575531006,disc loss=0.37750372290611267, {hms_string(epoch_elapsed)}
# Epoch 317, gen loss=4.050564765930176,disc loss=0.3375478982925415, {hms_string(epoch_elapsed)}
# Epoch 318, gen loss=4.386066436767578,disc loss=0.820357084274292, {hms_string(epoch_elapsed)}
# Epoch 319, gen loss=3.952115297317505,disc loss=0.3862033188343048, {hms_string(epoch_elapsed)}
# Epoch 320, gen loss=4.002170085906982,disc loss=0.41732391715049744, {hms_string(epoch_elapsed)}
# Epoch 321, gen loss=3.7666523456573486,disc loss=0.33778005838394165, {hms_string(epoch_elapsed)}
# Epoch 322, gen loss=4.085147857666016,disc loss=0.35933414101600647, {hms_string(epoch_elapsed)}
# Epoch 323, gen loss=3.8178324699401855,disc loss=0.3336707651615143, {hms_string(epoch_elapsed)}
# Epoch 324, gen loss=3.8374128341674805,disc loss=0.3235255777835846, {hms_string(epoch_elapsed)}
# Epoch 325, gen loss=4.131691932678223,disc loss=0.46399587392807007, {hms_string(epoch_elapsed)}
# Epoch 326, gen loss=4.4490132331848145,disc loss=0.34343618154525757, {hms_string(epoch_elapsed)}
# Epoch 327, gen loss=3.924288272857666,disc loss=0.4160846471786499, {hms_string(epoch_elapsed)}
# Epoch 328, gen loss=4.055832386016846,disc loss=0.406414657831192, {hms_string(epoch_elapsed)}
# Epoch 329, gen loss=4.531745433807373,disc loss=0.4314158260822296, {hms_string(epoch_elapsed)}
# Epoch 330, gen loss=3.9987475872039795,disc loss=0.3856274485588074, {hms_string(epoch_elapsed)}
# Epoch 331, gen loss=4.1298065185546875,disc loss=0.42392584681510925, {hms_string(epoch_elapsed)}
# Epoch 332, gen loss=4.451990127563477,disc loss=0.550849199295044, {hms_string(epoch_elapsed)}
# Epoch 333, gen loss=4.149206161499023,disc loss=0.3284702003002167, {hms_string(epoch_elapsed)}
# Epoch 334, gen loss=4.0965495109558105,disc loss=0.33131468296051025, {hms_string(epoch_elapsed)}
# Epoch 335, gen loss=4.209784507751465,disc loss=0.31081512570381165, {hms_string(epoch_elapsed)}
# Epoch 336, gen loss=4.012734413146973,disc loss=0.3972591757774353, {hms_string(epoch_elapsed)}
# Epoch 337, gen loss=3.9763731956481934,disc loss=0.368285208940506, {hms_string(epoch_elapsed)}
# Epoch 338, gen loss=4.12654447555542,disc loss=0.37242111563682556, {hms_string(epoch_elapsed)}
# Epoch 339, gen loss=4.000736236572266,disc loss=0.3045843839645386, {hms_string(epoch_elapsed)}
# Epoch 340, gen loss=4.407171726226807,disc loss=0.3954917788505554, {hms_string(epoch_elapsed)}
# Epoch 341, gen loss=4.308816909790039,disc loss=0.28452473878860474, {hms_string(epoch_elapsed)}
# Epoch 342, gen loss=4.0169572830200195,disc loss=0.35488319396972656, {hms_string(epoch_elapsed)}
# Epoch 343, gen loss=4.154293537139893,disc loss=0.3565784692764282, {hms_string(epoch_elapsed)}
# Epoch 344, gen loss=4.277868747711182,disc loss=0.3306436240673065, {hms_string(epoch_elapsed)}
# Epoch 345, gen loss=4.4470133781433105,disc loss=0.28672054409980774, {hms_string(epoch_elapsed)}
# Epoch 346, gen loss=4.241150856018066,disc loss=0.33054637908935547, {hms_string(epoch_elapsed)}
# Epoch 347, gen loss=4.312236309051514,disc loss=0.33285966515541077, {hms_string(epoch_elapsed)}
# Epoch 348, gen loss=4.10972261428833,disc loss=0.32638436555862427, {hms_string(epoch_elapsed)}
# Epoch 349, gen loss=4.527083873748779,disc loss=0.2992171347141266, {hms_string(epoch_elapsed)}
# Epoch 350, gen loss=4.1134443283081055,disc loss=0.29975080490112305, {hms_string(epoch_elapsed)}
# Epoch 351, gen loss=4.515491485595703,disc loss=0.3059682250022888, {hms_string(epoch_elapsed)}
# Epoch 352, gen loss=4.257479667663574,disc loss=0.2963683605194092, {hms_string(epoch_elapsed)}
# Epoch 353, gen loss=4.302313804626465,disc loss=0.2801482081413269, {hms_string(epoch_elapsed)}
# Epoch 354, gen loss=4.018686294555664,disc loss=0.3591153025627136, {hms_string(epoch_elapsed)}
# Epoch 355, gen loss=4.606762886047363,disc loss=0.40262702107429504, {hms_string(epoch_elapsed)}
# Epoch 356, gen loss=4.041621208190918,disc loss=0.3694238066673279, {hms_string(epoch_elapsed)}
# Epoch 357, gen loss=4.231761455535889,disc loss=0.30880266427993774, {hms_string(epoch_elapsed)}
# Epoch 358, gen loss=3.8612148761749268,disc loss=0.31798237562179565, {hms_string(epoch_elapsed)}
# Epoch 359, gen loss=4.0605244636535645,disc loss=0.2621591091156006, {hms_string(epoch_elapsed)}
# Epoch 360, gen loss=4.342587471008301,disc loss=0.3073098361492157, {hms_string(epoch_elapsed)}
# Epoch 361, gen loss=4.58497953414917,disc loss=0.3283250033855438, {hms_string(epoch_elapsed)}
# Epoch 362, gen loss=4.744904518127441,disc loss=0.3402898907661438, {hms_string(epoch_elapsed)}
# Epoch 363, gen loss=4.6316070556640625,disc loss=0.37575218081474304, {hms_string(epoch_elapsed)}
# Epoch 364, gen loss=4.635575771331787,disc loss=0.37444692850112915, {hms_string(epoch_elapsed)}
# Epoch 365, gen loss=4.973849296569824,disc loss=0.31628745794296265, {hms_string(epoch_elapsed)}
# Epoch 366, gen loss=4.434213161468506,disc loss=0.320676326751709, {hms_string(epoch_elapsed)}
# Epoch 367, gen loss=4.022603988647461,disc loss=0.3327586352825165, {hms_string(epoch_elapsed)}
# Epoch 368, gen loss=4.894972801208496,disc loss=0.36681443452835083, {hms_string(epoch_elapsed)}
# Epoch 369, gen loss=4.372159481048584,disc loss=0.3439117968082428, {hms_string(epoch_elapsed)}
# Epoch 370, gen loss=4.343303203582764,disc loss=0.21797937154769897, {hms_string(epoch_elapsed)}
# Epoch 371, gen loss=4.512136936187744,disc loss=0.33458274602890015, {hms_string(epoch_elapsed)}
# Epoch 372, gen loss=4.307854175567627,disc loss=0.32463839650154114, {hms_string(epoch_elapsed)}
# Epoch 373, gen loss=4.701250076293945,disc loss=0.5733006000518799, {hms_string(epoch_elapsed)}
# Epoch 374, gen loss=4.39054012298584,disc loss=0.3126845359802246, {hms_string(epoch_elapsed)}
# Epoch 375, gen loss=4.998282432556152,disc loss=0.5322842597961426, {hms_string(epoch_elapsed)}
# Epoch 376, gen loss=4.295433521270752,disc loss=0.32281795144081116, {hms_string(epoch_elapsed)}
# Epoch 377, gen loss=4.637187480926514,disc loss=0.41125085949897766, {hms_string(epoch_elapsed)}
# Epoch 378, gen loss=4.725688934326172,disc loss=0.2854462265968323, {hms_string(epoch_elapsed)}
# Epoch 379, gen loss=4.4816060066223145,disc loss=0.349842369556427, {hms_string(epoch_elapsed)}
# Epoch 380, gen loss=4.969086647033691,disc loss=0.5718098878860474, {hms_string(epoch_elapsed)}
# Epoch 381, gen loss=5.3867011070251465,disc loss=0.3770747780799866, {hms_string(epoch_elapsed)}
# Epoch 382, gen loss=4.546795845031738,disc loss=0.34491872787475586, {hms_string(epoch_elapsed)}
# Epoch 383, gen loss=4.498393535614014,disc loss=0.24932052195072174, {hms_string(epoch_elapsed)}
# Epoch 384, gen loss=4.420008659362793,disc loss=0.29514363408088684, {hms_string(epoch_elapsed)}
# Epoch 385, gen loss=4.61854362487793,disc loss=0.2635551393032074, {hms_string(epoch_elapsed)}
# Epoch 386, gen loss=4.565832138061523,disc loss=0.2689509689807892, {hms_string(epoch_elapsed)}
# Epoch 387, gen loss=4.513749599456787,disc loss=0.2697000801563263, {hms_string(epoch_elapsed)}
# Epoch 388, gen loss=4.6382856369018555,disc loss=0.33532604575157166, {hms_string(epoch_elapsed)}
# Epoch 389, gen loss=6.028075218200684,disc loss=0.6766348481178284, {hms_string(epoch_elapsed)}
# Epoch 390, gen loss=4.982864856719971,disc loss=0.27589643001556396, {hms_string(epoch_elapsed)}
# Epoch 391, gen loss=4.5889458656311035,disc loss=0.2707171142101288, {hms_string(epoch_elapsed)}
# Epoch 392, gen loss=4.577700614929199,disc loss=0.3560965657234192, {hms_string(epoch_elapsed)}
# Epoch 393, gen loss=4.815629005432129,disc loss=0.2981404662132263, {hms_string(epoch_elapsed)}
# Epoch 394, gen loss=4.893711566925049,disc loss=0.2794096767902374, {hms_string(epoch_elapsed)}
# Epoch 395, gen loss=4.835963249206543,disc loss=0.34006407856941223, {hms_string(epoch_elapsed)}
# Epoch 396, gen loss=4.127982139587402,disc loss=0.3142336308956146, {hms_string(epoch_elapsed)}
# Epoch 397, gen loss=5.412087440490723,disc loss=0.33160126209259033, {hms_string(epoch_elapsed)}
# Epoch 398, gen loss=4.599209308624268,disc loss=0.282827764749527, {hms_string(epoch_elapsed)}
# Epoch 399, gen loss=4.814377784729004,disc loss=0.2588243782520294, {hms_string(epoch_elapsed)}
# Epoch 400, gen loss=4.562461853027344,disc loss=0.30228474736213684, {hms_string(epoch_elapsed)}
# Epoch 401, gen loss=4.891009330749512,disc loss=0.27203404903411865, {hms_string(epoch_elapsed)}
# Epoch 402, gen loss=4.740623950958252,disc loss=0.32018154859542847, {hms_string(epoch_elapsed)}
# Epoch 403, gen loss=4.634211540222168,disc loss=0.23972076177597046, {hms_string(epoch_elapsed)}
# Epoch 404, gen loss=4.999614238739014,disc loss=0.2768547534942627, {hms_string(epoch_elapsed)}
# Epoch 405, gen loss=4.854644298553467,disc loss=0.24665234982967377, {hms_string(epoch_elapsed)}
# Epoch 406, gen loss=4.918956279754639,disc loss=0.21385638415813446, {hms_string(epoch_elapsed)}
# Epoch 407, gen loss=4.689221382141113,disc loss=0.22539152204990387, {hms_string(epoch_elapsed)}
# Epoch 408, gen loss=4.9841814041137695,disc loss=0.2891947329044342, {hms_string(epoch_elapsed)}
# Epoch 409, gen loss=4.794398307800293,disc loss=0.40119585394859314, {hms_string(epoch_elapsed)}
# Epoch 410, gen loss=4.658596515655518,disc loss=0.24880990386009216, {hms_string(epoch_elapsed)}
# Epoch 411, gen loss=4.46662712097168,disc loss=0.27986395359039307, {hms_string(epoch_elapsed)}
# Epoch 412, gen loss=4.760212421417236,disc loss=0.24544206261634827, {hms_string(epoch_elapsed)}
# Epoch 413, gen loss=4.387145042419434,disc loss=0.3346332013607025, {hms_string(epoch_elapsed)}
# Epoch 414, gen loss=4.926778316497803,disc loss=0.2509431540966034, {hms_string(epoch_elapsed)}
# Epoch 415, gen loss=5.179708480834961,disc loss=0.22073128819465637, {hms_string(epoch_elapsed)}
# Epoch 416, gen loss=5.181288719177246,disc loss=0.24389871954917908, {hms_string(epoch_elapsed)}
# Epoch 417, gen loss=5.563688278198242,disc loss=0.3097888231277466, {hms_string(epoch_elapsed)}
# Epoch 418, gen loss=4.683012008666992,disc loss=0.21438416838645935, {hms_string(epoch_elapsed)}
# Epoch 419, gen loss=5.438542366027832,disc loss=0.26130393147468567, {hms_string(epoch_elapsed)}
# Epoch 420, gen loss=4.759757041931152,disc loss=0.19668231904506683, {hms_string(epoch_elapsed)}
# Epoch 421, gen loss=5.181049823760986,disc loss=0.2121438831090927, {hms_string(epoch_elapsed)}
# Epoch 422, gen loss=4.676862716674805,disc loss=0.2354964315891266, {hms_string(epoch_elapsed)}
# Epoch 423, gen loss=5.396862983703613,disc loss=0.3180856704711914, {hms_string(epoch_elapsed)}
# Epoch 424, gen loss=4.7016167640686035,disc loss=0.2837996184825897, {hms_string(epoch_elapsed)}
# Epoch 425, gen loss=4.733096122741699,disc loss=0.25656428933143616, {hms_string(epoch_elapsed)}
# Epoch 426, gen loss=4.819982528686523,disc loss=0.2637876570224762, {hms_string(epoch_elapsed)}
# Epoch 427, gen loss=4.854847431182861,disc loss=0.25063973665237427, {hms_string(epoch_elapsed)}
# Epoch 428, gen loss=5.033777713775635,disc loss=0.21741625666618347, {hms_string(epoch_elapsed)}
# Epoch 429, gen loss=4.859435081481934,disc loss=0.22661444544792175, {hms_string(epoch_elapsed)}
# Epoch 430, gen loss=4.522334575653076,disc loss=0.26653626561164856, {hms_string(epoch_elapsed)}
# Epoch 431, gen loss=4.892972946166992,disc loss=0.27274781465530396, {hms_string(epoch_elapsed)}
# Epoch 432, gen loss=5.3097333908081055,disc loss=0.23402880132198334, {hms_string(epoch_elapsed)}
# Epoch 433, gen loss=5.564393043518066,disc loss=0.31017985939979553, {hms_string(epoch_elapsed)}
# Epoch 434, gen loss=5.552105903625488,disc loss=0.20622317492961884, {hms_string(epoch_elapsed)}
# Epoch 435, gen loss=5.4271368980407715,disc loss=0.17892268300056458, {hms_string(epoch_elapsed)}
# Epoch 436, gen loss=5.508641242980957,disc loss=0.27478206157684326, {hms_string(epoch_elapsed)}
# Epoch 437, gen loss=5.499198913574219,disc loss=0.3569839596748352, {hms_string(epoch_elapsed)}
# Epoch 438, gen loss=5.454797744750977,disc loss=0.291988730430603, {hms_string(epoch_elapsed)}
# Epoch 439, gen loss=5.157355308532715,disc loss=0.2265874445438385, {hms_string(epoch_elapsed)}
# Epoch 440, gen loss=5.341762065887451,disc loss=0.25788700580596924, {hms_string(epoch_elapsed)}
# Epoch 441, gen loss=5.274655818939209,disc loss=0.22440727055072784, {hms_string(epoch_elapsed)}
# Epoch 442, gen loss=6.0830206871032715,disc loss=0.2600308060646057, {hms_string(epoch_elapsed)}
# Epoch 443, gen loss=5.594916343688965,disc loss=0.21909478306770325, {hms_string(epoch_elapsed)}
# Epoch 444, gen loss=5.43019962310791,disc loss=0.22071398794651031, {hms_string(epoch_elapsed)}
# Epoch 445, gen loss=5.593869209289551,disc loss=0.19389447569847107, {hms_string(epoch_elapsed)}
# Epoch 446, gen loss=4.899191379547119,disc loss=0.26213905215263367, {hms_string(epoch_elapsed)}
# Epoch 447, gen loss=7.175961971282959,disc loss=0.6350904703140259, {hms_string(epoch_elapsed)}
# Epoch 448, gen loss=5.982138633728027,disc loss=0.3284866213798523, {hms_string(epoch_elapsed)}
# Epoch 449, gen loss=6.373796463012695,disc loss=0.36696356534957886, {hms_string(epoch_elapsed)}
# Epoch 450, gen loss=5.573401927947998,disc loss=0.3497363328933716, {hms_string(epoch_elapsed)}
# Epoch 451, gen loss=5.36353063583374,disc loss=0.24976176023483276, {hms_string(epoch_elapsed)}
# Epoch 452, gen loss=6.185477256774902,disc loss=0.3501702845096588, {hms_string(epoch_elapsed)}
# Epoch 453, gen loss=6.188224792480469,disc loss=0.2770150601863861, {hms_string(epoch_elapsed)}
# Epoch 454, gen loss=4.836521625518799,disc loss=0.2535267770290375, {hms_string(epoch_elapsed)}
# Epoch 455, gen loss=6.045280933380127,disc loss=0.27625349164009094, {hms_string(epoch_elapsed)}
# Epoch 456, gen loss=5.482963562011719,disc loss=0.2446504533290863, {hms_string(epoch_elapsed)}
# Epoch 457, gen loss=6.287948131561279,disc loss=0.2884736657142639, {hms_string(epoch_elapsed)}
# Epoch 458, gen loss=5.67078971862793,disc loss=0.2016511708498001, {hms_string(epoch_elapsed)}
# Epoch 459, gen loss=6.0815300941467285,disc loss=0.31429240107536316, {hms_string(epoch_elapsed)}
# Epoch 460, gen loss=6.1798481941223145,disc loss=0.22799669206142426, {hms_string(epoch_elapsed)}
# Epoch 461, gen loss=6.00112247467041,disc loss=0.24127891659736633, {hms_string(epoch_elapsed)}
# Epoch 462, gen loss=5.8848700523376465,disc loss=0.2574973404407501, {hms_string(epoch_elapsed)}
# Epoch 463, gen loss=5.760264873504639,disc loss=0.2582623362541199, {hms_string(epoch_elapsed)}
# Epoch 464, gen loss=5.590145587921143,disc loss=0.20692871510982513, {hms_string(epoch_elapsed)}
# Epoch 465, gen loss=6.0654425621032715,disc loss=0.23706009984016418, {hms_string(epoch_elapsed)}
# Epoch 466, gen loss=5.6434326171875,disc loss=0.1876341998577118, {hms_string(epoch_elapsed)}
# Epoch 467, gen loss=6.011019706726074,disc loss=0.2809009850025177, {hms_string(epoch_elapsed)}
# Epoch 468, gen loss=5.427544593811035,disc loss=0.255292147397995, {hms_string(epoch_elapsed)}
# Epoch 469, gen loss=4.948031902313232,disc loss=0.20627252757549286, {hms_string(epoch_elapsed)}
# Epoch 470, gen loss=5.51704216003418,disc loss=0.3211694359779358, {hms_string(epoch_elapsed)}
# Epoch 471, gen loss=5.671219825744629,disc loss=0.2984637916088104, {hms_string(epoch_elapsed)}
# Epoch 472, gen loss=5.238677978515625,disc loss=0.2784794270992279, {hms_string(epoch_elapsed)}
# Epoch 473, gen loss=4.7685980796813965,disc loss=0.22860373556613922, {hms_string(epoch_elapsed)}
# Epoch 474, gen loss=5.730190753936768,disc loss=0.2411097139120102, {hms_string(epoch_elapsed)}
# Epoch 475, gen loss=4.720451831817627,disc loss=0.2508200407028198, {hms_string(epoch_elapsed)}
# Epoch 476, gen loss=8.090413093566895,disc loss=0.40583309531211853, {hms_string(epoch_elapsed)}
# Epoch 477, gen loss=5.8232221603393555,disc loss=0.275407612323761, {hms_string(epoch_elapsed)}
# Epoch 478, gen loss=5.88848876953125,disc loss=0.28321579098701477, {hms_string(epoch_elapsed)}
# Epoch 479, gen loss=5.795108318328857,disc loss=0.25201839208602905, {hms_string(epoch_elapsed)}
# Epoch 480, gen loss=5.280709266662598,disc loss=0.2280355989933014, {hms_string(epoch_elapsed)}
# Epoch 481, gen loss=6.3146185874938965,disc loss=0.347209632396698, {hms_string(epoch_elapsed)}
# Epoch 482, gen loss=5.040696144104004,disc loss=0.2512907385826111, {hms_string(epoch_elapsed)}
# Epoch 483, gen loss=5.594625473022461,disc loss=0.24378517270088196, {hms_string(epoch_elapsed)}
# Epoch 484, gen loss=6.820645809173584,disc loss=0.2783757746219635, {hms_string(epoch_elapsed)}
# Epoch 485, gen loss=5.7974419593811035,disc loss=0.3327352702617645, {hms_string(epoch_elapsed)}
# Epoch 486, gen loss=5.832790851593018,disc loss=0.258971244096756, {hms_string(epoch_elapsed)}
# Epoch 487, gen loss=6.683266639709473,disc loss=0.2948826551437378, {hms_string(epoch_elapsed)}
# Epoch 488, gen loss=5.736517906188965,disc loss=0.2558637261390686, {hms_string(epoch_elapsed)}
# Epoch 489, gen loss=4.7565107345581055,disc loss=0.18082764744758606, {hms_string(epoch_elapsed)}
# Epoch 490, gen loss=5.00683069229126,disc loss=0.23884007334709167, {hms_string(epoch_elapsed)}
# Epoch 491, gen loss=5.839468002319336,disc loss=0.2819828391075134, {hms_string(epoch_elapsed)}
# Epoch 492, gen loss=6.423779010772705,disc loss=0.25265538692474365, {hms_string(epoch_elapsed)}
# Epoch 493, gen loss=4.991307258605957,disc loss=0.2151036262512207, {hms_string(epoch_elapsed)}
# Epoch 494, gen loss=5.60929536819458,disc loss=0.2792259156703949, {hms_string(epoch_elapsed)}
# Epoch 495, gen loss=6.845363140106201,disc loss=0.5964886546134949, {hms_string(epoch_elapsed)}
# Epoch 496, gen loss=7.585258483886719,disc loss=0.4111880660057068, {hms_string(epoch_elapsed)}
# Epoch 497, gen loss=5.545228004455566,disc loss=0.3080720901489258, {hms_string(epoch_elapsed)}
# Epoch 498, gen loss=5.856075763702393,disc loss=0.26435238122940063, {hms_string(epoch_elapsed)}
# Epoch 499, gen loss=6.04314661026001,disc loss=0.25094887614250183, {hms_string(epoch_elapsed)}
# Epoch 500, gen loss=7.175680160522461,disc loss=0.30406373739242554, {hms_string(epoch_elapsed)}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-d152560ca122> in <module>()
# ----> 1 train(train_dataset, EPOCHS)
#
# <ipython-input-13-beaaf5d2e204> in train(dataset, epochs)
#      24
#      25   elapsed = time.time()-start
# ---> 26   print (f'Training time: {hms_string(elapsed)}')
#
# NameError: name 'hms_string' is not defined
