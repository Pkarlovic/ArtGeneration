# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Reshape, Dropout, Dense 
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Activation, ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
import numpy as np
from PIL import Image
from tqdm import tqdm
import os 
import time
import matplotlib.pyplot as plt

# %%
GENERATE_RES = 2 # Generation resolution factor 
# (1=32, 2=64, 3=96, 4=128, etc.)
GENERATE_SQUARE = 32 * GENERATE_RES # rows/cols (should be square)
IMAGE_CHANNELS = 3

# Preview image 
PREVIEW_ROWS = 4
PREVIEW_COLS = 7
PREVIEW_MARGIN = 16

# Size vector to generate images from
SEED_SIZE = 100

# Configuration
DATA_PATH = '/content/drive/MyDrive/cats'
EPOCHS = 500
BATCH_SIZE = 32
BUFFER_SIZE = 60000

print(f"Will generate {GENERATE_SQUARE}px square images.")
# Out:
# Will generate 64px square images.

# %%
training_binary_path = os.path.join(DATA_PATH,
        f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}.npy')

print(f"Looking for file: {training_binary_path}")

if not os.path.isfile(training_binary_path):
  start = time.time()
  print("Loading training images...")

  training_data = []
  faces_path = os.path.join(DATA_PATH)
  for filename in tqdm(os.listdir(faces_path)):
      path = os.path.join(faces_path,filename)
      image = Image.open(path).resize((GENERATE_SQUARE,
            GENERATE_SQUARE),Image.ANTIALIAS)
      training_data.append(np.asarray(image))
  training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,
            GENERATE_SQUARE,IMAGE_CHANNELS))
  training_data = training_data.astype(np.float32)
  training_data = training_data / 127.5 - 1.


  print("Saving training image binary...")
  np.save(training_binary_path,training_data)
  elapsed = time.time()-start
  print (f'Image preprocess time: {hms_string(elapsed)}')
else:
  print("Loading previous training pickle...")
  training_data = np.load(training_binary_path)
# Out:
# Looking for file: /content/drive/MyDrive/cats/training_data_64_64.npy
# Loading training images...
# 100%|██████████| 10918/10918 [02:46<00:00, 65.59it/s]
# Saving training image binary...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e772a20664ce> in <module>()
#      24   np.save(training_binary_path,training_data)
#      25   elapsed = time.time()-start
# ---> 26   print (f'Image preprocess time: {hms_string(elapsed)}')
#      27 else:
#      28   print("Loading previous training pickle...")
#
# NameError: name 'hms_string' is not defined

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(training_data).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
 def build_generator(seed_size, channels):
    model = Sequential()

    model.add(Dense(4*4*256,activation="relu",input_dim=seed_size))
    model.add(Reshape((4,4,256)))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
   
    # Output resolution, additional upsampling
    model.add(UpSampling2D())
    model.add(Conv2D(128,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    if GENERATE_RES>1:
      model.add(UpSampling2D(size=(GENERATE_RES,GENERATE_RES)))
      model.add(Conv2D(128,kernel_size=3,padding="same"))
      model.add(BatchNormalization(momentum=0.8))
      model.add(Activation("relu"))

    # Final CNN layer
    model.add(Conv2D(channels,kernel_size=3,padding="same"))
    model.add(Activation("tanh"))

    return model


def build_discriminator(image_shape):
    model = Sequential()

    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=image_shape, 
                     padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(512, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))

    return model

# %%
def save_images(cnt,noise):
  image_array = np.full(( 
      PREVIEW_MARGIN + (PREVIEW_ROWS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 
      PREVIEW_MARGIN + (PREVIEW_COLS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 3), 
      255, dtype=np.uint8)
  
  generated_images = generator.predict(noise)

  generated_images = 0.5 * generated_images + 0.5

  image_count = 0
  for row in range(PREVIEW_ROWS):
      for col in range(PREVIEW_COLS):
        r = row * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        c = col * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        image_array[r:r+GENERATE_SQUARE,c:c+GENERATE_SQUARE] = generated_images[image_count] * 255
        image_count += 1

          
  output_path = os.path.join(DATA_PATH,'output')
  if not os.path.exists(output_path):
    os.makedirs(output_path)
  
  filename = os.path.join(output_path,f"train-{cnt}.png")
  im = Image.fromarray(image_array)
  im.save(filename)

# %%
generator = build_generator(SEED_SIZE, IMAGE_CHANNELS)

noise = tf.random.normal([1, SEED_SIZE])
generated_image = generator(noise, training=False)

plt.imshow(generated_image[0, :, :, 0])

# %%
image_shape = (GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS)

discriminator = build_discriminator(image_shape)
decision = discriminator(generated_image)
print (decision)
# Out:
# tf.Tensor([[0.500539]], shape=(1, 1), dtype=float32)

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy()

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
generator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)

# %%
@tf.function
def train_step(images):
  seed = tf.random.normal([BATCH_SIZE, SEED_SIZE])

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator(seed, training=True)

    real_output = discriminator(images, training=True)
    fake_output = discriminator(generated_images, training=True)

    gen_loss = generator_loss(fake_output)
    disc_loss = discriminator_loss(real_output, fake_output)
    

    gradients_of_generator = gen_tape.gradient(
        gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(
        disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(
        gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(
        gradients_of_discriminator, 
        discriminator.trainable_variables))
  return gen_loss,disc_loss

# %%
def train(dataset, epochs):
  fixed_seed = np.random.normal(0, 1, (PREVIEW_ROWS * PREVIEW_COLS, 
                                       SEED_SIZE))
  start = time.time()

  for epoch in range(epochs):
    epoch_start = time.time()

    gen_loss_list = []
    disc_loss_list = []

    for image_batch in dataset:
      t = train_step(image_batch)
      gen_loss_list.append(t[0])
      disc_loss_list.append(t[1])

    g_loss = sum(gen_loss_list) / len(gen_loss_list)
    d_loss = sum(disc_loss_list) / len(disc_loss_list)

    epoch_elapsed = time.time()-epoch_start
    print (f'Epoch {epoch+1}, gen loss={g_loss},disc loss={d_loss},'
           ' {hms_string(epoch_elapsed)}')
    save_images(epoch,fixed_seed)

  elapsed = time.time()-start
  print (f'Training time: {hms_string(elapsed)}')

# %%
train(train_dataset, EPOCHS)
# Out:
# Epoch 1, gen loss=2.8359391689300537,disc loss=0.7542309761047363, {hms_string(epoch_elapsed)}
# Epoch 2, gen loss=1.5076113939285278,disc loss=1.2424306869506836, {hms_string(epoch_elapsed)}
# Epoch 3, gen loss=1.5869489908218384,disc loss=1.1453815698623657, {hms_string(epoch_elapsed)}
# Epoch 4, gen loss=1.9010295867919922,disc loss=1.057125210762024, {hms_string(epoch_elapsed)}
# Epoch 5, gen loss=1.8129699230194092,disc loss=1.0512193441390991, {hms_string(epoch_elapsed)}
# Epoch 6, gen loss=1.8387541770935059,disc loss=1.0821412801742554, {hms_string(epoch_elapsed)}
# Epoch 7, gen loss=1.7426015138626099,disc loss=1.1103360652923584, {hms_string(epoch_elapsed)}
# Epoch 8, gen loss=1.7495476007461548,disc loss=1.1122108697891235, {hms_string(epoch_elapsed)}
# Epoch 9, gen loss=1.7421159744262695,disc loss=1.1292955875396729, {hms_string(epoch_elapsed)}
# Epoch 10, gen loss=1.7197377681732178,disc loss=1.106225848197937, {hms_string(epoch_elapsed)}
# Epoch 11, gen loss=1.7572426795959473,disc loss=1.0634511709213257, {hms_string(epoch_elapsed)}
# Epoch 12, gen loss=1.7622469663619995,disc loss=1.0510149002075195, {hms_string(epoch_elapsed)}
# Epoch 13, gen loss=1.902174949645996,disc loss=0.9918252825737, {hms_string(epoch_elapsed)}
# Epoch 14, gen loss=1.8816814422607422,disc loss=1.0494502782821655, {hms_string(epoch_elapsed)}
# Epoch 15, gen loss=1.8545535802841187,disc loss=1.0797618627548218, {hms_string(epoch_elapsed)}
# Epoch 16, gen loss=1.7912492752075195,disc loss=1.0470064878463745, {hms_string(epoch_elapsed)}
# Epoch 17, gen loss=1.8709067106246948,disc loss=1.0416094064712524, {hms_string(epoch_elapsed)}
# Epoch 18, gen loss=1.8766372203826904,disc loss=1.0531697273254395, {hms_string(epoch_elapsed)}
# Epoch 19, gen loss=1.7107501029968262,disc loss=1.1155431270599365, {hms_string(epoch_elapsed)}
# Epoch 20, gen loss=1.8022934198379517,disc loss=1.054517149925232, {hms_string(epoch_elapsed)}
# Epoch 21, gen loss=1.7455954551696777,disc loss=1.0428457260131836, {hms_string(epoch_elapsed)}
# Epoch 22, gen loss=1.7903739213943481,disc loss=1.0435082912445068, {hms_string(epoch_elapsed)}
# Epoch 23, gen loss=1.7822835445404053,disc loss=1.031699538230896, {hms_string(epoch_elapsed)}
# Epoch 24, gen loss=1.8775545358657837,disc loss=0.9630873203277588, {hms_string(epoch_elapsed)}
# Epoch 25, gen loss=1.8411376476287842,disc loss=1.0163581371307373, {hms_string(epoch_elapsed)}
# Epoch 26, gen loss=1.8550171852111816,disc loss=1.0034080743789673, {hms_string(epoch_elapsed)}
# Epoch 27, gen loss=1.7929418087005615,disc loss=1.0326963663101196, {hms_string(epoch_elapsed)}
# Epoch 28, gen loss=1.9059005975723267,disc loss=0.9769678711891174, {hms_string(epoch_elapsed)}
# Epoch 29, gen loss=1.8655441999435425,disc loss=0.9926598072052002, {hms_string(epoch_elapsed)}
# Epoch 30, gen loss=1.8460352420806885,disc loss=0.969188928604126, {hms_string(epoch_elapsed)}
# Epoch 31, gen loss=1.8621165752410889,disc loss=0.9778112173080444, {hms_string(epoch_elapsed)}
# Epoch 32, gen loss=1.7982501983642578,disc loss=1.0425636768341064, {hms_string(epoch_elapsed)}
# Epoch 33, gen loss=1.8599326610565186,disc loss=0.9506399631500244, {hms_string(epoch_elapsed)}
# Epoch 34, gen loss=1.8133915662765503,disc loss=1.0327105522155762, {hms_string(epoch_elapsed)}
# Epoch 35, gen loss=1.8012311458587646,disc loss=0.9854506850242615, {hms_string(epoch_elapsed)}
# Epoch 36, gen loss=1.832758903503418,disc loss=0.9789656400680542, {hms_string(epoch_elapsed)}
# Epoch 37, gen loss=1.8314898014068604,disc loss=0.9795724749565125, {hms_string(epoch_elapsed)}
# Epoch 38, gen loss=1.8453584909439087,disc loss=0.9670002460479736, {hms_string(epoch_elapsed)}
# Epoch 39, gen loss=1.8758705854415894,disc loss=0.9777566194534302, {hms_string(epoch_elapsed)}
# Epoch 40, gen loss=1.9298354387283325,disc loss=0.9381421804428101, {hms_string(epoch_elapsed)}
# Epoch 41, gen loss=1.909509301185608,disc loss=0.9565244317054749, {hms_string(epoch_elapsed)}
# Epoch 42, gen loss=1.9016519784927368,disc loss=0.9472038745880127, {hms_string(epoch_elapsed)}
# Epoch 43, gen loss=1.9567869901657104,disc loss=0.9373272657394409, {hms_string(epoch_elapsed)}
# Epoch 44, gen loss=1.96647047996521,disc loss=0.8974143862724304, {hms_string(epoch_elapsed)}
# Epoch 45, gen loss=2.020498037338257,disc loss=0.9091728925704956, {hms_string(epoch_elapsed)}
# Epoch 46, gen loss=2.024916172027588,disc loss=0.890951931476593, {hms_string(epoch_elapsed)}
# Epoch 47, gen loss=2.0577690601348877,disc loss=0.8839492201805115, {hms_string(epoch_elapsed)}
# Epoch 48, gen loss=2.0107028484344482,disc loss=0.9120652675628662, {hms_string(epoch_elapsed)}
# Epoch 49, gen loss=2.003143072128296,disc loss=0.9095237851142883, {hms_string(epoch_elapsed)}
# Epoch 50, gen loss=2.016860008239746,disc loss=0.9257230758666992, {hms_string(epoch_elapsed)}
# Epoch 51, gen loss=1.9751851558685303,disc loss=0.9335585236549377, {hms_string(epoch_elapsed)}
# Epoch 52, gen loss=2.0751264095306396,disc loss=0.892242431640625, {hms_string(epoch_elapsed)}
# Epoch 53, gen loss=2.002967596054077,disc loss=0.9302484393119812, {hms_string(epoch_elapsed)}
# Epoch 54, gen loss=2.0860989093780518,disc loss=0.8738884329795837, {hms_string(epoch_elapsed)}
# Epoch 55, gen loss=2.143303155899048,disc loss=0.8715522289276123, {hms_string(epoch_elapsed)}
# Epoch 56, gen loss=2.0908682346343994,disc loss=0.8807591795921326, {hms_string(epoch_elapsed)}
# Epoch 57, gen loss=2.1371302604675293,disc loss=0.8373129963874817, {hms_string(epoch_elapsed)}
# Epoch 58, gen loss=2.1404473781585693,disc loss=0.887117326259613, {hms_string(epoch_elapsed)}
# Epoch 59, gen loss=2.154470920562744,disc loss=0.8307847380638123, {hms_string(epoch_elapsed)}
# Epoch 60, gen loss=2.1688590049743652,disc loss=0.8652481436729431, {hms_string(epoch_elapsed)}
# Epoch 61, gen loss=2.257154941558838,disc loss=0.7980542778968811, {hms_string(epoch_elapsed)}
# Epoch 62, gen loss=2.1439402103424072,disc loss=0.8871738314628601, {hms_string(epoch_elapsed)}
# Epoch 63, gen loss=2.189323663711548,disc loss=0.8511004447937012, {hms_string(epoch_elapsed)}
# Epoch 64, gen loss=2.1056196689605713,disc loss=0.8998944759368896, {hms_string(epoch_elapsed)}
# Epoch 65, gen loss=2.214843988418579,disc loss=0.8138808608055115, {hms_string(epoch_elapsed)}
# Epoch 66, gen loss=2.2381327152252197,disc loss=0.7866665124893188, {hms_string(epoch_elapsed)}
# Epoch 67, gen loss=2.3107385635375977,disc loss=0.8035581111907959, {hms_string(epoch_elapsed)}
# Epoch 68, gen loss=2.241623878479004,disc loss=0.8199332356452942, {hms_string(epoch_elapsed)}
# Epoch 69, gen loss=2.254985809326172,disc loss=0.7898995280265808, {hms_string(epoch_elapsed)}
# Epoch 70, gen loss=2.309487819671631,disc loss=0.7671231031417847, {hms_string(epoch_elapsed)}
# Epoch 71, gen loss=2.4544103145599365,disc loss=0.7568316459655762, {hms_string(epoch_elapsed)}
# Epoch 72, gen loss=2.372462511062622,disc loss=0.7592640519142151, {hms_string(epoch_elapsed)}
# Epoch 73, gen loss=2.355888843536377,disc loss=0.7798133492469788, {hms_string(epoch_elapsed)}
# Epoch 74, gen loss=2.449690103530884,disc loss=0.7681267261505127, {hms_string(epoch_elapsed)}
# Epoch 75, gen loss=2.4062066078186035,disc loss=0.775326132774353, {hms_string(epoch_elapsed)}
# Epoch 76, gen loss=2.4432573318481445,disc loss=0.7872105836868286, {hms_string(epoch_elapsed)}
# Epoch 77, gen loss=2.3521852493286133,disc loss=0.8074513673782349, {hms_string(epoch_elapsed)}
# Epoch 78, gen loss=2.376610517501831,disc loss=0.8141083121299744, {hms_string(epoch_elapsed)}
# Epoch 79, gen loss=2.4089508056640625,disc loss=0.7610129117965698, {hms_string(epoch_elapsed)}
# Epoch 80, gen loss=2.4257707595825195,disc loss=0.76329505443573, {hms_string(epoch_elapsed)}
# Epoch 81, gen loss=2.389893054962158,disc loss=0.7894594669342041, {hms_string(epoch_elapsed)}
# Epoch 82, gen loss=2.480926275253296,disc loss=0.7207151055335999, {hms_string(epoch_elapsed)}
# Epoch 83, gen loss=2.5548183917999268,disc loss=0.7084312438964844, {hms_string(epoch_elapsed)}
# Epoch 84, gen loss=2.4910693168640137,disc loss=0.7450672388076782, {hms_string(epoch_elapsed)}
# Epoch 85, gen loss=2.5101065635681152,disc loss=0.7495995163917542, {hms_string(epoch_elapsed)}
# Epoch 86, gen loss=2.523378849029541,disc loss=0.7217064499855042, {hms_string(epoch_elapsed)}
# Epoch 87, gen loss=2.557234287261963,disc loss=0.7417786121368408, {hms_string(epoch_elapsed)}
# Epoch 88, gen loss=2.5509605407714844,disc loss=0.7236645817756653, {hms_string(epoch_elapsed)}
# Epoch 89, gen loss=2.492650270462036,disc loss=0.7526414394378662, {hms_string(epoch_elapsed)}
# Epoch 90, gen loss=2.53599214553833,disc loss=0.7260000109672546, {hms_string(epoch_elapsed)}
# Epoch 91, gen loss=2.5619397163391113,disc loss=0.7239641547203064, {hms_string(epoch_elapsed)}
# Epoch 92, gen loss=2.638579845428467,disc loss=0.6788274049758911, {hms_string(epoch_elapsed)}
# Epoch 93, gen loss=2.6247923374176025,disc loss=0.6721289753913879, {hms_string(epoch_elapsed)}
# Epoch 94, gen loss=2.730855941772461,disc loss=0.6830345392227173, {hms_string(epoch_elapsed)}
# Epoch 95, gen loss=2.667367458343506,disc loss=0.7038847804069519, {hms_string(epoch_elapsed)}
# Epoch 96, gen loss=2.6314139366149902,disc loss=0.7133945226669312, {hms_string(epoch_elapsed)}
# Epoch 97, gen loss=2.7152624130249023,disc loss=0.6706101894378662, {hms_string(epoch_elapsed)}
# Epoch 98, gen loss=2.640411615371704,disc loss=0.7444096803665161, {hms_string(epoch_elapsed)}
# Epoch 99, gen loss=2.7447166442871094,disc loss=0.6659950017929077, {hms_string(epoch_elapsed)}
# Epoch 100, gen loss=2.6840903759002686,disc loss=0.7060248851776123, {hms_string(epoch_elapsed)}
# Epoch 101, gen loss=2.741466760635376,disc loss=0.6852090954780579, {hms_string(epoch_elapsed)}
# Epoch 102, gen loss=2.767028570175171,disc loss=0.6634085178375244, {hms_string(epoch_elapsed)}
# Epoch 103, gen loss=2.698770523071289,disc loss=0.7161899209022522, {hms_string(epoch_elapsed)}
# Epoch 104, gen loss=2.7399508953094482,disc loss=0.6676086783409119, {hms_string(epoch_elapsed)}
# Epoch 105, gen loss=2.7429091930389404,disc loss=0.6638821363449097, {hms_string(epoch_elapsed)}
# Epoch 106, gen loss=2.7330315113067627,disc loss=0.6918419003486633, {hms_string(epoch_elapsed)}
# Epoch 107, gen loss=2.793297052383423,disc loss=0.7137627601623535, {hms_string(epoch_elapsed)}
# Epoch 108, gen loss=2.7412383556365967,disc loss=0.6776385307312012, {hms_string(epoch_elapsed)}
# Epoch 109, gen loss=2.792541742324829,disc loss=0.698799192905426, {hms_string(epoch_elapsed)}
# Epoch 110, gen loss=2.6852571964263916,disc loss=0.6642641425132751, {hms_string(epoch_elapsed)}
# Epoch 111, gen loss=2.7850821018218994,disc loss=0.6676902770996094, {hms_string(epoch_elapsed)}
# Epoch 112, gen loss=2.750572681427002,disc loss=0.7184215188026428, {hms_string(epoch_elapsed)}
# Epoch 113, gen loss=2.7397053241729736,disc loss=0.6791157722473145, {hms_string(epoch_elapsed)}
# Epoch 114, gen loss=2.8839590549468994,disc loss=0.6494476199150085, {hms_string(epoch_elapsed)}
# Epoch 115, gen loss=2.7984635829925537,disc loss=0.6945787668228149, {hms_string(epoch_elapsed)}
# Epoch 116, gen loss=2.89987850189209,disc loss=0.638312816619873, {hms_string(epoch_elapsed)}
# Epoch 117, gen loss=2.8139901161193848,disc loss=0.6628895401954651, {hms_string(epoch_elapsed)}
# Epoch 118, gen loss=2.8934166431427,disc loss=0.6338793635368347, {hms_string(epoch_elapsed)}
# Epoch 119, gen loss=2.8811800479888916,disc loss=0.6278195977210999, {hms_string(epoch_elapsed)}
# Epoch 120, gen loss=2.9394447803497314,disc loss=0.6193668842315674, {hms_string(epoch_elapsed)}
# Epoch 121, gen loss=2.854210376739502,disc loss=0.6588767170906067, {hms_string(epoch_elapsed)}
# Epoch 122, gen loss=2.915229320526123,disc loss=0.650092601776123, {hms_string(epoch_elapsed)}
# Epoch 123, gen loss=2.945051670074463,disc loss=0.6133102774620056, {hms_string(epoch_elapsed)}
# Epoch 124, gen loss=2.984624147415161,disc loss=0.639634907245636, {hms_string(epoch_elapsed)}
# Epoch 125, gen loss=2.9324653148651123,disc loss=0.6183027625083923, {hms_string(epoch_elapsed)}
# Epoch 126, gen loss=2.990269184112549,disc loss=0.6643877029418945, {hms_string(epoch_elapsed)}
# Epoch 127, gen loss=2.9027464389801025,disc loss=0.6653427481651306, {hms_string(epoch_elapsed)}
# Epoch 128, gen loss=3.075418710708618,disc loss=0.6056134104728699, {hms_string(epoch_elapsed)}
# Epoch 129, gen loss=3.0555009841918945,disc loss=0.5856577157974243, {hms_string(epoch_elapsed)}
# Epoch 130, gen loss=3.032519578933716,disc loss=0.6251972317695618, {hms_string(epoch_elapsed)}
# Epoch 131, gen loss=2.890749454498291,disc loss=0.6341026425361633, {hms_string(epoch_elapsed)}
# Epoch 132, gen loss=2.935473680496216,disc loss=0.6578283309936523, {hms_string(epoch_elapsed)}
# Epoch 133, gen loss=2.9749999046325684,disc loss=0.6058849692344666, {hms_string(epoch_elapsed)}
# Epoch 134, gen loss=3.017589569091797,disc loss=0.6054876446723938, {hms_string(epoch_elapsed)}
# Epoch 135, gen loss=2.9680230617523193,disc loss=0.672404944896698, {hms_string(epoch_elapsed)}
# Epoch 136, gen loss=2.931072950363159,disc loss=0.6560202240943909, {hms_string(epoch_elapsed)}
# Epoch 137, gen loss=3.013899564743042,disc loss=0.604939877986908, {hms_string(epoch_elapsed)}
# Epoch 138, gen loss=2.9807610511779785,disc loss=0.6306024789810181, {hms_string(epoch_elapsed)}
# Epoch 139, gen loss=3.0136005878448486,disc loss=0.6230973601341248, {hms_string(epoch_elapsed)}
# Epoch 140, gen loss=3.06880259513855,disc loss=0.6227389574050903, {hms_string(epoch_elapsed)}
# Epoch 141, gen loss=3.009232997894287,disc loss=0.6154745221138, {hms_string(epoch_elapsed)}
# Epoch 142, gen loss=3.0078001022338867,disc loss=0.6247437000274658, {hms_string(epoch_elapsed)}
# Epoch 143, gen loss=3.0081918239593506,disc loss=0.6654897332191467, {hms_string(epoch_elapsed)}
# Epoch 144, gen loss=2.9495439529418945,disc loss=0.6542778015136719, {hms_string(epoch_elapsed)}
# Epoch 145, gen loss=3.0290138721466064,disc loss=0.5950073599815369, {hms_string(epoch_elapsed)}
# Epoch 146, gen loss=3.026834726333618,disc loss=0.6662607192993164, {hms_string(epoch_elapsed)}
# Epoch 147, gen loss=2.9324138164520264,disc loss=0.6699041128158569, {hms_string(epoch_elapsed)}
# Epoch 148, gen loss=3.0324435234069824,disc loss=0.6196991205215454, {hms_string(epoch_elapsed)}
# Epoch 149, gen loss=3.0612332820892334,disc loss=0.6076744198799133, {hms_string(epoch_elapsed)}
# Epoch 150, gen loss=2.9756085872650146,disc loss=0.6193195581436157, {hms_string(epoch_elapsed)}
# Epoch 151, gen loss=2.997316837310791,disc loss=0.636518120765686, {hms_string(epoch_elapsed)}
# Epoch 152, gen loss=3.07794189453125,disc loss=0.6405019164085388, {hms_string(epoch_elapsed)}
# Epoch 153, gen loss=3.030475378036499,disc loss=0.629574716091156, {hms_string(epoch_elapsed)}
# Epoch 154, gen loss=3.0084521770477295,disc loss=0.6260808706283569, {hms_string(epoch_elapsed)}
# Epoch 155, gen loss=3.0241892337799072,disc loss=0.5916237235069275, {hms_string(epoch_elapsed)}
# Epoch 156, gen loss=3.0432629585266113,disc loss=0.6271929144859314, {hms_string(epoch_elapsed)}
# Epoch 157, gen loss=3.025386095046997,disc loss=0.6125485897064209, {hms_string(epoch_elapsed)}
# Epoch 158, gen loss=3.0948946475982666,disc loss=0.6061354875564575, {hms_string(epoch_elapsed)}
# Epoch 159, gen loss=3.1470961570739746,disc loss=0.6067385673522949, {hms_string(epoch_elapsed)}
# Epoch 160, gen loss=3.1832664012908936,disc loss=0.5896278023719788, {hms_string(epoch_elapsed)}
# Epoch 161, gen loss=3.0400137901306152,disc loss=0.6140282154083252, {hms_string(epoch_elapsed)}
# Epoch 162, gen loss=3.123060703277588,disc loss=0.6021643280982971, {hms_string(epoch_elapsed)}
# Epoch 163, gen loss=3.0917859077453613,disc loss=0.6131292581558228, {hms_string(epoch_elapsed)}
# Epoch 164, gen loss=3.0478997230529785,disc loss=0.6165683269500732, {hms_string(epoch_elapsed)}
# Epoch 165, gen loss=3.114241123199463,disc loss=0.6221151351928711, {hms_string(epoch_elapsed)}
# Epoch 166, gen loss=3.1123738288879395,disc loss=0.622373640537262, {hms_string(epoch_elapsed)}
# Epoch 167, gen loss=3.068688154220581,disc loss=0.6102456450462341, {hms_string(epoch_elapsed)}
# Epoch 168, gen loss=3.082108736038208,disc loss=0.6160896420478821, {hms_string(epoch_elapsed)}
# Epoch 169, gen loss=3.114259958267212,disc loss=0.6027597784996033, {hms_string(epoch_elapsed)}
# Epoch 170, gen loss=3.155081033706665,disc loss=0.6147363781929016, {hms_string(epoch_elapsed)}
# Epoch 171, gen loss=3.120514392852783,disc loss=0.5825333595275879, {hms_string(epoch_elapsed)}
# Epoch 172, gen loss=3.171297073364258,disc loss=0.5902336239814758, {hms_string(epoch_elapsed)}
# Epoch 173, gen loss=3.1627087593078613,disc loss=0.6356546878814697, {hms_string(epoch_elapsed)}
# Epoch 174, gen loss=3.118577718734741,disc loss=0.601534903049469, {hms_string(epoch_elapsed)}
# Epoch 175, gen loss=3.155097723007202,disc loss=0.5896241664886475, {hms_string(epoch_elapsed)}
# Epoch 176, gen loss=3.1807875633239746,disc loss=0.5767863988876343, {hms_string(epoch_elapsed)}
# Epoch 177, gen loss=3.1752097606658936,disc loss=0.6205156445503235, {hms_string(epoch_elapsed)}
# Epoch 178, gen loss=3.2219767570495605,disc loss=0.6079084873199463, {hms_string(epoch_elapsed)}
# Epoch 179, gen loss=3.271531820297241,disc loss=0.578208327293396, {hms_string(epoch_elapsed)}
# Epoch 180, gen loss=3.29166316986084,disc loss=0.557593822479248, {hms_string(epoch_elapsed)}
# Epoch 181, gen loss=3.3426263332366943,disc loss=0.5734167695045471, {hms_string(epoch_elapsed)}
# Epoch 182, gen loss=3.2841439247131348,disc loss=0.5843279361724854, {hms_string(epoch_elapsed)}
# Epoch 183, gen loss=3.2676656246185303,disc loss=0.5646324157714844, {hms_string(epoch_elapsed)}
# Epoch 184, gen loss=3.2866249084472656,disc loss=0.5686876773834229, {hms_string(epoch_elapsed)}
# Epoch 185, gen loss=3.1974782943725586,disc loss=0.5790035724639893, {hms_string(epoch_elapsed)}
# Epoch 186, gen loss=3.299712896347046,disc loss=0.5778855085372925, {hms_string(epoch_elapsed)}
# Epoch 187, gen loss=3.3465301990509033,disc loss=0.5805574655532837, {hms_string(epoch_elapsed)}
# Epoch 188, gen loss=3.44632625579834,disc loss=0.5377033948898315, {hms_string(epoch_elapsed)}
# Epoch 189, gen loss=3.3293850421905518,disc loss=0.5572832226753235, {hms_string(epoch_elapsed)}
# Epoch 190, gen loss=3.3648831844329834,disc loss=0.5427208542823792, {hms_string(epoch_elapsed)}
# Epoch 191, gen loss=3.35207462310791,disc loss=0.5536207556724548, {hms_string(epoch_elapsed)}
# Epoch 192, gen loss=3.3673763275146484,disc loss=0.5479413270950317, {hms_string(epoch_elapsed)}
# Epoch 193, gen loss=3.421940565109253,disc loss=0.5698552131652832, {hms_string(epoch_elapsed)}
# Epoch 194, gen loss=3.2732036113739014,disc loss=0.5724055171012878, {hms_string(epoch_elapsed)}
# Epoch 195, gen loss=3.344757318496704,disc loss=0.5602102279663086, {hms_string(epoch_elapsed)}
# Epoch 196, gen loss=3.268960952758789,disc loss=0.5710499286651611, {hms_string(epoch_elapsed)}
# Epoch 197, gen loss=3.373164653778076,disc loss=0.5610359311103821, {hms_string(epoch_elapsed)}
# Epoch 198, gen loss=3.4364898204803467,disc loss=0.5227726101875305, {hms_string(epoch_elapsed)}
# Epoch 199, gen loss=3.4622228145599365,disc loss=0.5591750741004944, {hms_string(epoch_elapsed)}
# Epoch 200, gen loss=3.352473735809326,disc loss=0.5615048408508301, {hms_string(epoch_elapsed)}
# Epoch 201, gen loss=3.4201624393463135,disc loss=0.5923741459846497, {hms_string(epoch_elapsed)}
# Epoch 202, gen loss=3.377925157546997,disc loss=0.5634157657623291, {hms_string(epoch_elapsed)}
# Epoch 203, gen loss=3.3567850589752197,disc loss=0.5793237686157227, {hms_string(epoch_elapsed)}
# Epoch 204, gen loss=3.3740673065185547,disc loss=0.5785781741142273, {hms_string(epoch_elapsed)}
# Epoch 205, gen loss=3.3959879875183105,disc loss=0.5751856565475464, {hms_string(epoch_elapsed)}
# Epoch 206, gen loss=3.326289415359497,disc loss=0.5724776387214661, {hms_string(epoch_elapsed)}
# Epoch 207, gen loss=3.418138265609741,disc loss=0.548587441444397, {hms_string(epoch_elapsed)}
# Epoch 208, gen loss=3.35054349899292,disc loss=0.5855423212051392, {hms_string(epoch_elapsed)}
# Epoch 209, gen loss=3.408644199371338,disc loss=0.561745822429657, {hms_string(epoch_elapsed)}
# Epoch 210, gen loss=3.321765661239624,disc loss=0.5665184855461121, {hms_string(epoch_elapsed)}
# Epoch 211, gen loss=3.4382903575897217,disc loss=0.5572567582130432, {hms_string(epoch_elapsed)}
# Epoch 212, gen loss=3.4751369953155518,disc loss=0.5317640900611877, {hms_string(epoch_elapsed)}
# Epoch 213, gen loss=3.472303628921509,disc loss=0.5393003225326538, {hms_string(epoch_elapsed)}
# Epoch 214, gen loss=3.5035459995269775,disc loss=0.5500330924987793, {hms_string(epoch_elapsed)}
# Epoch 215, gen loss=3.5774753093719482,disc loss=0.5470722317695618, {hms_string(epoch_elapsed)}
# Epoch 216, gen loss=3.5064992904663086,disc loss=0.525915801525116, {hms_string(epoch_elapsed)}
# Epoch 217, gen loss=3.4715018272399902,disc loss=0.5449609756469727, {hms_string(epoch_elapsed)}
# Epoch 218, gen loss=3.5222456455230713,disc loss=0.6003392338752747, {hms_string(epoch_elapsed)}
# Epoch 219, gen loss=3.4327304363250732,disc loss=0.5684148073196411, {hms_string(epoch_elapsed)}
# Epoch 220, gen loss=3.5112719535827637,disc loss=0.5311686992645264, {hms_string(epoch_elapsed)}
# Epoch 221, gen loss=3.5593514442443848,disc loss=0.5239336490631104, {hms_string(epoch_elapsed)}
# Epoch 222, gen loss=3.484502077102661,disc loss=0.5386490225791931, {hms_string(epoch_elapsed)}
# Epoch 223, gen loss=3.506232261657715,disc loss=0.5558629631996155, {hms_string(epoch_elapsed)}
# Epoch 224, gen loss=3.4232606887817383,disc loss=0.563448965549469, {hms_string(epoch_elapsed)}
# Epoch 225, gen loss=3.531189203262329,disc loss=0.5179499387741089, {hms_string(epoch_elapsed)}
# Epoch 226, gen loss=3.479107141494751,disc loss=0.5784163475036621, {hms_string(epoch_elapsed)}
# Epoch 227, gen loss=3.4957656860351562,disc loss=0.5428948402404785, {hms_string(epoch_elapsed)}
# Epoch 228, gen loss=3.4609038829803467,disc loss=0.5625677704811096, {hms_string(epoch_elapsed)}
# Epoch 229, gen loss=3.518430233001709,disc loss=0.5090994834899902, {hms_string(epoch_elapsed)}
# Epoch 230, gen loss=3.510138511657715,disc loss=0.552490234375, {hms_string(epoch_elapsed)}
# Epoch 231, gen loss=3.4856903553009033,disc loss=0.5175281763076782, {hms_string(epoch_elapsed)}
# Epoch 232, gen loss=3.6264562606811523,disc loss=0.5161876082420349, {hms_string(epoch_elapsed)}
# Epoch 233, gen loss=3.534235715866089,disc loss=0.5633551478385925, {hms_string(epoch_elapsed)}
# Epoch 234, gen loss=3.56954288482666,disc loss=0.5200051069259644, {hms_string(epoch_elapsed)}
# Epoch 235, gen loss=3.502794027328491,disc loss=0.5541834235191345, {hms_string(epoch_elapsed)}
# Epoch 236, gen loss=3.576667547225952,disc loss=0.5047875642776489, {hms_string(epoch_elapsed)}
# Epoch 237, gen loss=3.526293992996216,disc loss=0.5666213631629944, {hms_string(epoch_elapsed)}
# Epoch 238, gen loss=3.5665783882141113,disc loss=0.5511032342910767, {hms_string(epoch_elapsed)}
# Epoch 239, gen loss=3.5386972427368164,disc loss=0.5446045398712158, {hms_string(epoch_elapsed)}
# Epoch 240, gen loss=3.624689817428589,disc loss=0.4899331331253052, {hms_string(epoch_elapsed)}
# Epoch 241, gen loss=3.6098856925964355,disc loss=0.5052919983863831, {hms_string(epoch_elapsed)}
# Epoch 242, gen loss=3.5600528717041016,disc loss=0.5504264831542969, {hms_string(epoch_elapsed)}
# Epoch 243, gen loss=3.6180834770202637,disc loss=0.5240915417671204, {hms_string(epoch_elapsed)}
# Epoch 244, gen loss=3.5785601139068604,disc loss=0.5309133529663086, {hms_string(epoch_elapsed)}
# Epoch 245, gen loss=3.561950445175171,disc loss=0.523298442363739, {hms_string(epoch_elapsed)}
# Epoch 246, gen loss=3.555967092514038,disc loss=0.5387967824935913, {hms_string(epoch_elapsed)}
# Epoch 247, gen loss=3.5237464904785156,disc loss=0.545770525932312, {hms_string(epoch_elapsed)}
# Epoch 248, gen loss=3.515735387802124,disc loss=0.5283153057098389, {hms_string(epoch_elapsed)}
# Epoch 249, gen loss=3.6366195678710938,disc loss=0.5318245887756348, {hms_string(epoch_elapsed)}
# Epoch 250, gen loss=3.5712051391601562,disc loss=0.4993405342102051, {hms_string(epoch_elapsed)}
# Epoch 251, gen loss=3.600364923477173,disc loss=0.5436744689941406, {hms_string(epoch_elapsed)}
# Epoch 252, gen loss=3.570005178451538,disc loss=0.5316991806030273, {hms_string(epoch_elapsed)}
# Epoch 253, gen loss=3.7013823986053467,disc loss=0.5360498428344727, {hms_string(epoch_elapsed)}
# Epoch 254, gen loss=3.59696626663208,disc loss=0.5431801080703735, {hms_string(epoch_elapsed)}
# Epoch 255, gen loss=3.619852304458618,disc loss=0.5588284134864807, {hms_string(epoch_elapsed)}
# Epoch 256, gen loss=3.632359266281128,disc loss=0.4839276671409607, {hms_string(epoch_elapsed)}
# Epoch 257, gen loss=3.736034631729126,disc loss=0.47701945900917053, {hms_string(epoch_elapsed)}
# Epoch 258, gen loss=3.748094081878662,disc loss=0.4779681861400604, {hms_string(epoch_elapsed)}
# Epoch 259, gen loss=3.783210515975952,disc loss=0.5026037096977234, {hms_string(epoch_elapsed)}
# Epoch 260, gen loss=3.6716768741607666,disc loss=0.49902045726776123, {hms_string(epoch_elapsed)}
# Epoch 261, gen loss=3.7379813194274902,disc loss=0.5156073570251465, {hms_string(epoch_elapsed)}
# Epoch 262, gen loss=3.8478851318359375,disc loss=0.5131451487541199, {hms_string(epoch_elapsed)}
# Epoch 263, gen loss=3.791473150253296,disc loss=0.5001466870307922, {hms_string(epoch_elapsed)}
# Epoch 264, gen loss=3.6871049404144287,disc loss=0.4950776994228363, {hms_string(epoch_elapsed)}
# Epoch 265, gen loss=3.722993850708008,disc loss=0.5434937477111816, {hms_string(epoch_elapsed)}
# Epoch 266, gen loss=3.6703073978424072,disc loss=0.4976254403591156, {hms_string(epoch_elapsed)}
# Epoch 267, gen loss=3.7609195709228516,disc loss=0.5044179558753967, {hms_string(epoch_elapsed)}
# Epoch 268, gen loss=3.8082194328308105,disc loss=0.49895551800727844, {hms_string(epoch_elapsed)}
# Epoch 269, gen loss=3.7220590114593506,disc loss=0.5142716765403748, {hms_string(epoch_elapsed)}
# Epoch 270, gen loss=3.7043347358703613,disc loss=0.5267553329467773, {hms_string(epoch_elapsed)}
# Epoch 271, gen loss=3.627628803253174,disc loss=0.512424111366272, {hms_string(epoch_elapsed)}
# Epoch 272, gen loss=3.6556577682495117,disc loss=0.5032725930213928, {hms_string(epoch_elapsed)}
# Epoch 273, gen loss=3.7175824642181396,disc loss=0.49847933650016785, {hms_string(epoch_elapsed)}
# Epoch 274, gen loss=3.734180450439453,disc loss=0.5067959427833557, {hms_string(epoch_elapsed)}
# Epoch 275, gen loss=3.8043105602264404,disc loss=0.5121679306030273, {hms_string(epoch_elapsed)}
# Epoch 276, gen loss=3.789483070373535,disc loss=0.501505970954895, {hms_string(epoch_elapsed)}
# Epoch 277, gen loss=3.7913808822631836,disc loss=0.5123690962791443, {hms_string(epoch_elapsed)}
# Epoch 278, gen loss=3.756181001663208,disc loss=0.5063144564628601, {hms_string(epoch_elapsed)}
# Epoch 279, gen loss=3.6930088996887207,disc loss=0.5194676518440247, {hms_string(epoch_elapsed)}
# Epoch 280, gen loss=3.7571864128112793,disc loss=0.4930555522441864, {hms_string(epoch_elapsed)}
# Epoch 281, gen loss=3.803520441055298,disc loss=0.5157214403152466, {hms_string(epoch_elapsed)}
# Epoch 282, gen loss=3.8085458278656006,disc loss=0.50399249792099, {hms_string(epoch_elapsed)}
# Epoch 283, gen loss=3.802969217300415,disc loss=0.49459531903266907, {hms_string(epoch_elapsed)}
# Epoch 284, gen loss=3.775648593902588,disc loss=0.5100035667419434, {hms_string(epoch_elapsed)}
# Epoch 285, gen loss=3.7257654666900635,disc loss=0.4781685471534729, {hms_string(epoch_elapsed)}
# Epoch 286, gen loss=3.7772395610809326,disc loss=0.47336462140083313, {hms_string(epoch_elapsed)}
# Epoch 287, gen loss=3.8400375843048096,disc loss=0.4930391311645508, {hms_string(epoch_elapsed)}
# Epoch 288, gen loss=3.812706708908081,disc loss=0.47177374362945557, {hms_string(epoch_elapsed)}
# Epoch 289, gen loss=3.8299977779388428,disc loss=0.49647003412246704, {hms_string(epoch_elapsed)}
# Epoch 290, gen loss=3.764665126800537,disc loss=0.5087206959724426, {hms_string(epoch_elapsed)}
# Epoch 291, gen loss=3.828171730041504,disc loss=0.5157301425933838, {hms_string(epoch_elapsed)}
# Epoch 292, gen loss=3.7984530925750732,disc loss=0.49476033449172974, {hms_string(epoch_elapsed)}
# Epoch 293, gen loss=3.8369228839874268,disc loss=0.5154150724411011, {hms_string(epoch_elapsed)}
# Epoch 294, gen loss=3.723968029022217,disc loss=0.521581768989563, {hms_string(epoch_elapsed)}
# Epoch 295, gen loss=3.8220558166503906,disc loss=0.48022836446762085, {hms_string(epoch_elapsed)}
# Epoch 296, gen loss=3.8805601596832275,disc loss=0.4764721989631653, {hms_string(epoch_elapsed)}
# Epoch 297, gen loss=3.882136106491089,disc loss=0.482848197221756, {hms_string(epoch_elapsed)}
# Epoch 298, gen loss=3.840980291366577,disc loss=0.4652811288833618, {hms_string(epoch_elapsed)}
# Epoch 299, gen loss=3.835414171218872,disc loss=0.47986021637916565, {hms_string(epoch_elapsed)}
# Epoch 300, gen loss=3.8438503742218018,disc loss=0.4929966926574707, {hms_string(epoch_elapsed)}
# Epoch 301, gen loss=3.8735404014587402,disc loss=0.4795246124267578, {hms_string(epoch_elapsed)}
# Epoch 302, gen loss=3.901197671890259,disc loss=0.4740840494632721, {hms_string(epoch_elapsed)}
# Epoch 303, gen loss=3.900792121887207,disc loss=0.492910772562027, {hms_string(epoch_elapsed)}
# Epoch 304, gen loss=3.864790439605713,disc loss=0.5113337635993958, {hms_string(epoch_elapsed)}
# Epoch 305, gen loss=3.9264159202575684,disc loss=0.4306076765060425, {hms_string(epoch_elapsed)}
# Epoch 306, gen loss=3.8538339138031006,disc loss=0.4863083064556122, {hms_string(epoch_elapsed)}
# Epoch 307, gen loss=3.893115282058716,disc loss=0.49132195115089417, {hms_string(epoch_elapsed)}
# Epoch 308, gen loss=3.8643763065338135,disc loss=0.49783259630203247, {hms_string(epoch_elapsed)}
# Epoch 309, gen loss=3.950076103210449,disc loss=0.4634425640106201, {hms_string(epoch_elapsed)}
# Epoch 310, gen loss=3.957915782928467,disc loss=0.4913465678691864, {hms_string(epoch_elapsed)}
# Epoch 311, gen loss=3.875194549560547,disc loss=0.4777916371822357, {hms_string(epoch_elapsed)}
# Epoch 312, gen loss=3.913262367248535,disc loss=0.47444888949394226, {hms_string(epoch_elapsed)}
# Epoch 313, gen loss=3.8731281757354736,disc loss=0.5184694528579712, {hms_string(epoch_elapsed)}
# Epoch 314, gen loss=3.9102871417999268,disc loss=0.4819912910461426, {hms_string(epoch_elapsed)}
# Epoch 315, gen loss=4.015584468841553,disc loss=0.45032626390457153, {hms_string(epoch_elapsed)}
# Epoch 316, gen loss=3.931591749191284,disc loss=0.4703125059604645, {hms_string(epoch_elapsed)}
# Epoch 317, gen loss=3.9675493240356445,disc loss=0.48873209953308105, {hms_string(epoch_elapsed)}
# Epoch 318, gen loss=3.934696912765503,disc loss=0.4601220488548279, {hms_string(epoch_elapsed)}
# Epoch 319, gen loss=4.019529342651367,disc loss=0.44282519817352295, {hms_string(epoch_elapsed)}
# Epoch 320, gen loss=4.017019271850586,disc loss=0.4800569713115692, {hms_string(epoch_elapsed)}
# Epoch 321, gen loss=4.04049825668335,disc loss=0.46743202209472656, {hms_string(epoch_elapsed)}
# Epoch 322, gen loss=3.950967788696289,disc loss=0.4601026475429535, {hms_string(epoch_elapsed)}
# Epoch 323, gen loss=3.899548292160034,disc loss=0.5229079127311707, {hms_string(epoch_elapsed)}
# Epoch 324, gen loss=3.927049398422241,disc loss=0.4826512932777405, {hms_string(epoch_elapsed)}
# Epoch 325, gen loss=3.8982646465301514,disc loss=0.455148845911026, {hms_string(epoch_elapsed)}
# Epoch 326, gen loss=4.0244951248168945,disc loss=0.4369550943374634, {hms_string(epoch_elapsed)}
# Epoch 327, gen loss=3.9570224285125732,disc loss=0.4559474289417267, {hms_string(epoch_elapsed)}
# Epoch 328, gen loss=3.9719231128692627,disc loss=0.4748370945453644, {hms_string(epoch_elapsed)}
# Epoch 329, gen loss=3.963841438293457,disc loss=0.4718930125236511, {hms_string(epoch_elapsed)}
# Epoch 330, gen loss=3.9941155910491943,disc loss=0.4897923171520233, {hms_string(epoch_elapsed)}
# Epoch 331, gen loss=3.9800097942352295,disc loss=0.4488826096057892, {hms_string(epoch_elapsed)}
# Epoch 332, gen loss=3.9694178104400635,disc loss=0.4846231937408447, {hms_string(epoch_elapsed)}
# Epoch 333, gen loss=4.012410640716553,disc loss=0.46851709485054016, {hms_string(epoch_elapsed)}
# Epoch 334, gen loss=3.9629712104797363,disc loss=0.49187037348747253, {hms_string(epoch_elapsed)}
# Epoch 335, gen loss=3.9766793251037598,disc loss=0.47147825360298157, {hms_string(epoch_elapsed)}
# Epoch 336, gen loss=4.044722557067871,disc loss=0.43038928508758545, {hms_string(epoch_elapsed)}
# Epoch 337, gen loss=4.08456563949585,disc loss=0.4433452785015106, {hms_string(epoch_elapsed)}
# Epoch 338, gen loss=4.058413982391357,disc loss=0.4546862244606018, {hms_string(epoch_elapsed)}
# Epoch 339, gen loss=3.9474904537200928,disc loss=0.441194087266922, {hms_string(epoch_elapsed)}
# Epoch 340, gen loss=3.994694471359253,disc loss=0.4675890803337097, {hms_string(epoch_elapsed)}
# Epoch 341, gen loss=4.017911434173584,disc loss=0.445237934589386, {hms_string(epoch_elapsed)}
# Epoch 342, gen loss=4.034798622131348,disc loss=0.48184025287628174, {hms_string(epoch_elapsed)}
# Epoch 343, gen loss=4.008995056152344,disc loss=0.47144001722335815, {hms_string(epoch_elapsed)}
# Epoch 344, gen loss=4.086926460266113,disc loss=0.45248648524284363, {hms_string(epoch_elapsed)}
# Epoch 345, gen loss=4.046362400054932,disc loss=0.4656176269054413, {hms_string(epoch_elapsed)}
# Epoch 346, gen loss=4.022984027862549,disc loss=0.4762510359287262, {hms_string(epoch_elapsed)}
# Epoch 347, gen loss=4.028834819793701,disc loss=0.4658512771129608, {hms_string(epoch_elapsed)}
# Epoch 348, gen loss=4.095376968383789,disc loss=0.4328055679798126, {hms_string(epoch_elapsed)}
# Epoch 349, gen loss=4.12187385559082,disc loss=0.44942745566368103, {hms_string(epoch_elapsed)}
# Epoch 350, gen loss=4.185473918914795,disc loss=0.4387371242046356, {hms_string(epoch_elapsed)}
# Epoch 351, gen loss=4.067894458770752,disc loss=0.47720298171043396, {hms_string(epoch_elapsed)}
# Epoch 352, gen loss=4.068998336791992,disc loss=0.46398457884788513, {hms_string(epoch_elapsed)}
# Epoch 353, gen loss=3.961723566055298,disc loss=0.47039714455604553, {hms_string(epoch_elapsed)}
# Epoch 354, gen loss=4.04733419418335,disc loss=0.4507392346858978, {hms_string(epoch_elapsed)}
# Epoch 355, gen loss=3.9832143783569336,disc loss=0.5030984878540039, {hms_string(epoch_elapsed)}
# Epoch 356, gen loss=4.01192569732666,disc loss=0.46231546998023987, {hms_string(epoch_elapsed)}
# Epoch 357, gen loss=4.073260307312012,disc loss=0.46174731850624084, {hms_string(epoch_elapsed)}
# Epoch 358, gen loss=3.9678092002868652,disc loss=0.5024927258491516, {hms_string(epoch_elapsed)}
# Epoch 359, gen loss=4.090436935424805,disc loss=0.4437757432460785, {hms_string(epoch_elapsed)}
# Epoch 360, gen loss=4.1460466384887695,disc loss=0.4253690838813782, {hms_string(epoch_elapsed)}
# Epoch 361, gen loss=4.055029392242432,disc loss=0.4976682960987091, {hms_string(epoch_elapsed)}
# Epoch 362, gen loss=4.109137058258057,disc loss=0.44710153341293335, {hms_string(epoch_elapsed)}
# Epoch 363, gen loss=4.089550495147705,disc loss=0.4425309896469116, {hms_string(epoch_elapsed)}
# Epoch 364, gen loss=4.10017728805542,disc loss=0.49657511711120605, {hms_string(epoch_elapsed)}
# Epoch 365, gen loss=4.135930061340332,disc loss=0.45633310079574585, {hms_string(epoch_elapsed)}
# Epoch 366, gen loss=3.963956356048584,disc loss=0.4751293659210205, {hms_string(epoch_elapsed)}
# Epoch 367, gen loss=4.095119953155518,disc loss=0.44740912318229675, {hms_string(epoch_elapsed)}
# Epoch 368, gen loss=4.073851585388184,disc loss=0.43760818243026733, {hms_string(epoch_elapsed)}
# Epoch 369, gen loss=4.058635711669922,disc loss=0.456758052110672, {hms_string(epoch_elapsed)}
# Epoch 370, gen loss=4.162506103515625,disc loss=0.47031185030937195, {hms_string(epoch_elapsed)}
# Epoch 371, gen loss=4.0629563331604,disc loss=0.451461523771286, {hms_string(epoch_elapsed)}
# Epoch 372, gen loss=4.1273908615112305,disc loss=0.44497916102409363, {hms_string(epoch_elapsed)}
# Epoch 373, gen loss=4.178328990936279,disc loss=0.43346986174583435, {hms_string(epoch_elapsed)}
# Epoch 374, gen loss=4.112110137939453,disc loss=0.45897161960601807, {hms_string(epoch_elapsed)}
# Epoch 375, gen loss=4.147455215454102,disc loss=0.42800667881965637, {hms_string(epoch_elapsed)}
# Epoch 376, gen loss=4.128261089324951,disc loss=0.4510141909122467, {hms_string(epoch_elapsed)}
# Epoch 377, gen loss=4.22482442855835,disc loss=0.43581175804138184, {hms_string(epoch_elapsed)}
# Epoch 378, gen loss=4.091244697570801,disc loss=0.48722517490386963, {hms_string(epoch_elapsed)}
# Epoch 379, gen loss=4.194878101348877,disc loss=0.40515395998954773, {hms_string(epoch_elapsed)}
# Epoch 380, gen loss=4.082012176513672,disc loss=0.48860636353492737, {hms_string(epoch_elapsed)}
# Epoch 381, gen loss=4.008890151977539,disc loss=0.4663490653038025, {hms_string(epoch_elapsed)}
# Epoch 382, gen loss=4.161395072937012,disc loss=0.4225129187107086, {hms_string(epoch_elapsed)}
# Epoch 383, gen loss=4.131129741668701,disc loss=0.42496195435523987, {hms_string(epoch_elapsed)}
# Epoch 384, gen loss=4.247629165649414,disc loss=0.4091084897518158, {hms_string(epoch_elapsed)}
# Epoch 385, gen loss=4.235805034637451,disc loss=0.42892247438430786, {hms_string(epoch_elapsed)}
# Epoch 386, gen loss=4.229734420776367,disc loss=0.433610200881958, {hms_string(epoch_elapsed)}
# Epoch 387, gen loss=4.221625804901123,disc loss=0.4075973331928253, {hms_string(epoch_elapsed)}
# Epoch 388, gen loss=4.293715953826904,disc loss=0.42563366889953613, {hms_string(epoch_elapsed)}
# Epoch 389, gen loss=4.236559867858887,disc loss=0.42958328127861023, {hms_string(epoch_elapsed)}
# Epoch 390, gen loss=4.191933631896973,disc loss=0.42059803009033203, {hms_string(epoch_elapsed)}
# Epoch 391, gen loss=4.289736270904541,disc loss=0.44346898794174194, {hms_string(epoch_elapsed)}
# Epoch 392, gen loss=4.183295726776123,disc loss=0.40486210584640503, {hms_string(epoch_elapsed)}
# Epoch 393, gen loss=4.268126964569092,disc loss=0.41688814759254456, {hms_string(epoch_elapsed)}
# Epoch 394, gen loss=4.184213161468506,disc loss=0.45185473561286926, {hms_string(epoch_elapsed)}
# Epoch 395, gen loss=4.1667799949646,disc loss=0.4499487280845642, {hms_string(epoch_elapsed)}
# Epoch 396, gen loss=4.165124893188477,disc loss=0.43396419286727905, {hms_string(epoch_elapsed)}
# Epoch 397, gen loss=4.1572370529174805,disc loss=0.4249521791934967, {hms_string(epoch_elapsed)}
# Epoch 398, gen loss=4.194334506988525,disc loss=0.4097413122653961, {hms_string(epoch_elapsed)}
# Epoch 399, gen loss=4.229818344116211,disc loss=0.42487162351608276, {hms_string(epoch_elapsed)}
# Epoch 400, gen loss=4.23718786239624,disc loss=0.4371177852153778, {hms_string(epoch_elapsed)}
# Epoch 401, gen loss=4.1955060958862305,disc loss=0.44579267501831055, {hms_string(epoch_elapsed)}
# Epoch 402, gen loss=4.266225337982178,disc loss=0.4194188714027405, {hms_string(epoch_elapsed)}
# Epoch 403, gen loss=4.281259536743164,disc loss=0.4273112714290619, {hms_string(epoch_elapsed)}
# Epoch 404, gen loss=4.214871406555176,disc loss=0.42896369099617004, {hms_string(epoch_elapsed)}
# Epoch 405, gen loss=4.207644462585449,disc loss=0.4699989855289459, {hms_string(epoch_elapsed)}
# Epoch 406, gen loss=4.244157791137695,disc loss=0.43010857701301575, {hms_string(epoch_elapsed)}
# Epoch 407, gen loss=4.197636604309082,disc loss=0.46438607573509216, {hms_string(epoch_elapsed)}
# Epoch 408, gen loss=4.173483848571777,disc loss=0.42941948771476746, {hms_string(epoch_elapsed)}
# Epoch 409, gen loss=4.340588092803955,disc loss=0.3784438371658325, {hms_string(epoch_elapsed)}
# Epoch 410, gen loss=4.341407299041748,disc loss=0.4043564796447754, {hms_string(epoch_elapsed)}
# Epoch 411, gen loss=4.33876895904541,disc loss=0.40805134177207947, {hms_string(epoch_elapsed)}
# Epoch 412, gen loss=4.298880577087402,disc loss=0.3979036509990692, {hms_string(epoch_elapsed)}
# Epoch 413, gen loss=4.257884502410889,disc loss=0.42056286334991455, {hms_string(epoch_elapsed)}
# Epoch 414, gen loss=4.300673961639404,disc loss=0.3925527334213257, {hms_string(epoch_elapsed)}
# Epoch 415, gen loss=4.343871593475342,disc loss=0.3921787142753601, {hms_string(epoch_elapsed)}
# Epoch 416, gen loss=4.439756870269775,disc loss=0.3909617066383362, {hms_string(epoch_elapsed)}
# Epoch 417, gen loss=4.453376770019531,disc loss=0.4072209298610687, {hms_string(epoch_elapsed)}
# Epoch 418, gen loss=4.38958215713501,disc loss=0.43003183603286743, {hms_string(epoch_elapsed)}
# Epoch 419, gen loss=4.47861909866333,disc loss=0.4016737937927246, {hms_string(epoch_elapsed)}
# Epoch 420, gen loss=4.347104549407959,disc loss=0.44782429933547974, {hms_string(epoch_elapsed)}
# Epoch 421, gen loss=4.360005855560303,disc loss=0.4379253685474396, {hms_string(epoch_elapsed)}
# Epoch 422, gen loss=4.3892951011657715,disc loss=0.39817315340042114, {hms_string(epoch_elapsed)}
# Epoch 423, gen loss=4.357505798339844,disc loss=0.40733596682548523, {hms_string(epoch_elapsed)}
# Epoch 424, gen loss=4.323088645935059,disc loss=0.41403573751449585, {hms_string(epoch_elapsed)}
# Epoch 425, gen loss=4.365978717803955,disc loss=0.41301268339157104, {hms_string(epoch_elapsed)}
# Epoch 426, gen loss=4.387028217315674,disc loss=0.40364155173301697, {hms_string(epoch_elapsed)}
# Epoch 427, gen loss=4.356759548187256,disc loss=0.41883400082588196, {hms_string(epoch_elapsed)}
# Epoch 428, gen loss=4.362532615661621,disc loss=0.37896502017974854, {hms_string(epoch_elapsed)}
# Epoch 429, gen loss=4.4397711753845215,disc loss=0.41970500349998474, {hms_string(epoch_elapsed)}
# Epoch 430, gen loss=4.522890090942383,disc loss=0.3626680076122284, {hms_string(epoch_elapsed)}
# Epoch 431, gen loss=4.455774784088135,disc loss=0.42514002323150635, {hms_string(epoch_elapsed)}
# Epoch 432, gen loss=4.4013776779174805,disc loss=0.4299345910549164, {hms_string(epoch_elapsed)}
# Epoch 433, gen loss=4.457930564880371,disc loss=0.36751118302345276, {hms_string(epoch_elapsed)}
# Epoch 434, gen loss=4.380010604858398,disc loss=0.40027233958244324, {hms_string(epoch_elapsed)}
# Epoch 435, gen loss=4.44932222366333,disc loss=0.40667760372161865, {hms_string(epoch_elapsed)}
# Epoch 436, gen loss=4.408723831176758,disc loss=0.42306816577911377, {hms_string(epoch_elapsed)}
# Epoch 437, gen loss=4.3915228843688965,disc loss=0.4203824996948242, {hms_string(epoch_elapsed)}
# Epoch 438, gen loss=4.407498359680176,disc loss=0.4371199607849121, {hms_string(epoch_elapsed)}
# Epoch 439, gen loss=4.3716607093811035,disc loss=0.42515456676483154, {hms_string(epoch_elapsed)}
# Epoch 440, gen loss=4.390740871429443,disc loss=0.39591196179389954, {hms_string(epoch_elapsed)}
# Epoch 441, gen loss=4.41684103012085,disc loss=0.3836900591850281, {hms_string(epoch_elapsed)}
# Epoch 442, gen loss=4.469304084777832,disc loss=0.40136244893074036, {hms_string(epoch_elapsed)}
# Epoch 443, gen loss=4.548849105834961,disc loss=0.410334050655365, {hms_string(epoch_elapsed)}
# Epoch 444, gen loss=4.418922424316406,disc loss=0.42211654782295227, {hms_string(epoch_elapsed)}
# Epoch 445, gen loss=4.477585792541504,disc loss=0.39107874035835266, {hms_string(epoch_elapsed)}
# Epoch 446, gen loss=4.450414657592773,disc loss=0.3947017192840576, {hms_string(epoch_elapsed)}
# Epoch 447, gen loss=4.46672248840332,disc loss=0.40289533138275146, {hms_string(epoch_elapsed)}
# Epoch 448, gen loss=4.505642890930176,disc loss=0.4423075318336487, {hms_string(epoch_elapsed)}
# Epoch 449, gen loss=4.413320541381836,disc loss=0.3965187668800354, {hms_string(epoch_elapsed)}
# Epoch 450, gen loss=4.4302167892456055,disc loss=0.41818973422050476, {hms_string(epoch_elapsed)}
# Epoch 451, gen loss=4.386588096618652,disc loss=0.4009436368942261, {hms_string(epoch_elapsed)}
# Epoch 452, gen loss=4.4687089920043945,disc loss=0.41024816036224365, {hms_string(epoch_elapsed)}
# Epoch 453, gen loss=4.527916431427002,disc loss=0.40518835186958313, {hms_string(epoch_elapsed)}
# Epoch 454, gen loss=4.468188285827637,disc loss=0.41019466519355774, {hms_string(epoch_elapsed)}
# Epoch 455, gen loss=4.451952934265137,disc loss=0.38302871584892273, {hms_string(epoch_elapsed)}
# Epoch 456, gen loss=4.446376800537109,disc loss=0.39491090178489685, {hms_string(epoch_elapsed)}
# Epoch 457, gen loss=4.499166965484619,disc loss=0.4396957457065582, {hms_string(epoch_elapsed)}
# Epoch 458, gen loss=4.516003131866455,disc loss=0.4029621183872223, {hms_string(epoch_elapsed)}
# Epoch 459, gen loss=4.5230393409729,disc loss=0.3649464249610901, {hms_string(epoch_elapsed)}
# Epoch 460, gen loss=4.57093620300293,disc loss=0.3918858468532562, {hms_string(epoch_elapsed)}
# Epoch 461, gen loss=4.573370456695557,disc loss=0.3912956416606903, {hms_string(epoch_elapsed)}
# Epoch 462, gen loss=4.490845203399658,disc loss=0.4063177704811096, {hms_string(epoch_elapsed)}
# Epoch 463, gen loss=4.500510215759277,disc loss=0.4044993817806244, {hms_string(epoch_elapsed)}
# Epoch 464, gen loss=4.497261047363281,disc loss=0.3850211799144745, {hms_string(epoch_elapsed)}
# Epoch 465, gen loss=4.462734699249268,disc loss=0.37753826379776, {hms_string(epoch_elapsed)}
# Epoch 466, gen loss=4.498978614807129,disc loss=0.3981480300426483, {hms_string(epoch_elapsed)}
# Epoch 467, gen loss=4.629289627075195,disc loss=0.40299662947654724, {hms_string(epoch_elapsed)}
# Epoch 468, gen loss=4.517561435699463,disc loss=0.4003933370113373, {hms_string(epoch_elapsed)}
# Epoch 469, gen loss=4.649784088134766,disc loss=0.4066656827926636, {hms_string(epoch_elapsed)}
# Epoch 470, gen loss=4.624849319458008,disc loss=0.409016877412796, {hms_string(epoch_elapsed)}
# Epoch 471, gen loss=4.490593910217285,disc loss=0.40257441997528076, {hms_string(epoch_elapsed)}
# Epoch 472, gen loss=4.607970714569092,disc loss=0.43143922090530396, {hms_string(epoch_elapsed)}
# Epoch 473, gen loss=4.49959659576416,disc loss=0.3634394705295563, {hms_string(epoch_elapsed)}
# Epoch 474, gen loss=4.544797897338867,disc loss=0.40433916449546814, {hms_string(epoch_elapsed)}
# Epoch 475, gen loss=4.498311996459961,disc loss=0.4000435173511505, {hms_string(epoch_elapsed)}
# Epoch 476, gen loss=4.490200042724609,disc loss=0.41182205080986023, {hms_string(epoch_elapsed)}
# Epoch 477, gen loss=4.490087509155273,disc loss=0.3904486298561096, {hms_string(epoch_elapsed)}
# Epoch 478, gen loss=4.513366222381592,disc loss=0.41461753845214844, {hms_string(epoch_elapsed)}
# Epoch 479, gen loss=4.634157180786133,disc loss=0.3629568815231323, {hms_string(epoch_elapsed)}
# Epoch 480, gen loss=4.526208877563477,disc loss=0.418928325176239, {hms_string(epoch_elapsed)}
# Epoch 481, gen loss=4.566520690917969,disc loss=0.36031630635261536, {hms_string(epoch_elapsed)}
# Epoch 482, gen loss=4.675952434539795,disc loss=0.37992435693740845, {hms_string(epoch_elapsed)}
# Epoch 483, gen loss=4.638188362121582,disc loss=0.4035334587097168, {hms_string(epoch_elapsed)}
# Epoch 484, gen loss=4.529207229614258,disc loss=0.4216228723526001, {hms_string(epoch_elapsed)}
# Epoch 485, gen loss=4.539921760559082,disc loss=0.37999868392944336, {hms_string(epoch_elapsed)}
# Epoch 486, gen loss=4.527193069458008,disc loss=0.39626920223236084, {hms_string(epoch_elapsed)}
# Epoch 487, gen loss=4.553593635559082,disc loss=0.4037942588329315, {hms_string(epoch_elapsed)}
# Epoch 488, gen loss=4.4842352867126465,disc loss=0.41915929317474365, {hms_string(epoch_elapsed)}
# Epoch 489, gen loss=4.617672443389893,disc loss=0.3902638256549835, {hms_string(epoch_elapsed)}
# Epoch 490, gen loss=4.526411056518555,disc loss=0.38021761178970337, {hms_string(epoch_elapsed)}
# Epoch 491, gen loss=4.53692626953125,disc loss=0.3853892683982849, {hms_string(epoch_elapsed)}
# Epoch 492, gen loss=4.610651016235352,disc loss=0.38213664293289185, {hms_string(epoch_elapsed)}
# Epoch 493, gen loss=4.590295791625977,disc loss=0.38732436299324036, {hms_string(epoch_elapsed)}
# Epoch 494, gen loss=4.549520969390869,disc loss=0.38594916462898254, {hms_string(epoch_elapsed)}
# Epoch 495, gen loss=4.517551898956299,disc loss=0.3667382299900055, {hms_string(epoch_elapsed)}
# Epoch 496, gen loss=4.6579389572143555,disc loss=0.3827255070209503, {hms_string(epoch_elapsed)}
# Epoch 497, gen loss=4.563791751861572,disc loss=0.39786583185195923, {hms_string(epoch_elapsed)}
# Epoch 498, gen loss=4.601570129394531,disc loss=0.3651542365550995, {hms_string(epoch_elapsed)}
# Epoch 499, gen loss=4.57804012298584,disc loss=0.3845679759979248, {hms_string(epoch_elapsed)}
# Epoch 500, gen loss=4.66991662979126,disc loss=0.3821563720703125, {hms_string(epoch_elapsed)}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-d152560ca122> in <module>()
# ----> 1 train(train_dataset, EPOCHS)
#
# <ipython-input-13-beaaf5d2e204> in train(dataset, epochs)
#      24
#      25   elapsed = time.time()-start
# ---> 26   print (f'Training time: {hms_string(elapsed)}')
#
# NameError: name 'hms_string' is not defined
